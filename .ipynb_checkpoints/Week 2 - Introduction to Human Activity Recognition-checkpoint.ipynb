# %% [markdown]
# # Introduction to Human Activity Recognition

# %% [markdown]
# Here we will explore some common ways of preprocessing human activity recognition data.
#
# Using the example data we will learn:
# * how to merge multiple files into one large DataFrame
# * how to split data into sliding windows
# * how to quickly extract features from a window
# * how to set the number of classes considered for classification
# * how to build a simple Random Forest Classifier and train it on HAR data
# * how to build a simple CNN and train it on HAR data
#
# Bear in mind that the sample data offered is not cleaned or high quality. You should not use it in your own experiments but it is useful for this tutorial.
#
# You will need the following packages:
# * tsfresh
# * scikit-learn
# * tensorflow

# %% [markdown]
# #### Basic imports

# %%
import pandas as pd
import numpy as np
import tsfresh
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import tensorflow as tf

import os

import matplotlib.pyplot as plt

# keras goodies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv1D, Dropout, MaxPooling1D, BatchNormalization
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from tensorflow.keras import metrics as kmetrics
import tensorflow.keras.backend as K
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-67e3f3248a86> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import tsfresh
#       4 from sklearn.model_selection import train_test_split
#       5 from sklearn.ensemble import RandomForestClassifier
#
# ModuleNotFoundError: No module named 'tsfresh'

# %% [markdown]
# ## Loading multiple files into one large DataFrame

# %% [markdown]
# At this stage you should only be working with clean data, saved in the format required for Coursework 1. An example of such data can be found in the Data/Clean/ folder.

# %%
base_df = pd.DataFrame()

clean_data_folder = "2022_test"

for filename in os.listdir(clean_data_folder):
    full_path = f"{clean_data_folder}/{filename}"
    print(full_path)
    
    # load data into a DataFrame
    new_df = pd.read_csv(full_path)
    
    # merge into the base DataFrame
    base_df = pd.concat([base_df, new_df])
# Out:
# ../../pdiot_analysis/data/2022_test/Respeck_s1834237_Movement_30-09-2022_17-59-29.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1842855_Sitting_03-10-2022_23-46-16.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1810150_Lying down right_04-10-2022_19-27-18.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1853226_Descending stairs_28-09-2022_16-44-36.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1832512_Climbing stairs_05-10-2022_13-43-49.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1863792_Walking at normal speed_23-09-2022_15-42-20.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1828233_Movement_22-09-2022_14-06-24.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1834237_Sitting_30-09-2022_16-56-22.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1817967_Lying down right_30-09-2022_16-26-44.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1834237_Lying down on stomach_30-09-2022_17-17-45.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1836526_Lying down on back_23-09-2022_13-25-40.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1853226_Lying down on stomach_28-09-2022_16-32-28.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1863792_Climbing stairs_05-10-2022_16-19-26.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1810150_Lying down right_22-09-2022_11-46-01.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1842855_Sitting bent forward_03-10-2022_23-47-43.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1853226_Running_28-09-2022_16-57-50.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1862671_Lying down on stomach_22-09-2022_21-40-51.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1863792_Lying down on back_23-09-2022_15-39-05.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1817967_Standing_30-09-2022_17-16-31.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1842855_Sitting_03-10-2022_23-45-36.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1810150_Walking at normal speed_22-09-2022_15-08-33.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1862323_Running_02-10-2022_00-01-18.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1828233_Standing_22-09-2022_13-55-08.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1810150_Sitting bent forward_06-10-2022_20-28-47.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1862671_Lying down on back_23-09-2022_15-50-03.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1826377_Lying down left_30-09-2022_00-37-31.csv
# ../../pdiot_analysis/data/2022_test/Respeck_s1732873_Sitting bent forward_04-10-2022_14-08-40.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1800600_Lying down right_28-09-2022_13-04-27.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s1853226_Sitting bent backward_28-09-2022_16-16-22.csv
# ../../pdiot_analysis/data/2022_test/Thingy_s
# 3       -33.843750     Respeck      Movement              9   s1834237
# 4       -37.453125     Respeck      Movement              9   s1834237
# ...            ...         ...           ...            ...        ...
# 380668  601.625000      Thingy       Running             11   s1828233
# 380669   24.062500      Thingy       Running             11   s1828233
# 380670  -88.875000      Thingy       Running             11   s1828233
# 380671 -130.968750      Thingy       Running             11   s1828233
# 380672   21.250000      Thingy       Running             11   s1828233
#
#                   notes                                       recording_id  \
# 0       my flat complex  files\Respeck_s1834237_Movement_30-09-2022_17-...
# 1       my flat complex  files\Respeck_s1834237_Movement_30-09-2022_17-...
# 2       my flat complex  files\Respeck_s1834237_Movement_30-09-2022_17-...
# 3       my flat complex  files\Respeck_s1834237_Movement_30-09-2022_17-...
# 4       my flat complex  files\Respeck_s1834237_Movement_30-09-2022_17-...
# ...                 ...                                                ...
# 380668              NaN        Thingy_s1828233_Running_22-09-2022_15-02-28
# 380669              NaN        Thingy_s1828233_Running_22-09-2022_15-02-28
# 380670              NaN        Thingy_s1828233_Running_22-09-2022_15-02-28
# 380671              NaN        Thingy_s1828233_Running_22-09-2022_15-02-28
# 380672              NaN        Thingy_s1828233_Running_22-09-2022_15-02-28
#
#          mag_x    mag_y    mag_z
# 0          NaN      NaN      NaN
# 1          NaN      NaN      NaN
# 2          NaN      NaN      NaN
# 3          NaN      NaN      NaN
# 4          NaN      NaN      NaN
# ...        ...      ...      ...
# 380668   0.000   0.0000   0.0000
# 380669   0.000   0.0000   0.0000
# 380670   0.000   0.0000   0.0000
# 380671  57.875 -71.9375 -99.1875
# 380672   0.000   0.0000   0.0000
#
# [380673 rows x 16 columns]

# %% [markdown]
# Now you can get a list of all recording ids, activities, sensor types and anything else you might need.

# %%
print(f"The data was collected using the sensors: {base_df.sensor_type.unique()}")
print(f"The data was collected for the activities: {base_df.activity_type.unique()}")
print(f"The number of unique recordings is: {len(base_df.recording_id.unique())}")
print(f"The subject IDs in the recordings are: {len(base_df.subject_id.unique())}")
# Out:
# The data was collected using the sensors: ['Respeck' 'Thingy']
# The data was collected for the activities: ['Movement' 'Sitting' 'Lying down right' 'Descending stairs'
#  'Climbing stairs' 'Walking at normal speed' 'Lying down on stomach'
#  'Lying down on back' 'Sitting bent forward' 'Running' 'Standing'
#  'Lying down left' 'Sitting bent backward' 'Desk work']
# The number of unique recordings is: 504
# The subject IDs in the recordings are: 18

# %% [markdown]
# You can of course change the clean data folder to where you keep all the PDIoT data and you should be seeing a lot more subject IDs, unique recordings and activity types.

# %% [markdown]
# ## Splitting data into sliding windows

# %% [markdown]
# The sliding window approach is one of the most efficient ways to process Human Activity Recognition data. We saw in the last notebook that sensor data comes in the form of Time Series. One single datapoint is not enough to represent an activity, we need a larger snapshot of the signal for that. The image below shows how a sliding window achieves that.
#
# ![sliding windows](../Images/sliding_windows_complete.png "Sliding Windows")
#
# The windows can have some amount of overlap, as shown in the picture, or they can have no overlap at all in which case they would be side-by-side.
#
# Each window can now be treated as an input datapoint to whichever model you choose to train.

# %% [markdown]
# ### Watch out for separate recordings

# %% [markdown]
# You need to make sure that when you split your data into sliding windows you don't accidentally include two separate recordings in the same window. This would cause the signal from the first recording to suddenly "jump" to an unrelated value from the second recording.
#
# For this, you will have to first split up your dataset by recording (this is where the recording ID comes in), then you have to split each recording into sliding windows. At the end you can aggregate all of your resulting sliding windows in a large dataset.

# %% [markdown]
# ### Sliding windows with Pandas

# %% [markdown]
# Pandas conveniently offers built-in functions that help us create the sliding window data very easily.

# %%
example_recording = base_df[base_df.activity_code == 1]

# confim we only have one recording here
len(example_recording.recording_id.unique())
# Out:
# 36

# %%
window_size = 50 # 50 datapoints for the window size, which, at 25Hz, means 2 seconds
step_size = 25 # this is 50% overlap

window_number = 0 # start a counter at 0 to keep track of the window number

large_enough_windows = [window for window in example_recording.rolling(window=window_size, min_periods=window_size) if len(window) == window_size]

# %%
# we then get the windows with the required overlap

overlapping_windows = large_enough_windows[::step_size]

# %%
# then we will append a window ID to each window
for window in overlapping_windows:
    window.loc[:, 'window_id'] = window_number
    window_number += 1

# %%
# now we concatenate all the resulting windows
final_sliding_windows = pd.concat(overlapping_windows).reset_index(drop=True)

# %%
final_sliding_windows
# Out:
#           timestamp   accel_x   accel_y   accel_z     gyro_x     gyro_y  \
# 0      1.663928e+12 -0.080811 -0.975647  0.042908   4.234375   8.984375
# 1      1.663928e+12 -0.141846 -0.909729  0.118591  -0.843750  18.203125
# 2      1.663928e+12  0.083008 -1.086975  0.092712   7.921875  -1.531250
# 3      1.663928e+12 -0.358643 -1.211487  0.340271  -9.406250  -7.328125
# 4      1.663928e+12 -0.434082 -1.290588  0.148621 -22.078125   2.296875
# ...             ...       ...       ...       ...        ...        ...
# 54245  1.664665e+12  0.126953 -1.141174 -0.195618  17.750000   5.140625
# 54246  1.664665e+12  0.019043 -1.013977 -0.025452   7.000000  10.750000
# 54247  1.664665e+12  0.208984 -0.900940  0.074402   0.859375   8.281250
# 54248  1.664665e+12  0.133545 -0.924133 -0.143860  -0.296875   2.890625
# 54249  1.664665e+12 -0.028564 -0.942444 -0.328674  -0.218750  -1.171875
#
#           gyro_z sensor_type            activity_type  activity_code  \
# 0      -2.234375     Respeck  Walking at normal speed              1
# 1      -5.859375     Respeck  Walking at normal speed              1
# 2      -8.531250     Respeck  Walking at normal speed              1
# 3     -16.562500     Respeck  Walking at normal speed              1
# 4     -20.828125     Respeck  Walking at normal speed              1
# ...          ...         ...                      ...            ...
# 54245  14.546875     Respeck  Walking at normal speed              1
# 54246   7.093750     Respeck  Walking at normal speed              1
# 54247  -7.203125     Respeck  Walking at normal speed              1
# 54248  -0.312500     Respeck  Walking at normal speed              1
# 54249  -5.421875     Respeck  Walking at normal speed              1
#
#       subject_id notes                                       recording_id  \
# 0       s1863792   NaN  Respeck_s1863792_Walking at normal speed_23-09...
# 1       s1863792   NaN  Respeck_s1863792_Walking at normal speed_23-09...
# 2       s1863792   NaN  Respeck_s1863792_Walking at normal speed_23-09...
# 3       s1863792   NaN  Respeck_s1863792_Walking at normal speed_23-09...
# 4       s1863792   NaN  Respeck_s1863792_Walking at normal speed_23-09...
# ...          ...   ...                                                ...
# 54245   s1862323    zh  Respeck_s1862323_Walking at normal speed_01-10...
# 54246   s1862323    zh  Respeck_s1862323_Walking at normal speed_01-10...
# 54247   s1862323    zh  Respeck_s1862323_Walking at normal speed_01-10...
# 54248   s1862323    zh  Respeck_s1862323_Walking at normal speed_01-10...
# 54249   s1862323    zh  Respeck_s1862323_Walking at normal speed_01-10...
#
#        mag_x  mag_y  mag_z  window_id
# 0        NaN    NaN    NaN          0
# 1        NaN    NaN    NaN          0
# 2        NaN    NaN    NaN          0
# 3        NaN    NaN    NaN          0
# 4        NaN    NaN    NaN          0
# ...      ...    ...    ...        ...
# 54245    NaN    NaN    NaN       1084
# 54246    NaN    NaN    NaN       1084
# 54247    NaN    NaN    NaN       1084
# 54248    NaN    NaN    NaN       1084
# 54249    NaN    NaN    NaN       1084
#
# [54250 rows x 17 columns]

# %% [markdown]
# You can plot each window to see the signals. Here we will plot the first four windows of the walking activity.

# %%
first_four_windows = [group for _, group in final_sliding_windows[final_sliding_windows.window_id < 4].groupby("window_id")]

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 6))

for i in range(4):
    ax[i].plot(first_four_windows[i]['gyro_x'])
    ax[i].plot(first_four_windows[i]['gyro_y'])
    ax[i].plot(first_four_windows[i]['gyro_z'])
    ax[i].set_title(f"Window number = {first_four_windows[i].window_id.values[0]}")

# %% [markdown]
# It's also interesting to observe the dimensionality of one window. Considering just the accelerometer and gyroscope signals, with all three axes, the resulting dimensionality of one window is:

# %%
columns_of_interest = ['accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']

# %%
np.array(first_four_windows[0][columns_of_interest]).shape
# Out:
# (50, 6)

# %% [markdown]
# ## From sliding windows to datapoints

# %% [markdown]
# Each sliding window needs to be further processed in order to represent an appropriate input datapoint. The preprocessing methods might differ depending on which type of model you choose to use.
#
# You can also do further processing on the signal types and axes, for example smooth the signal, apply axis fusion, eliminate noise etc.
#
# Here we will discuss simple examples without any preprocessing.

# %% [markdown]
# ### Feature extraction with tsfresh

# %% [markdown]
# One quick and simple method to consider for HAR is a [Random Forest Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html). It can take a multi-dimensional datapoint as input and can output a classification.
#
# We can transform each window of data into one single, multidimensional datapoint by applying simple computations using the [tsfresh](https://tsfresh.readthedocs.io/en/latest/text/feature_extraction_settings.html) package.

# %%
feature_list = []

for col in columns_of_interest:
    new_features = tsfresh.extract_features(timeseries_container=final_sliding_windows, column_id='window_id',
                        column_value=col, default_fc_parameters=tsfresh.feature_extraction.MinimalFCParameters())
    
    feature_list.append(new_features)
    
feature_list = pd.concat(feature_list, axis=1)

feature_list
# Out:
# Feature Extraction: 100%|███████████████████████| 20/20 [00:00<00:00, 85.10it/s]
# Feature Extraction: 100%|███████████████████████| 20/20 [00:00<00:00, 96.10it/s]
# Feature Extraction: 100%|███████████████████████| 20/20 [00:00<00:00, 97.58it/s]
# Feature Extraction: 100%|███████████████████████| 20/20 [00:00<00:00, 85.48it/s]
# Feature Extraction: 100%|██████████████████████| 20/20 [00:00<00:00, 107.19it/s]
# 1081                    6.190025         38.316409                  6.204152
# 1082                    6.164799         38.004745                  6.193898
# 1083                    6.483891         42.040846                  6.485201
# 1084                    5.982172         35.786379                  6.011104
#
#       gyro_z__maximum  gyro_z__minimum
# 0           10.187500       -20.828125
# 1            9.781250       -16.843750
# 2            9.781250       -14.203125
# 3            9.359375       -16.359375
# 4            9.359375       -16.359375
# ...               ...              ...
# 1080        17.468750       -12.750000
# 1081        16.687500       -14.359375
# 1082        19.359375       -16.531250
# 1083        19.359375       -16.531250
# 1084        18.156250       -12.531250
#
# [1085 rows x 54 columns]

# %% [markdown]
# Now the index represents the window ID, and each row in the DataFrame represents a multi-dimensional datapoint which we can use as input to the RFC.
#
# You can use the window ID to refer back to the initial dataframe and get the class (activity type) for each window.

# %% [markdown]
# We will now process both recordings so that we have two classes for our classifier. For your own work you should only aim to perform classification on data from one sensor.

# %%
window_size = 50 # 50 datapoints for the window size, which, at 25Hz, means 2 seconds
step_size = 25 # this is 50% overlap

window_number = 0 # start a counter at 0 to keep track of the window number

all_overlapping_windows = []

for rid, group in base_df.groupby("recording_id"):
    print(f"Processing rid = {rid}")
    
    large_enough_windows = [window for window in group.rolling(window=window_size, min_periods=window_size) if len(window) == window_size]
    
    overlapping_windows = large_enough_windows[::step_size] 
    
    # then we will append a window ID to each window
    for window in overlapping_windows:
        window.loc[:, 'window_id'] = window_number
        window_number += 1
    
    
    all_overlapping_windows.append(pd.concat(overlapping_windows).reset_index(drop=True))
# Out:
# Processing rid = C:\2022\iot\our_branch\Labs\Data\2022_A\day1\Respeck_s1810150_Standing_06-10-2022_20-49-00
# Processing rid = Respeck_s1732873_Climbing stairs_04-10-2022_14-29-16
# Processing rid = Respeck_s1732873_Descending stairs_04-10-2022_14-29-57
# Processing rid = Respeck_s1732873_Desk work_05-10-2022_09-10-44
# Processing rid = Respeck_s1732873_Lying down left_04-10-2022_14-12-42
# Processing rid = Respeck_s1732873_Lying down on back_04-10-2022_14-11-56
# Processing rid = Respeck_s1732873_Lying down on stomach_04-10-2022_14-14-08
# Processing rid = Respeck_s1732873_Lying down right_04-10-2022_14-13-24
# Processing rid = Respeck_s1732873_Movement_05-10-2022_10-08-43
# Processing rid = Respeck_s1732873_Running_04-10-2022_14-32-19
# Processing rid = Respeck_s1732873_Sitting bent backward_04-10-2022_14-09-25
# Processing rid = Respeck_s1732873_Sitting bent forward_04-10-2022_14-08-40
# Processing rid = Respeck_s1732873_Sitting_04-10-2022_14-07-59
# Processing rid = Respeck_s1732873_Standing_04-10-2022_14-10-08
# Processing rid = Respeck_s1732873_Walking at normal speed_04-10-2022_14-31-37
# Processing rid = Respeck_s1800600_Climbing stairs_05-10-2022_14-07-25
# Processing rid = Respeck_s1800600_Descending stairs_05-10-2022_14-09-55
# Processing rid = Respeck_s1800600_Desk work_28-09-2022_13-35-51
# Processing rid = Respeck_s1800600_Lying down left_28-09-2022_13-02-18
# Processing rid = Respeck_s1800600_Lying down on back_28-09-2022_13-06-41
# Processing rid = Respeck_s1800600_Lying down on stomach_28-09-2022_13-05-16
# Processing rid = Respeck_s1800600_Lying down right_28-09-2022_13-03-48
# Processing rid = Respeck_s1800600_Movement_28-09-2022_13-37-54
# Processing rid = Respeck_s1800600_Running_28-09-2022_13-27-08
# Processing rid = Respeck_s1800600_Sitting bent backward_28-09-2022_12-57-52
# Processing rid = Respeck_s1800600_Sitting bent forward_28-09-2022_12-55-52
# Processing rid = Respeck_s1800600_Sitting_28-09-2022_12-49-23
# Processing rid = Respeck_s1800600_Standing_28-09-2022_12-59-33
# Processing rid = Respeck_s1800600_Walking at normal speed_28-09-2022_13-20-53
# Processing rid = Respeck_s1810150_Climbing stairs_22-09-2022_19-35-27
# Processing rid = Respeck_s1810150_Descending stairs_22-09-2022_19-49-57
# Processing rid = Respeck_s1810150_Desk work_06-10-2022_20-41-46
# Processing rid = Respeck_s1810150_Lying down left_22-09-2022_11-45-09
# Processing rid = Respeck_s1810150_Lying down on back_22-09-2022_11-44-14
# Processing rid = Respeck_s1810150_Lying down on stomach_22-09-2022_11-46-54
# Processing rid = Respeck_s1810150_Lying down right_22-09-2022_11-46-01
# Processing rid = Respeck_s1810150_Movement_06-10-2022_20-27-45
# Processing rid = Respeck_s1810150_Running_22-09-2022_14-06-03
# Processing rid = Respeck_s1810150_Sitting bent backward_22-09-2022_11-40-46
# Processing rid = Respeck_s1810150_Sitting bent forward_06-10-2022_20-28-47
# Processing rid = Respeck_s1810150_Sitting_22-09-2022_11-49-45
# Processing rid = Respeck_s1810150_Walking at normal speed_22-09-2022_12-28-56
# Processing rid = Respeck_s1817967_Climbing stairs_30-09-2022_16-32-18
# Processing rid = Respeck_s1817967_Descending stairs_30-09-2022_16-32-59
# Processing rid = Respeck_s1817967_Desk work_30-09-2022_16-34-46
# Processing rid = Respeck_s1817967_Lying down left_30-09-2022_16-25-54
# Processing rid = Respeck_s1817967_Lying down on back_30-09-2022_16-24-43
# Processing rid = Respeck_s1817967_Lying down on stomach_30-09-2022_16-27-33
# Processing rid = Respeck_s1817967_Lying down right_30-09-2022_16-26-44
# Processing rid = Respeck_s1817967_Movement_30-09-2022_16-35-29
# Processing rid = Respeck_s1817967_Running_30-09-2022_16-30-26
# Processing rid = Respeck_s1817967_Sitting bent backward_30-09-2022_16-21-38
# Processing rid = Respeck_s1817967_Sitting bent forward_30-09-2022_16-23-28
# Processing rid = Respeck_s1817967_Sitting_30-09-2022_16-19-45
# Processing rid = Respeck_s1817967_Standing_30-09-2022_16-22-44
# Processing rid = Respeck_s1817967_Walking at normal speed_30-09-2022_16-29-44
# Processing rid = Respeck_s1826377_Climbing stairs_07-10-2022_09-28-54
# Processing rid = Respeck_s1826377_Descending stairs_07-10-2022_09-29-45
# Processing rid = Respeck_s1826377_Desk work_30-09-2022_02-05-57
# Processing rid = Respeck_s1826377_Lying down left_28-09-2022_22-20-25
# Processing rid = Respeck_s1826377_Lying down on back_28-09-2022_22-18-43
# Processing rid = Respeck_s1826377_Lying down on stomach_28-09-2022_22-28-16
# Processing rid = Respeck_s1826377_Lying down right_28-09-2022_22-22-54
# Processing rid = Respeck_s1842855_Movement_04-10-2022_00-05-19
# Processing rid = Respeck_s1842855_Running_04-10-2022_00-13-13
# Processing rid = Respeck_s1842855_Sitting bent backward_03-10-2022_23-48-37
# Processing rid = Respeck_s1842855_Sitting bent forward_03-10-2022_23-47-07
# Processing rid = Respeck_s1842855_Sitting_03-10-2022_23-45-36
# Processing rid = Respeck_s1842855_Standing_03-10-2022_23-50-06
# Processing rid = Respeck_s1842855_Walking at normal speed_04-10-2022_00-16-28
# Processing rid = Respeck_s1852056_Climbing stairs_05-10-2022_14-35-44
# Processing rid = Respeck_s1852056_Descending stairs_05-10-2022_14-39-23
# Processing rid = Respeck_s1852056_Desk work_05-10-2022_15-06-36
# Processing rid = Respeck_s1852056_Lying down left_05-10-2022_15-16-11
# Processing rid = Respeck_s1852056_Lying down on back_05-10-2022_15-11-38
# Processing rid = Respeck_s1852056_Lying down on stomach_05-10-2022_15-13-53
# Processing rid = Respeck_s1852056_Lying down right_05-10-2022_15-17-15
# Processing rid = Respeck_s1852056_Movement_05-10-2022_15-10-01
# Processing rid = Respeck_s1852056_Running_05-10-2022_15-55-29
# Processing rid = Respeck_s1852056_Sitting bent backward_05-10-2022_15-03-21
# Processing rid = Respeck_s1852056_Sitting bent forward_05-10-2022_14-44-04
# Processing rid = Respeck_s1852056_Sitting_05-10-2022_14-43-03
# Processing rid = Respeck_s1852056_Standing_05-10-2022_15-07-34
# Processing rid = Respeck_s1852056_Walking at normal speed_05-10-2022_15-52-26
# Processing rid = Respeck_s1853226_Climbing stairs_28-09-2022_16-38-36
# Processing rid = Respeck_s1853226_Descending stairs_28-09-2022_16-41-08
# Processing rid = Respeck_s1853226_Desk work_28-09-2022_16-36-56
# Processing rid = Respeck_s1853226_Lying down left_28-09-2022_16-22-09
# Processing rid = Respeck_s1853226_Lying down on back_28-09-2022_16-19-43
# Processing rid = Respeck_s1853226_Lying down on stomach_28-09-2022_16-31-43
# Processing rid = Respeck_s1853226_Lying down right_28-09-2022_16-24-19
# Processing rid = Respeck_s1853226_Movement_28-09-2022_16-33-59
# Processing rid = Respeck_s1853226_Running_28-09-2022_16-55-34
# Processing rid = Respeck_s1853226_Sitting bent backward_28-09-2022_16-15-24
# Processing rid = Respeck_s1853226_Sitting bent forward_28-09-2022_16-12-21
# Processing rid = Respeck_s1853226_Sitting_28-09-2022_16-11-24
# Processing rid = Respeck_s1853226_Standing_28-09-2022_16-17-29
# Processing rid = Respeck_s1853226_Walking at normal speed_28-09-2022_16-53-27
# Processing rid = Respeck_s1858629_Climbing stairs_22-09-2022_20-05-01
# Processing rid = Respeck_s1858629_Descending stairs_22-09-2022_20-06-01
# Processing rid = Respeck_s1858629_Desk work_26-09-2022_12-45-36
# Processing rid = Respeck_s1858629_Lying down left_26-09-2022_13-24-23
# Processing rid = Respeck_s1858629_Lying down on back_26-09-2022_13-15-13
# Processing rid = Respeck_s1858629_Lying down on stomach_26-09-2022_13-01-18
# Processing rid = Respeck_s1858629_Lying down right_26-09-2022_13-28-36
# Processing rid = Respeck_s1858629_Movement_26-09-2022_14-00-19
# Processing rid = Respeck_s1858629_Running_07-10-2022_08-52-32
# Processing rid = Respeck_s1858629_Sitting bent backward_26-09-2022_12-40-05
# Processing rid = Respeck_s1858629_Sitting bent forward_26-09-2022_12-17-47
# Processing rid = Respeck_s1858629_Sitting_26-09-2022_12-06-10
# Processing rid = Respeck_s1858629_Standing_26-09-2022_12-56-13
# Processing rid = Respeck_s1858629_Walking at normal speed_07-10-2022_08-46-49
# Processing rid = Respeck_s1862323_Climbing stairs_02-10-2022_00-05-31
# Processing rid = Respeck_s1862323_Descending stairs_02-10-2022_00-13-57
# Processing rid = Respeck_s1862323_Desk work_01-10-2022_23-14-04
# Processing rid = Respeck_s1862323_Lying down left_01-10-2022_22-45-29
# Processing rid = Respeck_s1862323_Lying down on back_01-10-2022_22-39-10
# Processing rid = Respeck_s1862323_Lying down on stomach_01-10-2022_23-05-46
# Processing rid = Respeck_s1862323_Lying down right_01-10-2022_22-54-56
# Processing rid = Respeck_s1862323_Movement_01-10-2022_23-17-54
# Processing rid = Respeck_s1862323_Running_01-10-2022_23-59-27
# Processing rid = Respeck_s1862323_Sitting bent backward_01-10-2022_22-25-45
# Processing rid = Respeck_s1862323_Sitting bent forward_01-10-2022_22-03-29
# Processing rid = Respeck_s1862323_Sitting_01-10-2022_21-57-58
# Processing rid = Respeck_s1862323_Standing_01-10-2022_22-30-55
# Processing rid = Respeck_s1862323_Walking at normal speed_01-10-2022_23-55-56
# Processing rid = Respeck_s1862671_Climbing stairs_22-09-2022_21-02-33
# Processing rid = Respeck_s1862671_Descending stairs_22-09-2022_21-01-44
# Processing rid = Respeck_s1862671_Desk work_22-09-2022_21-58-38
# Processing rid = Respeck_s1862671_Lying down left_05-10-2022_22-56-11
# Processing rid = Respeck_s1862671_Lying down on back_22-09-2022_21-32-19
# Processing rid = Respeck_s1862671_Lying down on stomach_22-09-2022_21-40-51
# Processing rid = Respeck_s1862671_Lying down right_05-10-2022_22-54-41
# Processing rid = Respeck_s1862671_Movement_22-09-2022_22-58-03
# Processing rid = Respeck_s1862671_Running_22-09-2022_22-51-08
# Processing rid = Respeck_s1862671_Sitting bent backward_05-10-2022_22-25-52
# Processing rid = Respeck_s1862671_Sitting bent forward_22-09-2022_21-50-21
# Processing rid = Respeck_s1862671_Sitting_04-10-2022_12-45-29
# Processing rid = Respeck_s1862671_Standing_04-10-2022_12-43-00
# Processing rid = Respeck_s1862671_Walking at normal speed_22-09-2022_21-09-24
# Processing rid = Respeck_s1863792_Climbing stairs_05-10-2022_16-17-08
# Processing rid = Respeck_s1863792_Descending stairs_05-10-2022_16-18-15
# Processing rid = Respeck_s1863792_Desk work_23-09-2022_15-49-23
# Processing rid = Respeck_s1863792_Lying down left_23-09-2022_15-34-31
# Processing rid = Respeck_s1863792_Lying down on back_23-09-2022_15-39-05
# Processing rid = Respeck_s1863792_Lying down on stomach_23-09-2022_15-37-42
# Processing rid = Respeck_s1863792_Lying down right_23-09-2022_15-36-02
# Processing rid = Respeck_s1863792_Movement_23-09-2022_15-53-04
# Processing rid = files\Respeck_s1834237_Sitting bent backward_30-09-2022_16-59-23
# Processing rid = files\Respeck_s1834237_Sitting bent forward_30-09-2022_16-58-23
# Processing rid = files\Respeck_s1834237_Sitting_30-09-2022_16-55-17
# Processing rid = files\Respeck_s1834237_Standing_30-09-2022_17-02-21
# Processing rid = files\Respeck_s1834237_Walking at normal speed_30-09-2022_17-39-29
# Processing rid = files\Thingy_s1834237_Climbing stairs_30-09-2022_17-54-34
# Processing rid = files\Thingy_s1834237_Descending stairs_30-09-2022_17-55-23
# Processing rid = files\Thingy_s1834237_Desk work_30-09-2022_17-51-25
# Processing rid = files\Thingy_s1834237_Lying down left_30-09-2022_17-15-26
# Processing rid = files\Thingy_s1834237_Lying down on back_30-09-2022_17-10-14
# Processing rid = files\Thingy_s1834237_Lying down on stomach_30-09-2022_17-16-56
# Processing rid = files\Thingy_s1834237_Lying down right_30-09-2022_17-11-19
# Processing rid = files\Thingy_s1834237_Movement_30-09-2022_18-00-09
# Processing rid = files\Thingy_s1834237_Running_30-09-2022_17-43-00
# Processing rid = files\Thingy_s1834237_Sitting bent backward_30-09-2022_17-00-14
# Processing rid = files\Thingy_s1834237_Sitting bent forward_30-09-2022_16-57-34
# Processing rid = files\Thingy_s1834237_Sitting_30-09-2022_16-56-22
# Processing rid = files\Thingy_s1834237_Standing_30-09-2022_17-01-21
# Processing rid = files\Thingy_s1834237_Walking at normal speed_30-09-2022_17-40-21

# %%
final_sliding_windows = pd.concat(all_overlapping_windows).reset_index(drop=True)

# %%
# now extract all features
feature_list = []

for col in columns_of_interest:
    new_features = tsfresh.extract_features(timeseries_container=final_sliding_windows, column_id='window_id',
                        column_value=col, default_fc_parameters=tsfresh.feature_extraction.MinimalFCParameters())
    
    feature_list.append(new_features)
    
feature_list = pd.concat(feature_list, axis=1)

feature_list
# Out:
# Feature Extraction: 100%|███████████████████████| 20/20 [00:03<00:00,  6.02it/s]
# Feature Extraction: 100%|███████████████████████| 20/20 [00:02<00:00,  7.00it/s]
# Feature Extraction: 100%|███████████████████████| 20/20 [00:03<00:00,  6.40it/s]
# Feature Extraction: 100%|███████████████████████| 20/20 [00:03<00:00,  6.54it/s]
# Feature Extraction: 100%|███████████████████████| 20/20 [00:02<00:00,  7.03it/s]
# Feature Extraction: 100%|███████████████████████| 20/20 [00:03<00:00,  6.26it/s]
#        accel_x__sum_values  accel_x__median  accel_x__mean  accel_x__length  \
# 0               -10.845703        -0.216675      -0.216914             50.0
# 1               -10.818604        -0.216187      -0.216372             50.0
# 2               -10.489502        -0.210693      -0.209790             50.0
# 3               -10.311279        -0.206665      -0.206226             50.0
# 4               -10.548584        -0.211182      -0.210972             50.0
# ...                    ...              ...            ...              ...
# 14609           -46.262695        -0.854004      -0.925254             50.0
# 14610           -45.315430        -0.844727      -0.906309             50.0
# 14611           -45.810547        -0.851074      -0.916211             50.0
# 14612           -47.112305        -0.860352      -0.942246             50.0
# 14613           -45.827148        -0.831543      -0.916543             50.0
#
#        accel_x__standard_deviation  accel_x__variance  \
# 0                         0.010934           0.000120
# 1                         0.008302           0.000069
# 2                         0.010663           0.000114
# 3                         0.010581           0.000112
# 4                         0.007953           0.000063
# ...                            ...                ...
# 14609                     0.412701           0.170322
# 14610                     0.424313           0.180042
# 14611                     0.407624           0.166157
# 14612                     0.393781           0.155063
# 14613                     0.392667           0.154187
#
#        accel_x__root_mean_square  accel_x__maximum  accel_x__minimum  \
# 0                       0.217189         -0.190186         -0.248779
# 1                       0.216531         -0.190186         -0.239746
# 2                       0.210061         -0.185547         -0.238525
# 3                       0.206497         -0.185547         -0.238525
# 4                       0.211122         -0.190186         -0.225586
# ...                          ...               ...               ...
# 14609                   1.013122         -0.155273         -2.000000
# 14610                   1.000718         -0.144531         -2.000000
# 14611                   1.002796         -0.144531         -2.000000
# 14612                   1.021220         -0.305664         -1.714844
# 14613                   0.997115         -0.365234         -2.000000
#
#        accel_y__sum_values  ...  gyro_y__minimum  gyro_z__sum_values  \
# 0               -48.698120  ...        -1.281250            0.515625
# 1               -48.696411  ...        -1.656250            4.562500
# 2               -48.782104  ...        -2.015625           17.546875
# 3               -48.825561  ...        -2.015625            3.859375
# 4               -48.705688  ...        -1.875000           -8.687500
# ...                    ...  ...              ...                 ...
# 14609           -20.803711  ...      -138.718750         -131.500000
# 14610           -20.762695  ...      -138.656250         -113.781250
# 14611           -19.991211  ...      -138.656250          -57.437500
# 14612           -20.725586  ...      -127.968750          -19.750000
# 14613           -20.885742  ...      -129.750000          -57.000000
#
#        gyro_z__median  gyro_z__mean  gyro_z__length  \
# 0           -0.078125      0.010313            50.0
# 1            0.132812      0.091250            50.0
# 2            0.359375      0.350938            50.0
# 3            0.078125      0.077188            50.0
# 4           -0.140625     -0.173750            50.0
# ...               ...           ...             ...
# 14609      -10.296875     -2.630000            50.0
# 14610       -3.062500     -2.275625            50.0
# 14611        7.031250     -1.148750            50.0
# 14612        4.812500     -0.395000            50.0
# 14613        7.312500     -1.140000            50.0
#
#        gyro_z__standard_deviation  gyro_z__variance  gyro_z__root_mean_square  \
# 0                        0.522030          0.272516                  0.522132
# 1                        0.360790          0.130170                  0.372151
# 2                        0.449296          0.201867                  0.570109
# 3                        0.621501          0.386264                  0.626276
# 4                        0.367990          0.135416                  0.406947
# ...                           ...               ...                       ...
# 14609                   41.732476       1741.599584                 41.815266
# 14610                   42.033507       1766.815730                 42.095061
# 14611                   40.105461       1608.447991                 40.121909
# 14612                   40.741633       1659.880655                 40.743548
# 14613                   43.747910       1913.879658                 43.762761
#
#        gyro_z__maximum  gyro_z__minimum
# 0             1.359375        -1.281250
# 1             1.046875        -0.687500
# 2             1.390625        -0.937500
# 3             1.390625        -1.234375
# 4             0.625000        -1.234375
# ...                ...              ...
# 14609        57.531250      -106.812500
# 14610        58.875000      -106.812500
# 14611        58.875000      -103.343750
# 14612        61.281250       -82.593750
# 14613        61.281250      -125.250000
#
# [14614 rows x 54 columns]

# %% [markdown]
# Now we also extract the classes from each window

# %%
final_sliding_windows.groupby("window_id")[['activity_type']].agg(np.min)
# Out:
#                      activity_type
# window_id
# 0                         Standing
# 1                         Standing
# 2                         Standing
# 3                         Standing
# 4                         Standing
# ...                            ...
# 14609      Walking at normal speed
# 14610      Walking at normal speed
# 14611      Walking at normal speed
# 14612      Walking at normal speed
# 14613      Walking at normal speed
#
# [14614 rows x 1 columns]

# %% [markdown]
# We need to assign a number to each categorical class for the Random Forest Classifer. It is mainly up to you how you categorise your classes. In this example, we will use the labels:
# - 0 for Desk work
# - 1 for Walking at normal speed
#
# Bear in mind that your classification task will be multi-class, not binary.

# %%
class_labels = {
    'Desk work': 0,
    'Walking at normal speed': 1,
    'Climbing stairs': 2,
    'Descending stairs': 3,
    'Lying down left': 4,
    'Lying down right': 5,
    'Lying down on back': 6,
    'Lying down on stomach': 7,
    'Movement': 8,
    'Running': 9,
    'Sitting': 10,
    'Sitting bent backward': 11,
    'Sitting bent forward': 12,
    'Standing': 13
    
    
}

# %%
window_id_class_labels = final_sliding_windows.groupby("window_id")[['activity_type']].agg(np.min).replace(class_labels)
window_id_class_labels
# Out:
#            activity_type
# window_id
# 0                     13
# 1                     13
# 2                     13
# 3                     13
# 4                     13
# ...                  ...
# 14609                  1
# 14610                  1
# 14611                  1
# 14612                  1
# 14613                  1
#
# [14614 rows x 1 columns]

# %% [markdown]
# ### Quickly training a Random Forest Classifier

# %% [markdown]
# We now have all the tools to start training a Random Forest Classifier. We will use the feature_list as inputs and window_id_class_labels as outputs. We will do a basic 80/20 split of the data for demonstration purposes.
#
# In your project you should split the data into training and tests sets by excluding entire subjects from the training set. This is discussed later on in this notebook.

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_list, window_id_class_labels,
                                                    test_size=0.2, train_size=0.8)

# %%
print(f"Training set: X_train = {X_train.shape}, y_train = {y_train.shape}")
print(f"Test set: X_test = {X_test.shape}, y_test = {y_test.shape}")
# Out:
# Training set: X_train = (11691, 54), y_train = (11691, 1)
# Test set: X_test = (2923, 54), y_test = (2923, 1)

# %% [markdown]
# Now we can build and train the random forest classifier

# %%
rfc = RandomForestClassifier(n_estimators=10)

rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)
# Out:
# /home/umuttkartal/miniconda3/envs/pdiot/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(classification_report(y_pred=y_pred, y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       232
#            1       0.93      0.96      0.94       208
#            2       0.93      0.94      0.94       224
#            3       0.93      0.92      0.92       192
#            4       1.00      1.00      1.00       204
#            5       1.00      1.00      1.00       209
#            6       0.99      0.99      0.99       222
#            7       0.99      1.00      1.00       221
#            8       0.92      0.86      0.89       187
#            9       0.97      1.00      0.99       201
#           10       0.97      0.94      0.95       200
#           11       0.99      0.98      0.98       208
#           12       1.00      0.99      0.99       210
#           13       0.97      0.97      0.97       205
#
#     accuracy                           0.96      2923
#    macro avg       0.96      0.96      0.96      2923
# weighted avg       0.96      0.96      0.96      2923

# %% [markdown]
# This is a very easy problem so the classifier learns very quickly. Your actual problem of classifying multiple activities will be much harder.

# %% [markdown]
# ## Leave-one-subject-out cross-validation

# %% [markdown]
# One of the other reason our previous classifier functions so well is that each person performs activities in a very consistent manner. If a subject's data is both in the training set and the test set, it provides the model with an unfair advantage. Moreover, the results that your model will output will be falsely high. When you test your model on a completely new, unseen subject, your accuracy will drop considerably.
#
# This is why when training a HAR model you will want to do a special kind of cross-validation: Leave-One-Subject-Out (LOSOXV), where we leave one (or more) subject(s) in the testing set at each iteration.
#
# ![losoxv](../Images/LOOCV.png "losoxv")
#
# This ensures that the results we get from our classifier are consistent to what we would get in real life, if we were to test the model on a new user.

# %% [markdown]
# ## Training a simple CNN

# %% [markdown]
# There are some different preprocessing techniques you can apply when the resulting "datapoint" is an input to a convolutional neural network.
#
# You can use two types of convolutional layers:
# * 1D Conv Layers - which will work on 1D data, for example a single axis from one single sensor (accel, gyro or mag)
# * 2D Conv Layers - suitable if the input data is in the form of an image, for example
#
# We will be demonstrating how to build a simple 1D CNN using 6 channels: the 3 axes of the accelerometer and the 3 axes of the gyroscope.

# %% [markdown]
# ### Setting up the model

# %%
filters = 64
kernel_size = 3
n_features = 6
activation='relu'
n_classes = 14

# %%
from keras.utils.vis_utils import plot_model
model = Sequential()

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear', 
                 input_shape=(window_size, n_features)))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(n_classes, activation='softmax'))

model.summary()
plot_model(model, show_shapes=True, show_layer_names = True)
# Out:
# 2022-10-12 11:35:12.807271: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-12 11:35:12.807694: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 48, 64)            1216
#
#  batch_normalization (BatchN  (None, 48, 64)           256
#  ormalization)
#
#  activation (Activation)     (None, 48, 64)            0
#
#  conv1d_1 (Conv1D)           (None, 46, 64)            12352
#
#  batch_normalization_1 (Batc  (None, 46, 64)           256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 46, 64)            0
#
#  conv1d_2 (Conv1D)           (None, 44, 64)            12352
#
#  batch_normalization_2 (Batc  (None, 44, 64)           256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 44, 64)            0
#
#  flatten (Flatten)           (None, 2816)              0
#
#  dense (Dense)               (None, 100)               281700
#
#  dense_1 (Dense)             (None, 14)                1414
#
# =================================================================
# Total params: 309,802
# Trainable params: 309,418
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Re-generating the data in the appropriate format

# %% [markdown]
# We need to do a bit more work with our data to bring it into a format fit for training a CNN.
#
# A CNN will take multi-dimensional arrays as input. We have already specified that the input shape is (window_size, n_features), i.e. (50, 6).

# %% [markdown]
# Remember that we generated sliding windows before. Now we just need to take the raw values from each window and create a training set.

# %%
columns_of_interest
# Out:
# ['accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']

# %%
X = []
y = []

for window_id, group in final_sliding_windows.groupby('window_id'):
    print(f"window_id = {window_id}")
    
    shape = group[columns_of_interest].values.shape
    print(f"shape = {shape}")
    
    X.append(group[columns_of_interest].values)
    y.append(class_labels[group["activity_type"].values[0]])
# Out:
# window_id = 0
# shape = (50, 6)
# window_id = 1
# shape = (50, 6)
# window_id = 2
# shape = (50, 6)
# window_id = 3
# shape = (50, 6)
# window_id = 4
# shape = (50, 6)
# window_id = 5
# shape = (50, 6)
# window_id = 6
# shape = (50, 6)
# window_id = 7
# shape = (50, 6)
# window_id = 8
# shape = (50, 6)
# window_id = 9
# shape = (50, 6)
# window_id = 10
# shape = (50, 6)
# window_id = 11
# shape = (50, 6)
# window_id = 12
# shape = (50, 6)
# window_id = 13
# shape = (50, 6)
# window_id = 14
# shape = (50, 6)
# window_id = 15
# shape = (50, 6)
# window_id = 16
# shape = (50, 6)
# window_id = 17
# shape = (50, 6)
# window_id = 18
# shape = (50, 6)
# window_id = 19
# shape = (50, 6)
# window_id = 20
# shape = (50, 6)
# window_id = 21
# shape = (50, 6)
# window_id = 22
# shape = (50, 6)
# window_id = 23
# shape = (50, 6)
# window_id = 24
# shape = (50, 6)
# window_id = 25
# shape = (50, 6)
# window_id = 26
# shape = (50, 6)
# window_id = 27
# shape = (50, 6)
# window_id = 28
# shape = (50, 6)
# window_id = 29
# shape = (50, 6)
# window_id = 30
# shape = (50, 6)
# window_id = 31
# shape = (50, 6)
# window_id = 32
# shape = (50, 6)
# window_id = 33
# shape = (50, 6)
# window_id = 34
# shape = (50, 6)
# window_id = 35
# shape = (50, 6)
# window_id = 36
# shape = (50, 6)
# window_id = 37
# shape = (50, 6)
# window_id = 38
# shape = (50, 6)
# window_id = 39
# shape = (50, 6)
# window_id = 40
# shape = (50, 6)
# window_id = 41
# shape = (50, 6)
# window_id = 42
# shape = (50, 6)
# window_id = 43
# shape = (50, 6)
# window_id = 44
# shape = (50, 6)
# window_id = 45
# shape = (50, 6)
# window_id = 46
# shape = (50, 6)
# window_id = 47
# shape = (50, 6)
# window_id = 48
# shape = (50, 6)
# window_id = 49
# shape = (50, 6)
# window_id = 50
# shape = (50, 6)
# window_id = 51
# shape = (50, 6)
# window_id = 52
# shape = (50, 6)
# window_id = 53
# shape = (50, 6)
# window_id = 54
# shape = (50, 6)
# window_id = 55
# shape = (50, 6)
# window_id = 56
# shape = (50, 6)
# window_id = 57
# shape = (50, 6)
# window_id = 58
# shape = (50, 6)
# window_id = 59
# shape = (50, 6)
# window_id = 60
# shape = (50, 6)
# window_id = 61
# shape = (50, 6)
# window_id = 62
# shape = (50, 6)
# window_id = 63
# shape = (50, 6)
# window_id = 64
# shape = (50, 6)
# window_id = 65
# shape = (50, 6)
# window_id = 66
# shape = (50, 6)
# window_id = 67
# shape = (50, 6)
# window_id = 68
# shape = (50, 6)
# window_id = 69
# shape = (50, 6)
# window_id = 70
# shape = (50, 6)
# window_id = 71
# shape = (50, 6)
# window_id = 72
# shape = (50, 6)
# window_id = 73
# shape = (50, 6)
# window_id = 74
# shape = (50, 6)
# window_id = 75
# shape = (50, 6)
# window_id = 76
# shape = (50, 6)
# window_id = 77
# shape = (50, 6)
# window_id = 78
# shape = (50, 6)
# window_id = 79
# shape = (50, 6)
# window_id = 80
# shape = (50, 6)
# window_id = 81
# shape = (50, 6)
# window_id = 82
# shape = (50, 6)
# window_id = 83
# shape = (50, 6)
# window_id = 84
# shape = (50, 6)
# window_id = 85
# shape = (50, 6)
# window_id = 86
# shape = (50, 6)
# window_id = 87
# shape = (50, 6)
# window_id = 88
# shape = (50, 6)
# window_id = 89
# shape = (50, 6)
# window_id = 90
# shape = (50, 6)
# window_id = 91
# shape = (50, 6)
# window_id = 92
# shape = (50, 6)
# window_id = 93
# shape = (50, 6)
# window_id = 94
# shape = (50, 6)
# window_id = 95
# shape = (50, 6)
# window_id = 96
# shape = (50, 6)
# window_id = 97
# shape = (50, 6)
# window_id = 98
# shape = (50, 6)
# window_id = 99
# shape = (50, 6)
# window_id = 100
# shape = (50, 6)
# window_id = 101
# shape = (50, 6)
# window_id = 102
# shape = (50, 6)
# window_id = 103
# shape = (50, 6)
# window_id = 104
# shape = (50, 6)
# window_id = 105
# shape = (50, 6)
# window_id = 106
# shape = (50, 6)
# window_id = 107
# shape = (50, 6)
# window_id = 108
# shape = (50, 6)
# window_id = 109
# shape = (50, 6)
# window_id = 110
# shape = (50, 6)
# window_id = 111
# shape = (50, 6)
# window_id = 112
# shape = (50, 6)
# window_id = 113
# shape = (50, 6)
# window_id = 114
# shape = (50, 6)
# window_id = 115
# shape = (50, 6)
# window_id = 116
# shape = (50, 6)
# window_id = 117
# shape = (50, 6)
# window_id = 118
# shape = (50, 6)
# window_id = 119
# shape = (50, 6)
# window_id = 120
# shape = (50, 6)
# window_id = 121
# shape = (50, 6)
# window_id = 122
# shape = (50, 6)
# window_id = 123
# shape = (50, 6)
# window_id = 124
# shape = (50, 6)
# window_id = 125
# shape = (50, 6)
# window_id = 126
# shape = (50, 6)
# window_id = 127
# shape = (50, 6)
# window_id = 128
# shape = (50, 6)
# window_id = 129
# shape = (50, 6)
# window_id = 130
# shape = (50, 6)
# window_id = 131
# shape = (50, 6)
# window_id = 132
# shape = (50, 6)
# window_id = 133
# shape = (50, 6)
# window_id = 134
# shape = (50, 6)
# window_id = 135
# shape = (50, 6)
# window_id = 136
# shape = (50, 6)
# window_id = 137
# shape = (50, 6)
# window_id = 138
# shape = (50, 6)
# window_id = 139
# shape = (50, 6)
# window_id = 140
# shape = (50, 6)
# window_id = 141
# shape = (50, 6)
# window_id = 142
# shape = (50, 6)
# window_id = 143
# shape = (50, 6)
# window_id = 144
# shape = (50, 6)
# window_id = 145
# shape = (50, 6)
# window_id = 146
# shape = (50, 6)
# window_id = 147
# shape = (50, 6)
# window_id = 148
# shape = (50, 6)
# window_id = 149
# shape = (50, 6)
# window_id = 150
# shape = (50, 6)
# window_id = 151
# shape = (50, 6)
# window_id = 152
# shape = (50, 6)
# window_id = 153
# shape = (50, 6)
# window_id = 154
# shape = (50, 6)
# window_id = 155
# shape = (50, 6)
# window_id = 156
# shape = (50, 6)
# window_id = 157
# shape = (50, 6)
# window_id = 158
# shape = (50, 6)
# window_id = 159
# shape = (50, 6)
# window_id = 160
# shape = (50, 6)
# window_id = 161
# shape = (50, 6)
# window_id = 162
# shape = (50, 6)
# window_id = 163
# shape = (50, 6)
# window_id = 164
# shape = (50, 6)
# window_id = 165
# shape = (50, 6)
# window_id = 166
# shape = (50, 6)
# window_id = 167
# shape = (50, 6)
# window_id = 168
# shape = (50, 6)
# window_id = 169
# shape = (50, 6)
# window_id = 170
# shape = (50, 6)
# window_id = 171
# shape = (50, 6)
# window_id = 172
# shape = (50, 6)
# window_id = 173
# shape = (50, 6)
# window_id = 174
# shape = (50, 6)
# window_id = 175
# shape = (50, 6)
# window_id = 176
# shape = (50, 6)
# window_id = 177
# shape = (50, 6)
# window_id = 178
# shape = (50, 6)
# window_id = 179
# shape = (50, 6)
# window_id = 180
# shape = (50, 6)
# window_id = 181
# shape = (50, 6)
# window_id = 182
# shape = (50, 6)
# window_id = 183
# shape = (50, 6)
# window_id = 184
# shape = (50, 6)
# window_id = 185
# shape = (50, 6)
# window_id = 186
# shape = (50, 6)
# window_id = 187
# shape = (50, 6)
# window_id = 188
# shape = (50, 6)
# window_id = 189
# shape = (50, 6)
# window_id = 190
# shape = (50, 6)
# window_id = 191
# shape = (50, 6)
# window_id = 192
# shape = (50, 6)
# window_id = 193
# shape = (50, 6)
# window_id = 194
# shape = (50, 6)
# window_id = 195
# shape = (50, 6)
# window_id = 196
# shape = (50, 6)
# window_id = 197
# shape = (50, 6)
# window_id = 198
# shape = (50, 6)
# window_id = 199
# shape = (50, 6)
# window_id = 200
# shape = (50, 6)
# window_id = 201
# shape = (50, 6)
# window_id = 202
# shape = (50, 6)
# window_id = 203
# shape = (50, 6)
# window_id = 204
# shape = (50, 6)
# window_id = 205
# shape = (50, 6)
# window_id = 206
# shape = (50, 6)
# window_id = 207
# shape = (50, 6)
# window_id = 208
# shape = (50, 6)
# window_id = 209
# shape = (50, 6)
# window_id = 210
# shape = (50, 6)
# window_id = 211
# shape = (50, 6)
# window_id = 212
# shape = (50, 6)
# window_id = 213
# shape = (50, 6)
# window_id = 214
# shape = (50, 6)
# window_id = 215
# shape = (50, 6)
# window_id = 216
# shape = (50, 6)
# window_id = 217
# shape = (50, 6)
# window_id = 218
# shape = (50, 6)
# window_id = 219
# shape = (50, 6)
# window_id = 220
# shape = (50, 6)
# window_id = 221
# shape = (50, 6)
# window_id = 222
# shape = (50, 6)
# window_id = 223
# shape = (50, 6)
# window_id = 224
# shape = (50, 6)
# window_id = 225
# shape = (50, 6)
# window_id = 226
# shape = (50, 6)
# window_id = 227
# shape = (50, 6)
# window_id = 228
# shape = (50, 6)
# window_id = 229
# shape = (50, 6)
# window_id = 230
# shape = (50, 6)
# window_id = 231
# shape = (50, 6)
# window_id = 232
# shape = (50, 6)
# window_id = 233
# shape = (50, 6)
# window_id = 234
# shape = (50, 6)
# window_id = 235
# shape = (50, 6)
# window_id = 236
# shape = (50, 6)
# window_id = 237
# shape = (50, 6)
# window_id = 238
# shape = (50, 6)
# window_id = 239
# shape = (50, 6)
# window_id = 240
# shape = (50, 6)
# window_id = 241
# shape = (50, 6)
# window_id = 242
# shape = (50, 6)
# window_id = 243
# shape = (50, 6)
# window_id = 244
# shape = (50, 6)
# window_id = 245
# shape = (50, 6)
# window_id = 246
# shape = (50, 6)
# window_id = 247
# shape = (50, 6)
# window_id = 248
# shape = (50, 6)
# window_id = 249
# shape = (50, 6)
# window_id = 250
# shape = (50, 6)
# window_id = 251
# shape = (50, 6)
# window_id = 252
# shape = (50, 6)
# window_id = 253
# shape = (50, 6)
# window_id = 254
# shape = (50, 6)
# window_id = 255
# shape = (50, 6)
# window_id = 256
# shape = (50, 6)
# window_id = 257
# shape = (50, 6)
# window_id = 258
# shape = (50, 6)
# window_id = 259
# shape = (50, 6)
# window_id = 260
# shape = (50, 6)
# window_id = 261
# shape = (50, 6)
# window_id = 262
# shape = (50, 6)
# window_id = 263
# shape = (50, 6)
# window_id = 264
# shape = (50, 6)
# window_id = 265
# shape = (50, 6)
# window_id = 266
# shape = (50, 6)
# window_id = 267
# shape = (50, 6)
# window_id = 268
# shape = (50, 6)
# window_id = 269
# shape = (50, 6)
# window_id = 270
# shape = (50, 6)
# window_id = 271
# shape = (50, 6)
# window_id = 272
# shape = (50, 6)
# window_id = 273
# shape = (50, 6)
# window_id = 274
# shape = (50, 6)
# window_id = 275
# shape = (50, 6)
# window_id = 276
# shape = (50, 6)
# window_id = 277
# shape = (50, 6)
# window_id = 278
# shape = (50, 6)
# window_id = 279
# shape = (50, 6)
# window_id = 280
# shape = (50, 6)
# window_id = 281
# shape = (50, 6)
# window_id = 282
# shape = (50, 6)
# window_id = 283
# shape = (50, 6)
# window_id = 284
# shape = (50, 6)
# window_id = 285
# shape = (50, 6)
# window_id = 286
# shape = (50, 6)
# window_id = 287
# shape = (50, 6)
# window_id = 288
# shape = (50, 6)
# window_id = 289
# shape = (50, 6)
# window_id = 290
# shape = (50, 6)
# window_id = 291
# shape = (50, 6)
# window_id = 292
# shape = (50, 6)
# window_id = 293
# shape = (50, 6)
# window_id = 294
# shape = (50, 6)
# window_id = 295
# shape = (50, 6)
# window_id = 296
# shape = (50, 6)
# window_id = 297
# shape = (50, 6)
# window_id = 298
# shape = (50, 6)
# window_id = 299
# shape = (50, 6)
# window_id = 300
# shape = (50, 6)
# window_id = 301
# shape = (50, 6)
# window_id = 302
# shape = (50, 6)
# window_id = 303
# shape = (50, 6)
# window_id = 304
# shape = (50, 6)
# window_id = 305
# shape = (50, 6)
# window_id = 306
# shape = (50, 6)
# window_id = 307
# shape = (50, 6)
# window_id = 308
# shape = (50, 6)
# window_id = 309
# shape = (50, 6)
# window_id = 310
# shape = (50, 6)
# window_id = 311
# shape = (50, 6)
# window_id = 312
# shape = (50, 6)
# window_id = 313
# shape = (50, 6)
# window_id = 314
# shape = (50, 6)
# window_id = 315
# shape = (50, 6)
# window_id = 316
# shape = (50, 6)
# window_id = 317
# shape = (50, 6)
# window_id = 318
# shape = (50, 6)
# window_id = 319
# shape = (50, 6)
# window_id = 320
# shape = (50, 6)
# window_id = 321
# shape = (50, 6)
# window_id = 322
# shape = (50, 6)
# window_id = 323
# shape = (50, 6)
# window_id = 324
# shape = (50, 6)
# window_id = 325
# shape = (50, 6)
# window_id = 326
# shape = (50, 6)
# window_id = 327
# shape = (50, 6)
# window_id = 328
# shape = (50, 6)
# window_id = 329
# shape = (50, 6)
# window_id = 330
# shape = (50, 6)
# window_id = 331
# shape = (50, 6)
# window_id = 332
# shape = (50, 6)
# window_id = 333
# shape = (50, 6)
# window_id = 334
# shape = (50, 6)
# window_id = 335
# shape = (50, 6)
# window_id = 336
# shape = (50, 6)
# window_id = 337
# shape = (50, 6)
# window_id = 338
# shape = (50, 6)
# window_id = 339
# shape = (50, 6)
# window_id = 340
# shape = (50, 6)
# window_id = 341
# shape = (50, 6)
# window_id = 342
# shape = (50, 6)
# window_id = 343
# shape = (50, 6)
# window_id = 344
# shape = (50, 6)
# window_id = 345
# shape = (50, 6)
# window_id = 346
# shape = (50, 6)
# window_id = 347
# shape = (50, 6)
# window_id = 348
# shape = (50, 6)
# window_id = 349
# shape = (50, 6)
# window_id = 350
# shape = (50, 6)
# window_id = 351
# shape = (50, 6)
# window_id = 352
# shape = (50, 6)
# window_id = 353
# shape = (50, 6)
# window_id = 354
# shape = (50, 6)
# window_id = 355
# shape = (50, 6)
# window_id = 356
# shape = (50, 6)
# window_id = 357
# shape = (50, 6)
# window_id = 358
# shape = (50, 6)
# window_id = 359
# shape = (50, 6)
# window_id = 360
# shape = (50, 6)
# window_id = 361
# shape = (50, 6)
# window_id = 362
# shape = (50, 6)
# window_id = 363
# shape = (50, 6)
# window_id = 364
# shape = (50, 6)
# window_id = 365
# shape = (50, 6)
# window_id = 366
# shape = (50, 6)
# window_id = 367
# shape = (50, 6)
# window_id = 368
# shape = (50, 6)
# window_id = 369
# shape = (50, 6)
# window_id = 370
# shape = (50, 6)
# window_id = 371
# shape = (50, 6)
# window_id = 372
# shape = (50, 6)
# window_id = 373
# shape = (50, 6)
# window_id = 374
# shape = (50, 6)
# window_id = 375
# shape = (50, 6)
# window_id = 376
# shape = (50, 6)
# window_id = 377
# shape = (50, 6)
# window_id = 378
# shape = (50, 6)
# window_id = 379
# shape = (50, 6)
# window_id = 380
# shape = (50, 6)
# window_id = 381
# shape = (50, 6)
# window_id = 382
# shape = (50, 6)
# window_id = 383
# shape = (50, 6)
# window_id = 384
# shape = (50, 6)
# window_id = 385
# shape = (50, 6)
# window_id = 386
# shape = (50, 6)
# window_id = 387
# shape = (50, 6)
# window_id = 388
# shape = (50, 6)
# window_id = 389
# shape = (50, 6)
# window_id = 390
# shape = (50, 6)
# window_id = 391
# shape = (50, 6)
# window_id = 392
# shape = (50, 6)
# window_id = 393
# shape = (50, 6)
# window_id = 394
# shape = (50, 6)
# window_id = 395
# shape = (50, 6)
# window_id = 396
# shape = (50, 6)
# window_id = 397
# shape = (50, 6)
# window_id = 398
# shape = (50, 6)
# window_id = 399
# shape = (50, 6)
# window_id = 400
# shape = (50, 6)
# window_id = 401
# shape = (50, 6)
# window_id = 402
# shape = (50, 6)
# window_id = 403
# shape = (50, 6)
# window_id = 404
# shape = (50, 6)
# window_id = 405
# shape = (50, 6)
# window_id = 406
# shape = (50, 6)
# window_id = 407
# shape = (50, 6)
# window_id = 408
# shape = (50, 6)
# window_id = 409
# shape = (50, 6)
# window_id = 410
# shape = (50, 6)
# window_id = 411
# shape = (50, 6)
# window_id = 412
# shape = (50, 6)
# window_id = 413
# shape = (50, 6)
# window_id = 414
# shape = (50, 6)
# window_id = 415
# shape = (50, 6)
# window_id = 416
# shape = (50, 6)
# window_id = 417
# shape = (50, 6)
# window_id = 418
# shape = (50, 6)
# window_id = 419
# shape = (50, 6)
# window_id = 420
# shape = (50, 6)
# window_id = 421
# shape = (50, 6)
# window_id = 422
# shape = (50, 6)
# window_id = 423
# shape = (50, 6)
# window_id = 424
# shape = (50, 6)
# window_id = 425
# shape = (50, 6)
# window_id = 426
# shape = (50, 6)
# window_id = 427
# shape = (50, 6)
# window_id = 428
# shape = (50, 6)
# window_id = 429
# shape = (50, 6)
# window_id = 430
# shape = (50, 6)
# window_id = 431
# shape = (50, 6)
# window_id = 432
# shape = (50, 6)
# window_id = 433
# shape = (50, 6)
# window_id = 434
# shape = (50, 6)
# window_id = 435
# shape = (50, 6)
# window_id = 436
# shape = (50, 6)
# window_id = 437
# shape = (50, 6)
# window_id = 438
# shape = (50, 6)
# window_id = 439
# shape = (50, 6)
# window_id = 440
# shape = (50, 6)
# window_id = 441
# shape = (50, 6)
# window_id = 442
# shape = (50, 6)
# window_id = 443
# shape = (50, 6)
# window_id = 444
# shape = (50, 6)
# window_id = 445
# shape = (50, 6)
# window_id = 446
# shape = (50, 6)
# window_id = 447
# shape = (50, 6)
# window_id = 448
# shape = (50, 6)
# window_id = 449
# shape = (50, 6)
# window_id = 450
# shape = (50, 6)
# window_id = 451
# shape = (50, 6)
# window_id = 452
# shape = (50, 6)
# window_id = 453
# shape = (50, 6)
# window_id = 454
# shape = (50, 6)
# window_id = 455
# shape = (50, 6)
# window_id = 456
# shape = (50, 6)
# window_id = 457
# shape = (50, 6)
# window_id = 458
# shape = (50, 6)
# window_id = 459
# shape = (50, 6)
# window_id = 460
# shape = (50, 6)
# window_id = 461
# shape = (50, 6)
# window_id = 462
# shape = (50, 6)
# window_id = 463
# shape = (50, 6)
# window_id = 464
# shape = (50, 6)
# window_id = 465
# shape = (50, 6)
# window_id = 466
# shape = (50, 6)
# window_id = 467
# shape = (50, 6)
# window_id = 468
# shape = (50, 6)
# window_id = 469
# shape = (50, 6)
# window_id = 470
# shape = (50, 6)
# window_id = 471
# shape = (50, 6)
# window_id = 472
# shape = (50, 6)
# window_id = 473
# shape = (50, 6)
# window_id = 474
# shape = (50, 6)
# window_id = 475
# shape = (50, 6)
# window_id = 476
# shape = (50, 6)
# window_id = 477
# shape = (50, 6)
# window_id = 478
# shape = (50, 6)
# window_id = 479
# shape = (50, 6)
# window_id = 480
# shape = (50, 6)
# window_id = 481
# shape = (50, 6)
# window_id = 482
# shape = (50, 6)
# window_id = 483
# shape = (50, 6)
# window_id = 484
# shape = (50, 6)
# window_id = 485
# shape = (50, 6)
# window_id = 486
# shape = (50, 6)
# window_id = 487
# shape = (50, 6)
# window_id = 488
# shape = (50, 6)
# window_id = 489
# shape = (50, 6)
# window_id = 490
# shape = (50, 6)
# window_id = 491
# shape = (50, 6)
# window_id = 492
# shape = (50, 6)
# window_id = 493
# shape = (50, 6)
# window_id = 494
# shape = (50, 6)
# window_id = 495
# shape = (50, 6)
# window_id = 496
# shape = (50, 6)
# window_id = 497
# shape = (50, 6)
# window_id = 498
# shape = (50, 6)
# window_id = 499
# shape = (50, 6)
# window_id = 500
# shape = (50, 6)
# window_id = 501
# shape = (50, 6)
# window_id = 502
# shape = (50, 6)
# window_id = 503
# shape = (50, 6)
# window_id = 504
# shape = (50, 6)
# window_id = 505
# shape = (50, 6)
# window_id = 506
# shape = (50, 6)
# window_id = 507
# shape = (50, 6)
# window_id = 508
# shape = (50, 6)
# window_id = 509
# shape = (50, 6)
# window_id = 510
# shape = (50, 6)
# window_id = 511
# shape = (50, 6)
# window_id = 512
# shape = (50, 6)
# window_id = 513
# shape = (50, 6)
# window_id = 514
# shape = (50, 6)
# window_id = 515
# shape = (50, 6)
# window_id = 516
# shape = (50, 6)
# window_id = 517
# shape = (50, 6)
# window_id = 518
# shape = (50, 6)
# window_id = 519
# shape = (50, 6)
# window_id = 520
# shape = (50, 6)
# window_id = 521
# shape = (50, 6)
# window_id = 522
# shape = (50, 6)
# window_id = 523
# shape = (50, 6)
# window_id = 524
# shape = (50, 6)
# window_id = 525
# shape = (50, 6)
# window_id = 526
# shape = (50, 6)
# window_id = 527
# shape = (50, 6)
# window_id = 528
# shape = (50, 6)
# window_id = 529
# shape = (50, 6)
# window_id = 530
# shape = (50, 6)
# window_id = 531
# shape = (50, 6)
# window_id = 532
# shape = (50, 6)
# window_id = 533
# shape = (50, 6)
# window_id = 534
# shape = (50, 6)
# window_id = 535
# shape = (50, 6)
# window_id = 536
# shape = (50, 6)
# window_id = 537
# shape = (50, 6)
# window_id = 538
# shape = (50, 6)
# window_id = 539
# shape = (50, 6)
# window_id = 540
# shape = (50, 6)
# window_id = 541
# shape = (50, 6)
# window_id = 542
# shape = (50, 6)
# window_id = 543
# shape = (50, 6)
# window_id = 544
# shape = (50, 6)
# window_id = 545
# shape = (50, 6)
# window_id = 546
# shape = (50, 6)
# window_id = 547
# shape = (50, 6)
# window_id = 548
# shape = (50, 6)
# window_id = 549
# shape = (50, 6)
# window_id = 550
# shape = (50, 6)
# window_id = 551
# shape = (50, 6)
# window_id = 552
# shape = (50, 6)
# window_id = 553
# shape = (50, 6)
# window_id = 554
# shape = (50, 6)
# window_id = 555
# shape = (50, 6)
# window_id = 556
# shape = (50, 6)
# window_id = 557
# shape = (50, 6)
# window_id = 558
# shape = (50, 6)
# window_id = 559
# shape = (50, 6)
# window_id = 560
# shape = (50, 6)
# window_id = 561
# shape = (50, 6)
# window_id = 562
# shape = (50, 6)
# window_id = 563
# shape = (50, 6)
# window_id = 564
# shape = (50, 6)
# window_id = 565
# shape = (50, 6)
# window_id = 566
# shape = (50, 6)
# window_id = 567
# shape = (50, 6)
# window_id = 568
# shape = (50, 6)
# window_id = 569
# shape = (50, 6)
# window_id = 570
# shape = (50, 6)
# window_id = 571
# shape = (50, 6)
# window_id = 572
# shape = (50, 6)
# window_id = 573
# shape = (50, 6)
# window_id = 574
# shape = (50, 6)
# window_id = 575
# shape = (50, 6)
# window_id = 576
# shape = (50, 6)
# window_id = 577
# shape = (50, 6)
# window_id = 578
# shape = (50, 6)
# window_id = 579
# shape = (50, 6)
# window_id = 580
# shape = (50, 6)
# window_id = 581
# shape = (50, 6)
# window_id = 582
# shape = (50, 6)
# window_id = 583
# shape = (50, 6)
# window_id = 584
# shape = (50, 6)
# window_id = 585
# shape = (50, 6)
# window_id = 586
# shape = (50, 6)
# window_id = 587
# shape = (50, 6)
# window_id = 588
# shape = (50, 6)
# window_id = 589
# shape = (50, 6)
# window_id = 590
# shape = (50, 6)
# window_id = 591
# shape = (50, 6)
# window_id = 592
# shape = (50, 6)
# window_id = 593
# shape = (50, 6)
# window_id = 594
# shape = (50, 6)
# window_id = 595
# shape = (50, 6)
# window_id = 596
# shape = (50, 6)
# window_id = 597
# shape = (50, 6)
# window_id = 598
# shape = (50, 6)
# window_id = 599
# shape = (50, 6)
# window_id = 600
# shape = (50, 6)
# window_id = 601
# shape = (50, 6)
# window_id = 602
# shape = (50, 6)
# window_id = 603
# shape = (50, 6)
# window_id = 604
# shape = (50, 6)
# window_id = 605
# shape = (50, 6)
# window_id = 606
# shape = (50, 6)
# window_id = 607
# shape = (50, 6)
# window_id = 608
# shape = (50, 6)
# window_id = 609
# shape = (50, 6)
# window_id = 610
# shape = (50, 6)
# window_id = 611
# shape = (50, 6)
# window_id = 612
# shape = (50, 6)
# window_id = 613
# shape = (50, 6)
# window_id = 614
# shape = (50, 6)
# window_id = 615
# shape = (50, 6)
# window_id = 616
# shape = (50, 6)
# window_id = 617
# shape = (50, 6)
# window_id = 618
# shape = (50, 6)
# window_id = 619
# shape = (50, 6)
# window_id = 620
# shape = (50, 6)
# window_id = 621
# shape = (50, 6)
# window_id = 622
# shape = (50, 6)
# window_id = 623
# shape = (50, 6)
# window_id = 624
# shape = (50, 6)
# window_id = 625
# shape = (50, 6)
# window_id = 626
# shape = (50, 6)
# window_id = 627
# shape = (50, 6)
# window_id = 628
# shape = (50, 6)
# window_id = 629
# shape = (50, 6)
# window_id = 630
# shape = (50, 6)
# window_id = 631
# shape = (50, 6)
# window_id = 632
# shape = (50, 6)
# window_id = 633
# shape = (50, 6)
# window_id = 634
# shape = (50, 6)
# window_id = 635
# shape = (50, 6)
# window_id = 636
# shape = (50, 6)
# window_id = 637
# shape = (50, 6)
# window_id = 638
# shape = (50, 6)
# window_id = 639
# shape = (50, 6)
# window_id = 640
# shape = (50, 6)
# window_id = 641
# shape = (50, 6)
# window_id = 642
# shape = (50, 6)
# window_id = 643
# shape = (50, 6)
# window_id = 644
# shape = (50, 6)
# window_id = 645
# shape = (50, 6)
# window_id = 646
# shape = (50, 6)
# window_id = 647
# shape = (50, 6)
# window_id = 648
# shape = (50, 6)
# window_id = 649
# shape = (50, 6)
# window_id = 650
# shape = (50, 6)
# window_id = 651
# shape = (50, 6)
# window_id = 652
# shape = (50, 6)
# window_id = 653
# shape = (50, 6)
# window_id = 654
# shape = (50, 6)
# window_id = 655
# shape = (50, 6)
# window_id = 656
# shape = (50, 6)
# window_id = 657
# shape = (50, 6)
# window_id = 658
# shape = (50, 6)
# window_id = 659
# shape = (50, 6)
# window_id = 660
# shape = (50, 6)
# window_id = 661
# shape = (50, 6)
# window_id = 662
# shape = (50, 6)
# window_id = 663
# shape = (50, 6)
# window_id = 664
# shape = (50, 6)
# window_id = 665
# shape = (50, 6)
# window_id = 666
# shape = (50, 6)
# window_id = 667
# shape = (50, 6)
# window_id = 668
# shape = (50, 6)
# window_id = 669
# shape = (50, 6)
# window_id = 670
# shape = (50, 6)
# window_id = 671
# shape = (50, 6)
# window_id = 672
# shape = (50, 6)
# window_id = 673
# shape = (50, 6)
# window_id = 674
# shape = (50, 6)
# window_id = 675
# shape = (50, 6)
# window_id = 676
# shape = (50, 6)
# window_id = 677
# shape = (50, 6)
# window_id = 678
# shape = (50, 6)
# window_id = 679
# shape = (50, 6)
# window_id = 680
# shape = (50, 6)
# window_id = 681
# shape = (50, 6)
# window_id = 682
# shape = (50, 6)
# window_id = 683
# shape = (50, 6)
# window_id = 684
# shape = (50, 6)
# window_id = 685
# shape = (50, 6)
# window_id = 686
# shape = (50, 6)
# window_id = 687
# shape = (50, 6)
# window_id = 688
# shape = (50, 6)
# window_id = 689
# shape = (50, 6)
# window_id = 690
# shape = (50, 6)
# window_id = 691
# shape = (50, 6)
# window_id = 692
# shape = (50, 6)
# window_id = 693
# shape = (50, 6)
# window_id = 694
# shape = (50, 6)
# window_id = 695
# shape = (50, 6)
# window_id = 696
# shape = (50, 6)
# window_id = 697
# shape = (50, 6)
# window_id = 698
# shape = (50, 6)
# window_id = 699
# shape = (50, 6)
# window_id = 700
# shape = (50, 6)
# window_id = 701
# shape = (50, 6)
# window_id = 702
# shape = (50, 6)
# window_id = 703
# shape = (50, 6)
# window_id = 704
# shape = (50, 6)
# window_id = 705
# shape = (50, 6)
# window_id = 706
# shape = (50, 6)
# window_id = 707
# shape = (50, 6)
# window_id = 708
# shape = (50, 6)
# window_id = 709
# shape = (50, 6)
# window_id = 710
# shape = (50, 6)
# window_id = 711
# shape = (50, 6)
# window_id = 712
# shape = (50, 6)
# window_id = 713
# shape = (50, 6)
# window_id = 714
# shape = (50, 6)
# window_id = 715
# shape = (50, 6)
# window_id = 716
# shape = (50, 6)
# window_id = 717
# shape = (50, 6)
# window_id = 718
# shape = (50, 6)
# window_id = 719
# shape = (50, 6)
# window_id = 720
# shape = (50, 6)
# window_id = 721
# shape = (50, 6)
# window_id = 722
# shape = (50, 6)
# window_id = 723
# shape = (50, 6)
# window_id = 724
# shape = (50, 6)
# window_id = 725
# shape = (50, 6)
# window_id = 726
# shape = (50, 6)
# window_id = 727
# shape = (50, 6)
# window_id = 728
# shape = (50, 6)
# window_id = 729
# shape = (50, 6)
# window_id = 730
# shape = (50, 6)
# window_id = 731
# shape = (50, 6)
# window_id = 732
# shape = (50, 6)
# window_id = 733
# shape = (50, 6)
# window_id = 734
# shape = (50, 6)
# window_id = 735
# shape = (50, 6)
# window_id = 736
# shape = (50, 6)
# window_id = 737
# shape = (50, 6)
# window_id = 738
# shape = (50, 6)
# window_id = 739
# shape = (50, 6)
# window_id = 740
# shape = (50, 6)
# window_id = 741
# shape = (50, 6)
# window_id = 742
# shape = (50, 6)
# window_id = 743
# shape = (50, 6)
# window_id = 744
# shape = (50, 6)
# window_id = 745
# shape = (50, 6)
# window_id = 746
# shape = (50, 6)
# window_id = 747
# shape = (50, 6)
# window_id = 748
# shape = (50, 6)
# window_id = 749
# shape = (50, 6)
# window_id = 750
# shape = (50, 6)
# window_id = 751
# shape = (50, 6)
# window_id = 752
# shape = (50, 6)
# window_id = 753
# shape = (50, 6)
# window_id = 754
# shape = (50, 6)
# window_id = 755
# shape = (50, 6)
# window_id = 756
# shape = (50, 6)
# window_id = 757
# shape = (50, 6)
# window_id = 758
# shape = (50, 6)
# window_id = 759
# shape = (50, 6)
# window_id = 760
# shape = (50, 6)
# window_id = 761
# shape = (50, 6)
# window_id = 762
# shape = (50, 6)
# window_id = 763
# shape = (50, 6)
# window_id = 764
# shape = (50, 6)
# window_id = 765
# shape = (50, 6)
# window_id = 766
# shape = (50, 6)
# window_id = 767
# shape = (50, 6)
# window_id = 768
# shape = (50, 6)
# window_id = 769
# shape = (50, 6)
# window_id = 770
# shape = (50, 6)
# window_id = 771
# shape = (50, 6)
# window_id = 772
# shape = (50, 6)
# window_id = 773
# shape = (50, 6)
# window_id = 774
# shape = (50, 6)
# window_id = 775
# shape = (50, 6)
# window_id = 776
# shape = (50, 6)
# window_id = 777
# shape = (50, 6)
# window_id = 778
# shape = (50, 6)
# window_id = 779
# shape = (50, 6)
# window_id = 780
# shape = (50, 6)
# window_id = 781
# shape = (50, 6)
# window_id = 782
# shape = (50, 6)
# window_id = 783
# shape = (50, 6)
# window_id = 784
# shape = (50, 6)
# window_id = 785
# shape = (50, 6)
# window_id = 786
# shape = (50, 6)
# window_id = 787
# shape = (50, 6)
# window_id = 788
# shape = (50, 6)
# window_id = 789
# shape = (50, 6)
# window_id = 790
# shape = (50, 6)
# window_id = 791
# shape = (50, 6)
# window_id = 792
# shape = (50, 6)
# window_id = 793
# shape = (50, 6)
# window_id = 794
# shape = (50, 6)
# window_id = 795
# shape = (50, 6)
# window_id = 796
# shape = (50, 6)
# window_id = 797
# shape = (50, 6)
# window_id = 798
# shape = (50, 6)
# window_id = 799
# shape = (50, 6)
# window_id = 800
# shape = (50, 6)
# window_id = 801
# shape = (50, 6)
# window_id = 802
# shape = (50, 6)
# window_id = 803
# shape = (50, 6)
# window_id = 804
# shape = (50, 6)
# window_id = 805
# shape = (50, 6)
# window_id = 806
# shape = (50, 6)
# window_id = 807
# shape = (50, 6)
# window_id = 808
# shape = (50, 6)
# window_id = 809
# shape = (50, 6)
# window_id = 810
# shape = (50, 6)
# window_id = 811
# shape = (50, 6)
# window_id = 812
# shape = (50, 6)
# window_id = 813
# shape = (50, 6)
# window_id = 814
# shape = (50, 6)
# window_id = 815
# shape = (50, 6)
# window_id = 816
# shape = (50, 6)
# window_id = 817
# shape = (50, 6)
# window_id = 818
# shape = (50, 6)
# window_id = 819
# shape = (50, 6)
# window_id = 820
# shape = (50, 6)
# window_id = 821
# shape = (50, 6)
# window_id = 822
# shape = (50, 6)
# window_id = 823
# shape = (50, 6)
# window_id = 824
# shape = (50, 6)
# window_id = 825
# shape = (50, 6)
# window_id = 826
# shape = (50, 6)
# window_id = 827
# shape = (50, 6)
# window_id = 828
# shape = (50, 6)
# window_id = 829
# shape = (50, 6)
# window_id = 830
# shape = (50, 6)
# window_id = 831
# shape = (50, 6)
# window_id = 832
# shape = (50, 6)
# window_id = 833
# shape = (50, 6)
# window_id = 834
# shape = (50, 6)
# window_id = 835
# shape = (50, 6)
# window_id = 836
# shape = (50, 6)
# window_id = 837
# shape = (50, 6)
# window_id = 838
# shape = (50, 6)
# window_id = 839
# shape = (50, 6)
# window_id = 840
# shape = (50, 6)
# window_id = 841
# shape = (50, 6)
# window_id = 842
# shape = (50, 6)
# window_id = 843
# shape = (50, 6)
# window_id = 844
# shape = (50, 6)
# window_id = 845
# shape = (50, 6)
# window_id = 846
# shape = (50, 6)
# window_id = 847
# shape = (50, 6)
# window_id = 848
# shape = (50, 6)
# window_id = 849
# shape = (50, 6)
# window_id = 850
# shape = (50, 6)
# window_id = 851
# shape = (50, 6)
# window_id = 852
# shape = (50, 6)
# window_id = 853
# shape = (50, 6)
# window_id = 854
# shape = (50, 6)
# window_id = 855
# shape = (50, 6)
# window_id = 856
# shape = (50, 6)
# window_id = 857
# shape = (50, 6)
# window_id = 858
# shape = (50, 6)
# window_id = 859
# shape = (50, 6)
# window_id = 860
# shape = (50, 6)
# window_id = 861
# shape = (50, 6)
# window_id = 862
# shape = (50, 6)
# window_id = 863
# shape = (50, 6)
# window_id = 864
# shape = (50, 6)
# window_id = 865
# shape = (50, 6)
# window_id = 866
# shape = (50, 6)
# window_id = 867
# shape = (50, 6)
# window_id = 868
# shape = (50, 6)
# window_id = 869
# shape = (50, 6)
# window_id = 870
# shape = (50, 6)
# window_id = 871
# shape = (50, 6)
# window_id = 872
# shape = (50, 6)
# window_id = 873
# shape = (50, 6)
# window_id = 874
# shape = (50, 6)
# window_id = 875
# shape = (50, 6)
# window_id = 876
# shape = (50, 6)
# window_id = 877
# shape = (50, 6)
# window_id = 878
# shape = (50, 6)
# window_id = 879
# shape = (50, 6)
# window_id = 880
# shape = (50, 6)
# window_id = 881
# shape = (50, 6)
# window_id = 882
# shape = (50, 6)
# window_id = 883
# shape = (50, 6)
# window_id = 884
# shape = (50, 6)
# window_id = 885
# shape = (50, 6)
# window_id = 886
# shape = (50, 6)
# window_id = 887
# shape = (50, 6)
# window_id = 888
# shape = (50, 6)
# window_id = 889
# shape = (50, 6)
# window_id = 890
# shape = (50, 6)
# window_id = 891
# shape = (50, 6)
# window_id = 892
# shape = (50, 6)
# window_id = 893
# shape = (50, 6)
# window_id = 894
# shape = (50, 6)
# window_id = 895
# shape = (50, 6)
# window_id = 896
# shape = (50, 6)
# window_id = 897
# shape = (50, 6)
# window_id = 898
# shape = (50, 6)
# window_id = 899
# shape = (50, 6)
# window_id = 900
# shape = (50, 6)
# window_id = 901
# shape = (50, 6)
# window_id = 902
# shape = (50, 6)
# window_id = 903
# shape = (50, 6)
# window_id = 904
# shape = (50, 6)
# window_id = 905
# shape = (50, 6)
# window_id = 906
# shape = (50, 6)
# window_id = 907
# shape = (50, 6)
# window_id = 908
# shape = (50, 6)
# window_id = 909
# shape = (50, 6)
# window_id = 910
# shape = (50, 6)
# window_id = 911
# shape = (50, 6)
# window_id = 912
# shape = (50, 6)
# window_id = 913
# shape = (50, 6)
# window_id = 914
# shape = (50, 6)
# window_id = 915
# shape = (50, 6)
# window_id = 916
# shape = (50, 6)
# window_id = 917
# shape = (50, 6)
# window_id = 918
# shape = (50, 6)
# window_id = 919
# shape = (50, 6)
# window_id = 920
# shape = (50, 6)
# window_id = 921
# shape = (50, 6)
# window_id = 922
# shape = (50, 6)
# window_id = 923
# shape = (50, 6)
# window_id = 924
# shape = (50, 6)
# window_id = 925
# shape = (50, 6)
# window_id = 926
# shape = (50, 6)
# window_id = 927
# shape = (50, 6)
# window_id = 928
# shape = (50, 6)
# window_id = 929
# shape = (50, 6)
# window_id = 930
# shape = (50, 6)
# window_id = 931
# shape = (50, 6)
# window_id = 932
# shape = (50, 6)
# window_id = 933
# shape = (50, 6)
# window_id = 934
# shape = (50, 6)
# window_id = 935
# shape = (50, 6)
# window_id = 936
# shape = (50, 6)
# window_id = 937
# shape = (50, 6)
# window_id = 938
# shape = (50, 6)
# window_id = 939
# shape = (50, 6)
# window_id = 940
# shape = (50, 6)
# window_id = 941
# shape = (50, 6)
# window_id = 942
# shape = (50, 6)
# window_id = 943
# shape = (50, 6)
# window_id = 944
# shape = (50, 6)
# window_id = 945
# shape = (50, 6)
# window_id = 946
# shape = (50, 6)
# window_id = 947
# shape = (50, 6)
# window_id = 948
# shape = (50, 6)
# window_id = 949
# shape = (50, 6)
# window_id = 950
# shape = (50, 6)
# window_id = 951
# shape = (50, 6)
# window_id = 952
# shape = (50, 6)
# window_id = 953
# shape = (50, 6)
# window_id = 954
# shape = (50, 6)
# window_id = 955
# shape = (50, 6)
# window_id = 956
# shape = (50, 6)
# window_id = 957
# shape = (50, 6)
# window_id = 958
# shape = (50, 6)
# window_id = 959
# shape = (50, 6)
# window_id = 960
# shape = (50, 6)
# window_id = 961
# shape = (50, 6)
# window_id = 962
# shape = (50, 6)
# window_id = 963
# shape = (50, 6)
# window_id = 964
# shape = (50, 6)
# window_id = 965
# shape = (50, 6)
# window_id = 966
# shape = (50, 6)
# window_id = 967
# shape = (50, 6)
# window_id = 968
# shape = (50, 6)
# window_id = 969
# shape = (50, 6)
# window_id = 970
# shape = (50, 6)
# window_id = 971
# shape = (50, 6)
# window_id = 972
# shape = (50, 6)
# window_id = 973
# shape = (50, 6)
# window_id = 974
# shape = (50, 6)
# window_id = 975
# shape = (50, 6)
# window_id = 976
# shape = (50, 6)
# window_id = 977
# shape = (50, 6)
# window_id = 978
# shape = (50, 6)
# window_id = 979
# shape = (50, 6)
# window_id = 980
# shape = (50, 6)
# window_id = 981
# shape = (50, 6)
# window_id = 982
# shape = (50, 6)
# window_id = 983
# shape = (50, 6)
# window_id = 984
# shape = (50, 6)
# window_id = 985
# shape = (50, 6)
# window_id = 986
# shape = (50, 6)
# window_id = 987
# shape = (50, 6)
# window_id = 988
# shape = (50, 6)
# window_id = 989
# shape = (50, 6)
# window_id = 990
# shape = (50, 6)
# window_id = 991
# shape = (50, 6)
# window_id = 992
# shape = (50, 6)
# window_id = 993
# shape = (50, 6)
# window_id = 994
# shape = (50, 6)
# window_id = 995
# shape = (50, 6)
# window_id = 996
# shape = (50, 6)
# window_id = 997
# shape = (50, 6)
# window_id = 998
# shape = (50, 6)
# window_id = 999
# shape = (50, 6)
# window_id = 1000
# shape = (50, 6)
# window_id = 1001
# shape = (50, 6)
# window_id = 1002
# shape = (50, 6)
# window_id = 1003
# shape = (50, 6)
# window_id = 1004
# shape = (50, 6)
# window_id = 1005
# shape = (50, 6)
# window_id = 1006
# shape = (50, 6)
# window_id = 1007
# shape = (50, 6)
# window_id = 1008
# shape = (50, 6)
# window_id = 1009
# shape = (50, 6)
# window_id = 1010
# shape = (50, 6)
# window_id = 1011
# shape = (50, 6)
# window_id = 1012
# shape = (50, 6)
# window_id = 1013
# shape = (50, 6)
# window_id = 1014
# shape = (50, 6)
# window_id = 1015
# shape = (50, 6)
# window_id = 1016
# shape = (50, 6)
# window_id = 1017
# shape = (50, 6)
# window_id = 1018
# shape = (50, 6)
# window_id = 1019
# shape = (50, 6)
# window_id = 1020
# shape = (50, 6)
# window_id = 1021
# shape = (50, 6)
# window_id = 1022
# shape = (50, 6)
# window_id = 1023
# shape = (50, 6)
# window_id = 1024
# shape = (50, 6)
# window_id = 1025
# shape = (50, 6)
# window_id = 1026
# shape = (50, 6)
# window_id = 1027
# shape = (50, 6)
# window_id = 1028
# shape = (50, 6)
# window_id = 1029
# shape = (50, 6)
# window_id = 1030
# shape = (50, 6)
# window_id = 1031
# shape = (50, 6)
# window_id = 1032
# shape = (50, 6)
# window_id = 1033
# shape = (50, 6)
# window_id = 1034
# shape = (50, 6)
# window_id = 1035
# shape = (50, 6)
# window_id = 1036
# shape = (50, 6)
# window_id = 1037
# shape = (50, 6)
# window_id = 1038
# shape = (50, 6)
# window_id = 1039
# shape = (50, 6)
# window_id = 1040
# shape = (50, 6)
# window_id = 1041
# shape = (50, 6)
# window_id = 1042
# shape = (50, 6)
# window_id = 1043
# shape = (50, 6)
# window_id = 1044
# shape = (50, 6)
# window_id = 1045
# shape = (50, 6)
# window_id = 1046
# shape = (50, 6)
# window_id = 1047
# shape = (50, 6)
# window_id = 1048
# shape = (50, 6)
# window_id = 1049
# shape = (50, 6)
# window_id = 1050
# shape = (50, 6)
# window_id = 1051
# shape = (50, 6)
# window_id = 1052
# shape = (50, 6)
# window_id = 1053
# shape = (50, 6)
# window_id = 1054
# shape = (50, 6)
# window_id = 1055
# shape = (50, 6)
# window_id = 1056
# shape = (50, 6)
# window_id = 1057
# shape = (50, 6)
# window_id = 1058
# shape = (50, 6)
# window_id = 1059
# shape = (50, 6)
# window_id = 1060
# shape = (50, 6)
# window_id = 1061
# shape = (50, 6)
# window_id = 1062
# shape = (50, 6)
# window_id = 1063
# shape = (50, 6)
# window_id = 1064
# shape = (50, 6)
# window_id = 1065
# shape = (50, 6)
# window_id = 1066
# shape = (50, 6)
# window_id = 1067
# shape = (50, 6)
# window_id = 1068
# shape = (50, 6)
# window_id = 1069
# shape = (50, 6)
# window_id = 1070
# shape = (50, 6)
# window_id = 1071
# shape = (50, 6)
# window_id = 1072
# shape = (50, 6)
# window_id = 1073
# shape = (50, 6)
# window_id = 1074
# shape = (50, 6)
# window_id = 1075
# shape = (50, 6)
# window_id = 1076
# shape = (50, 6)
# window_id = 1077
# shape = (50, 6)
# window_id = 1078
# shape = (50, 6)
# window_id = 1079
# shape = (50, 6)
# window_id = 1080
# shape = (50, 6)
# window_id = 1081
# shape = (50, 6)
# window_id = 1082
# shape = (50, 6)
# window_id = 1083
# shape = (50, 6)
# window_id = 1084
# shape = (50, 6)
# window_id = 1085
# shape = (50, 6)
# window_id = 1086
# shape = (50, 6)
# window_id = 1087
# shape = (50, 6)
# window_id = 1088
# shape = (50, 6)
# window_id = 1089
# shape = (50, 6)
# window_id = 1090
# shape = (50, 6)
# window_id = 1091
# shape = (50, 6)
# window_id = 1092
# shape = (50, 6)
# window_id = 1093
# shape = (50, 6)
# window_id = 1094
# shape = (50, 6)
# window_id = 1095
# shape = (50, 6)
# window_id = 1096
# shape = (50, 6)
# window_id = 1097
# shape = (50, 6)
# window_id = 1098
# shape = (50, 6)
# window_id = 1099
# shape = (50, 6)
# window_id = 1100
# shape = (50, 6)
# window_id = 1101
# shape = (50, 6)
# window_id = 1102
# shape = (50, 6)
# window_id = 1103
# shape = (50, 6)
# window_id = 1104
# shape = (50, 6)
# window_id = 1105
# shape = (50, 6)
# window_id = 1106
# shape = (50, 6)
# window_id = 1107
# shape = (50, 6)
# window_id = 1108
# shape = (50, 6)
# window_id = 1109
# shape = (50, 6)
# window_id = 1110
# shape = (50, 6)
# window_id = 1111
# shape = (50, 6)
# window_id = 1112
# shape = (50, 6)
# window_id = 1113
# shape = (50, 6)
# window_id = 1114
# shape = (50, 6)
# window_id = 1115
# shape = (50, 6)
# window_id = 1116
# shape = (50, 6)
# window_id = 1117
# shape = (50, 6)
# window_id = 1118
# shape = (50, 6)
# window_id = 1119
# shape = (50, 6)
# window_id = 1120
# shape = (50, 6)
# window_id = 1121
# shape = (50, 6)
# window_id = 1122
# shape = (50, 6)
# window_id = 1123
# shape = (50, 6)
# window_id = 1124
# shape = (50, 6)
# window_id = 1125
# shape = (50, 6)
# window_id = 1126
# shape = (50, 6)
# window_id = 1127
# shape = (50, 6)
# window_id = 1128
# shape = (50, 6)
# window_id = 1129
# shape = (50, 6)
# window_id = 1130
# shape = (50, 6)
# window_id = 1131
# shape = (50, 6)
# window_id = 1132
# shape = (50, 6)
# window_id = 1133
# shape = (50, 6)
# window_id = 1134
# shape = (50, 6)
# window_id = 1135
# shape = (50, 6)
# window_id = 1136
# shape = (50, 6)
# window_id = 1137
# shape = (50, 6)
# window_id = 1138
# shape = (50, 6)
# window_id = 1139
# shape = (50, 6)
# window_id = 1140
# shape = (50, 6)
# window_id = 1141
# shape = (50, 6)
# window_id = 1142
# shape = (50, 6)
# window_id = 1143
# shape = (50, 6)
# window_id = 1144
# shape = (50, 6)
# window_id = 1145
# shape = (50, 6)
# window_id = 1146
# shape = (50, 6)
# window_id = 1147
# shape = (50, 6)
# window_id = 1148
# shape = (50, 6)
# window_id = 1149
# shape = (50, 6)
# window_id = 1150
# shape = (50, 6)
# window_id = 1151
# shape = (50, 6)
# window_id = 1152
# shape = (50, 6)
# window_id = 1153
# shape = (50, 6)
# window_id = 1154
# shape = (50, 6)
# window_id = 1155
# shape = (50, 6)
# window_id = 1156
# shape = (50, 6)
# window_id = 1157
# shape = (50, 6)
# window_id = 1158
# shape = (50, 6)
# window_id = 1159
# shape = (50, 6)
# window_id = 1160
# shape = (50, 6)
# window_id = 1161
# shape = (50, 6)
# window_id = 1162
# shape = (50, 6)
# window_id = 1163
# shape = (50, 6)
# window_id = 1164
# shape = (50, 6)
# window_id = 1165
# shape = (50, 6)
# window_id = 1166
# shape = (50, 6)
# window_id = 1167
# shape = (50, 6)
# window_id = 1168
# shape = (50, 6)
# window_id = 1169
# shape = (50, 6)
# window_id = 1170
# shape = (50, 6)
# window_id = 1171
# shape = (50, 6)
# window_id = 1172
# shape = (50, 6)
# window_id = 1173
# shape = (50, 6)
# window_id = 1174
# shape = (50, 6)
# window_id = 1175
# shape = (50, 6)
# window_id = 1176
# shape = (50, 6)
# window_id = 1177
# shape = (50, 6)
# window_id = 1178
# shape = (50, 6)
# window_id = 1179
# shape = (50, 6)
# window_id = 1180
# shape = (50, 6)
# window_id = 1181
# shape = (50, 6)
# window_id = 1182
# shape = (50, 6)
# window_id = 1183
# shape = (50, 6)
# window_id = 1184
# shape = (50, 6)
# window_id = 1185
# shape = (50, 6)
# window_id = 1186
# shape = (50, 6)
# window_id = 1187
# shape = (50, 6)
# window_id = 1188
# shape = (50, 6)
# window_id = 1189
# shape = (50, 6)
# window_id = 1190
# shape = (50, 6)
# window_id = 1191
# shape = (50, 6)
# window_id = 1192
# shape = (50, 6)
# window_id = 1193
# shape = (50, 6)
# window_id = 1194
# shape = (50, 6)
# window_id = 1195
# shape = (50, 6)
# window_id = 1196
# shape = (50, 6)
# window_id = 1197
# shape = (50, 6)
# window_id = 1198
# shape = (50, 6)
# window_id = 1199
# shape = (50, 6)
# window_id = 1200
# shape = (50, 6)
# window_id = 1201
# shape = (50, 6)
# window_id = 1202
# shape = (50, 6)
# window_id = 1203
# shape = (50, 6)
# window_id = 1204
# shape = (50, 6)
# window_id = 1205
# shape = (50, 6)
# window_id = 1206
# shape = (50, 6)
# window_id = 1207
# shape = (50, 6)
# window_id = 1208
# shape = (50, 6)
# window_id = 1209
# shape = (50, 6)
# window_id = 1210
# shape = (50, 6)
# window_id = 1211
# shape = (50, 6)
# window_id = 1212
# shape = (50, 6)
# window_id = 1213
# shape = (50, 6)
# window_id = 1214
# shape = (50, 6)
# window_id = 1215
# shape = (50, 6)
# window_id = 1216
# shape = (50, 6)
# window_id = 1217
# shape = (50, 6)
# window_id = 1218
# shape = (50, 6)
# window_id = 1219
# shape = (50, 6)
# window_id = 1220
# shape = (50, 6)
# window_id = 1221
# shape = (50, 6)
# window_id = 1222
# shape = (50, 6)
# window_id = 1223
# shape = (50, 6)
# window_id = 1224
# shape = (50, 6)
# window_id = 1225
# shape = (50, 6)
# window_id = 1226
# shape = (50, 6)
# window_id = 1227
# shape = (50, 6)
# window_id = 1228
# shape = (50, 6)
# window_id = 1229
# shape = (50, 6)
# window_id = 1230
# shape = (50, 6)
# window_id = 1231
# shape = (50, 6)
# window_id = 1232
# shape = (50, 6)
# window_id = 1233
# shape = (50, 6)
# window_id = 1234
# shape = (50, 6)
# window_id = 1235
# shape = (50, 6)
# window_id = 1236
# shape = (50, 6)
# window_id = 1237
# shape = (50, 6)
# window_id = 1238
# shape = (50, 6)
# window_id = 1239
# shape = (50, 6)
# window_id = 1240
# shape = (50, 6)
# window_id = 1241
# shape = (50, 6)
# window_id = 1242
# shape = (50, 6)
# window_id = 1243
# shape = (50, 6)
# window_id = 1244
# shape = (50, 6)
# window_id = 1245
# shape = (50, 6)
# window_id = 1246
# shape = (50, 6)
# window_id = 1247
# shape = (50, 6)
# window_id = 1248
# shape = (50, 6)
# window_id = 1249
# shape = (50, 6)
# window_id = 1250
# shape = (50, 6)
# window_id = 1251
# shape = (50, 6)
# window_id = 1252
# shape = (50, 6)
# window_id = 1253
# shape = (50, 6)
# window_id = 1254
# shape = (50, 6)
# window_id = 1255
# shape = (50, 6)
# window_id = 1256
# shape = (50, 6)
# window_id = 1257
# shape = (50, 6)
# window_id = 1258
# shape = (50, 6)
# window_id = 1259
# shape = (50, 6)
# window_id = 1260
# shape = (50, 6)
# window_id = 1261
# shape = (50, 6)
# window_id = 1262
# shape = (50, 6)
# window_id = 1263
# shape = (50, 6)
# window_id = 1264
# shape = (50, 6)
# window_id = 1265
# shape = (50, 6)
# window_id = 1266
# shape = (50, 6)
# window_id = 1267
# shape = (50, 6)
# window_id = 1268
# shape = (50, 6)
# window_id = 1269
# shape = (50, 6)
# window_id = 1270
# shape = (50, 6)
# window_id = 1271
# shape = (50, 6)
# window_id = 1272
# shape = (50, 6)
# window_id = 1273
# shape = (50, 6)
# window_id = 1274
# shape = (50, 6)
# window_id = 1275
# shape = (50, 6)
# window_id = 1276
# shape = (50, 6)
# window_id = 1277
# shape = (50, 6)
# window_id = 1278
# shape = (50, 6)
# window_id = 1279
# shape = (50, 6)
# window_id = 1280
# shape = (50, 6)
# window_id = 1281
# shape = (50, 6)
# window_id = 1282
# shape = (50, 6)
# window_id = 1283
# shape = (50, 6)
# window_id = 1284
# shape = (50, 6)
# window_id = 1285
# shape = (50, 6)
# window_id = 1286
# shape = (50, 6)
# window_id = 1287
# shape = (50, 6)
# window_id = 1288
# shape = (50, 6)
# window_id = 1289
# shape = (50, 6)
# window_id = 1290
# shape = (50, 6)
# window_id = 1291
# shape = (50, 6)
# window_id = 1292
# shape = (50, 6)
# window_id = 1293
# shape = (50, 6)
# window_id = 1294
# shape = (50, 6)
# window_id = 1295
# shape = (50, 6)
# window_id = 1296
# shape = (50, 6)
# window_id = 1297
# shape = (50, 6)
# window_id = 1298
# shape = (50, 6)
# window_id = 1299
# shape = (50, 6)
# window_id = 1300
# shape = (50, 6)
# window_id = 1301
# shape = (50, 6)
# window_id = 1302
# shape = (50, 6)
# window_id = 1303
# shape = (50, 6)
# window_id = 1304
# shape = (50, 6)
# window_id = 1305
# shape = (50, 6)
# window_id = 1306
# shape = (50, 6)
# window_id = 1307
# shape = (50, 6)
# window_id = 1308
# shape = (50, 6)
# window_id = 1309
# shape = (50, 6)
# window_id = 1310
# shape = (50, 6)
# window_id = 1311
# shape = (50, 6)
# window_id = 1312
# shape = (50, 6)
# window_id = 1313
# shape = (50, 6)
# window_id = 1314
# shape = (50, 6)
# window_id = 1315
# shape = (50, 6)
# window_id = 1316
# shape = (50, 6)
# window_id = 1317
# shape = (50, 6)
# window_id = 1318
# shape = (50, 6)
# window_id = 1319
# shape = (50, 6)
# window_id = 1320
# shape = (50, 6)
# window_id = 1321
# shape = (50, 6)
# window_id = 1322
# shape = (50, 6)
# window_id = 1323
# shape = (50, 6)
# window_id = 1324
# shape = (50, 6)
# window_id = 1325
# shape = (50, 6)
# window_id = 1326
# shape = (50, 6)
# window_id = 1327
# shape = (50, 6)
# window_id = 1328
# shape = (50, 6)
# window_id = 1329
# shape = (50, 6)
# window_id = 1330
# shape = (50, 6)
# window_id = 1331
# shape = (50, 6)
# window_id = 1332
# shape = (50, 6)
# window_id = 1333
# shape = (50, 6)
# window_id = 1334
# shape = (50, 6)
# window_id = 1335
# shape = (50, 6)
# window_id = 1336
# shape = (50, 6)
# window_id = 1337
# shape = (50, 6)
# window_id = 1338
# shape = (50, 6)
# window_id = 1339
# shape = (50, 6)
# window_id = 1340
# shape = (50, 6)
# window_id = 1341
# shape = (50, 6)
# window_id = 1342
# shape = (50, 6)
# window_id = 1343
# shape = (50, 6)
# window_id = 1344
# shape = (50, 6)
# window_id = 1345
# shape = (50, 6)
# window_id = 1346
# shape = (50, 6)
# window_id = 1347
# shape = (50, 6)
# window_id = 1348
# shape = (50, 6)
# window_id = 1349
# shape = (50, 6)
# window_id = 1350
# shape = (50, 6)
# window_id = 1351
# shape = (50, 6)
# window_id = 1352
# shape = (50, 6)
# window_id = 1353
# shape = (50, 6)
# window_id = 1354
# shape = (50, 6)
# window_id = 1355
# shape = (50, 6)
# window_id = 1356
# shape = (50, 6)
# window_id = 1357
# shape = (50, 6)
# window_id = 1358
# shape = (50, 6)
# window_id = 1359
# shape = (50, 6)
# window_id = 1360
# shape = (50, 6)
# window_id = 1361
# shape = (50, 6)
# window_id = 1362
# shape = (50, 6)
# window_id = 1363
# shape = (50, 6)
# window_id = 1364
# shape = (50, 6)
# window_id = 1365
# shape = (50, 6)
# window_id = 1366
# shape = (50, 6)
# window_id = 1367
# shape = (50, 6)
# window_id = 1368
# shape = (50, 6)
# window_id = 1369
# shape = (50, 6)
# window_id = 1370
# shape = (50, 6)
# window_id = 1371
# shape = (50, 6)
# window_id = 1372
# shape = (50, 6)
# window_id = 1373
# shape = (50, 6)
# window_id = 1374
# shape = (50, 6)
# window_id = 1375
# shape = (50, 6)
# window_id = 1376
# shape = (50, 6)
# window_id = 1377
# shape = (50, 6)
# window_id = 1378
# shape = (50, 6)
# window_id = 1379
# shape = (50, 6)
# window_id = 1380
# shape = (50, 6)
# window_id = 1381
# shape = (50, 6)
# window_id = 1382
# shape = (50, 6)
# window_id = 1383
# shape = (50, 6)
# window_id = 1384
# shape = (50, 6)
# window_id = 1385
# shape = (50, 6)
# window_id = 1386
# shape = (50, 6)
# window_id = 1387
# shape = (50, 6)
# window_id = 1388
# shape = (50, 6)
# window_id = 1389
# shape = (50, 6)
# window_id = 1390
# shape = (50, 6)
# window_id = 1391
# shape = (50, 6)
# window_id = 1392
# shape = (50, 6)
# window_id = 1393
# shape = (50, 6)
# window_id = 1394
# shape = (50, 6)
# window_id = 1395
# shape = (50, 6)
# window_id = 1396
# shape = (50, 6)
# window_id = 1397
# shape = (50, 6)
# window_id = 1398
# shape = (50, 6)
# window_id = 1399
# shape = (50, 6)
# window_id = 1400
# shape = (50, 6)
# window_id = 1401
# shape = (50, 6)
# window_id = 1402
# shape = (50, 6)
# window_id = 1403
# shape = (50, 6)
# window_id = 1404
# shape = (50, 6)
# window_id = 1405
# shape = (50, 6)
# window_id = 1406
# shape = (50, 6)
# window_id = 1407
# shape = (50, 6)
# window_id = 1408
# shape = (50, 6)
# window_id = 1409
# shape = (50, 6)
# window_id = 1410
# shape = (50, 6)
# window_id = 1411
# shape = (50, 6)
# window_id = 1412
# shape = (50, 6)
# window_id = 1413
# shape = (50, 6)
# window_id = 1414
# shape = (50, 6)
# window_id = 1415
# shape = (50, 6)
# window_id = 1416
# shape = (50, 6)
# window_id = 1417
# shape = (50, 6)
# window_id = 1418
# shape = (50, 6)
# window_id = 1419
# shape = (50, 6)
# window_id = 1420
# shape = (50, 6)
# window_id = 1421
# shape = (50, 6)
# window_id = 1422
# shape = (50, 6)
# window_id = 1423
# shape = (50, 6)
# window_id = 1424
# shape = (50, 6)
# window_id = 1425
# shape = (50, 6)
# window_id = 1426
# shape = (50, 6)
# window_id = 1427
# shape = (50, 6)
# window_id = 1428
# shape = (50, 6)
# window_id = 1429
# shape = (50, 6)
# window_id = 1430
# shape = (50, 6)
# window_id = 1431
# shape = (50, 6)
# window_id = 1432
# shape = (50, 6)
# window_id = 1433
# shape = (50, 6)
# window_id = 1434
# shape = (50, 6)
# window_id = 1435
# shape = (50, 6)
# window_id = 1436
# shape = (50, 6)
# window_id = 1437
# shape = (50, 6)
# window_id = 1438
# shape = (50, 6)
# window_id = 1439
# shape = (50, 6)
# window_id = 1440
# shape = (50, 6)
# window_id = 1441
# shape = (50, 6)
# window_id = 1442
# shape = (50, 6)
# window_id = 1443
# shape = (50, 6)
# window_id = 1444
# shape = (50, 6)
# window_id = 1445
# shape = (50, 6)
# window_id = 1446
# shape = (50, 6)
# window_id = 1447
# shape = (50, 6)
# window_id = 1448
# shape = (50, 6)
# window_id = 1449
# shape = (50, 6)
# window_id = 1450
# shape = (50, 6)
# window_id = 1451
# shape = (50, 6)
# window_id = 1452
# shape = (50, 6)
# window_id = 1453
# shape = (50, 6)
# window_id = 1454
# shape = (50, 6)
# window_id = 1455
# shape = (50, 6)
# window_id = 1456
# shape = (50, 6)
# window_id = 1457
# shape = (50, 6)
# window_id = 1458
# shape = (50, 6)
# window_id = 1459
# shape = (50, 6)
# window_id = 1460
# shape = (50, 6)
# window_id = 1461
# shape = (50, 6)
# window_id = 1462
# shape = (50, 6)
# window_id = 1463
# shape = (50, 6)
# window_id = 1464
# shape = (50, 6)
# window_id = 1465
# shape = (50, 6)
# window_id = 1466
# shape = (50, 6)
# window_id = 1467
# shape = (50, 6)
# window_id = 1468
# shape = (50, 6)
# window_id = 1469
# shape = (50, 6)
# window_id = 1470
# shape = (50, 6)
# window_id = 1471
# shape = (50, 6)
# window_id = 1472
# shape = (50, 6)
# window_id = 1473
# shape = (50, 6)
# window_id = 1474
# shape = (50, 6)
# window_id = 1475
# shape = (50, 6)
# window_id = 1476
# shape = (50, 6)
# window_id = 1477
# shape = (50, 6)
# window_id = 1478
# shape = (50, 6)
# window_id = 1479
# shape = (50, 6)
# window_id = 1480
# shape = (50, 6)
# window_id = 1481
# shape = (50, 6)
# window_id = 1482
# shape = (50, 6)
# window_id = 1483
# shape = (50, 6)
# window_id = 1484
# shape = (50, 6)
# window_id = 1485
# shape = (50, 6)
# window_id = 1486
# shape = (50, 6)
# window_id = 1487
# shape = (50, 6)
# ...
# shape = (50, 6)
# window_id = 14144
# shape = (50, 6)
# window_id = 14145
# shape = (50, 6)
# window_id = 14146
# shape = (50, 6)
# window_id = 14147
# shape = (50, 6)
# window_id = 14148
# shape = (50, 6)
# window_id = 14149
# shape = (50, 6)
# window_id = 14150
# shape = (50, 6)
# window_id = 14151
# shape = (50, 6)
# window_id = 14152
# shape = (50, 6)
# window_id = 14153
# shape = (50, 6)
# window_id = 14154
# shape = (50, 6)
# window_id = 14155
# shape = (50, 6)
# window_id = 14156
# shape = (50, 6)
# window_id = 14157
# shape = (50, 6)
# window_id = 14158
# shape = (50, 6)
# window_id = 14159
# shape = (50, 6)
# window_id = 14160
# shape = (50, 6)
# window_id = 14161
# shape = (50, 6)
# window_id = 14162
# shape = (50, 6)
# window_id = 14163
# shape = (50, 6)
# window_id = 14164
# shape = (50, 6)
# window_id = 14165
# shape = (50, 6)
# window_id = 14166
# shape = (50, 6)
# window_id = 14167
# shape = (50, 6)
# window_id = 14168
# shape = (50, 6)
# window_id = 14169
# shape = (50, 6)
# window_id = 14170
# shape = (50, 6)
# window_id = 14171
# shape = (50, 6)
# window_id = 14172
# shape = (50, 6)
# window_id = 14173
# shape = (50, 6)
# window_id = 14174
# shape = (50, 6)
# window_id = 14175
# shape = (50, 6)
# window_id = 14176
# shape = (50, 6)
# window_id = 14177
# shape = (50, 6)
# window_id = 14178
# shape = (50, 6)
# window_id = 14179
# shape = (50, 6)
# window_id = 14180
# shape = (50, 6)
# window_id = 14181
# shape = (50, 6)
# window_id = 14182
# shape = (50, 6)
# window_id = 14183
# shape = (50, 6)
# window_id = 14184
# shape = (50, 6)
# window_id = 14185
# shape = (50, 6)
# window_id = 14186
# shape = (50, 6)
# window_id = 14187
# shape = (50, 6)
# window_id = 14188
# shape = (50, 6)
# window_id = 14189
# shape = (50, 6)
# window_id = 14190
# shape = (50, 6)
# window_id = 14191
# shape = (50, 6)
# window_id = 14192
# shape = (50, 6)
# window_id = 14193
# shape = (50, 6)
# window_id = 14194
# shape = (50, 6)
# window_id = 14195
# shape = (50, 6)
# window_id = 14196
# shape = (50, 6)
# window_id = 14197
# shape = (50, 6)
# window_id = 14198
# shape = (50, 6)
# window_id = 14199
# shape = (50, 6)
# window_id = 14200
# shape = (50, 6)
# window_id = 14201
# shape = (50, 6)
# window_id = 14202
# shape = (50, 6)
# window_id = 14203
# shape = (50, 6)
# window_id = 14204
# shape = (50, 6)
# window_id = 14205
# shape = (50, 6)
# window_id = 14206
# shape = (50, 6)
# window_id = 14207
# shape = (50, 6)
# window_id = 14208
# shape = (50, 6)
# window_id = 14209
# shape = (50, 6)
# window_id = 14210
# shape = (50, 6)
# window_id = 14211
# shape = (50, 6)
# window_id = 14212
# shape = (50, 6)
# window_id = 14213
# shape = (50, 6)
# window_id = 14214
# shape = (50, 6)
# window_id = 14215
# shape = (50, 6)
# window_id = 14216
# shape = (50, 6)
# window_id = 14217
# shape = (50, 6)
# window_id = 14218
# shape = (50, 6)
# window_id = 14219
# shape = (50, 6)
# window_id = 14220
# shape = (50, 6)
# window_id = 14221
# shape = (50, 6)
# window_id = 14222
# shape = (50, 6)
# window_id = 14223
# shape = (50, 6)
# window_id = 14224
# shape = (50, 6)
# window_id = 14225
# shape = (50, 6)
# window_id = 14226
# shape = (50, 6)
# window_id = 14227
# shape = (50, 6)
# window_id = 14228
# shape = (50, 6)
# window_id = 14229
# shape = (50, 6)
# window_id = 14230
# shape = (50, 6)
# window_id = 14231
# shape = (50, 6)
# window_id = 14232
# shape = (50, 6)
# window_id = 14233
# shape = (50, 6)
# window_id = 14234
# shape = (50, 6)
# window_id = 14235
# shape = (50, 6)
# window_id = 14236
# shape = (50, 6)
# window_id = 14237
# shape = (50, 6)
# window_id = 14238
# shape = (50, 6)
# window_id = 14239
# shape = (50, 6)
# window_id = 14240
# shape = (50, 6)
# window_id = 14241
# shape = (50, 6)
# window_id = 14242
# shape = (50, 6)
# window_id = 14243
# shape = (50, 6)
# window_id = 14244
# shape = (50, 6)
# window_id = 14245
# shape = (50, 6)
# window_id = 14246
# shape = (50, 6)
# window_id = 14247
# shape = (50, 6)
# window_id = 14248
# shape = (50, 6)
# window_id = 14249
# shape = (50, 6)
# window_id = 14250
# shape = (50, 6)
# window_id = 14251
# shape = (50, 6)
# window_id = 14252
# shape = (50, 6)
# window_id = 14253
# shape = (50, 6)
# window_id = 14254
# shape = (50, 6)
# window_id = 14255
# shape = (50, 6)
# window_id = 14256
# shape = (50, 6)
# window_id = 14257
# shape = (50, 6)
# window_id = 14258
# shape = (50, 6)
# window_id = 14259
# shape = (50, 6)
# window_id = 14260
# shape = (50, 6)
# window_id = 14261
# shape = (50, 6)
# window_id = 14262
# shape = (50, 6)
# window_id = 14263
# shape = (50, 6)
# window_id = 14264
# shape = (50, 6)
# window_id = 14265
# shape = (50, 6)
# window_id = 14266
# shape = (50, 6)
# window_id = 14267
# shape = (50, 6)
# window_id = 14268
# shape = (50, 6)
# window_id = 14269
# shape = (50, 6)
# window_id = 14270
# shape = (50, 6)
# window_id = 14271
# shape = (50, 6)
# window_id = 14272
# shape = (50, 6)
# window_id = 14273
# shape = (50, 6)
# window_id = 14274
# shape = (50, 6)
# window_id = 14275
# shape = (50, 6)
# window_id = 14276
# shape = (50, 6)
# window_id = 14277
# shape = (50, 6)
# window_id = 14278
# shape = (50, 6)
# window_id = 14279
# shape = (50, 6)
# window_id = 14280
# shape = (50, 6)
# window_id = 14281
# shape = (50, 6)
# window_id = 14282
# shape = (50, 6)
# window_id = 14283
# shape = (50, 6)
# window_id = 14284
# shape = (50, 6)
# window_id = 14285
# shape = (50, 6)
# window_id = 14286
# shape = (50, 6)
# window_id = 14287
# shape = (50, 6)
# window_id = 14288
# shape = (50, 6)
# window_id = 14289
# shape = (50, 6)
# window_id = 14290
# shape = (50, 6)
# window_id = 14291
# shape = (50, 6)
# window_id = 14292
# shape = (50, 6)
# window_id = 14293
# shape = (50, 6)
# window_id = 14294
# shape = (50, 6)
# window_id = 14295
# shape = (50, 6)
# window_id = 14296
# shape = (50, 6)
# window_id = 14297
# shape = (50, 6)
# window_id = 14298
# shape = (50, 6)
# window_id = 14299
# shape = (50, 6)
# window_id = 14300
# shape = (50, 6)
# window_id = 14301
# shape = (50, 6)
# window_id = 14302
# shape = (50, 6)
# window_id = 14303
# shape = (50, 6)
# window_id = 14304
# shape = (50, 6)
# window_id = 14305
# shape = (50, 6)
# window_id = 14306
# shape = (50, 6)
# window_id = 14307
# shape = (50, 6)
# window_id = 14308
# shape = (50, 6)
# window_id = 14309
# shape = (50, 6)
# window_id = 14310
# shape = (50, 6)
# window_id = 14311
# shape = (50, 6)
# window_id = 14312
# shape = (50, 6)
# window_id = 14313
# shape = (50, 6)
# window_id = 14314
# shape = (50, 6)
# window_id = 14315
# shape = (50, 6)
# window_id = 14316
# shape = (50, 6)
# window_id = 14317
# shape = (50, 6)
# window_id = 14318
# shape = (50, 6)
# window_id = 14319
# shape = (50, 6)
# window_id = 14320
# shape = (50, 6)
# window_id = 14321
# shape = (50, 6)
# window_id = 14322
# shape = (50, 6)
# window_id = 14323
# shape = (50, 6)
# window_id = 14324
# shape = (50, 6)
# window_id = 14325
# shape = (50, 6)
# window_id = 14326
# shape = (50, 6)
# window_id = 14327
# shape = (50, 6)
# window_id = 14328
# shape = (50, 6)
# window_id = 14329
# shape = (50, 6)
# window_id = 14330
# shape = (50, 6)
# window_id = 14331
# shape = (50, 6)
# window_id = 14332
# shape = (50, 6)
# window_id = 14333
# shape = (50, 6)
# window_id = 14334
# shape = (50, 6)
# window_id = 14335
# shape = (50, 6)
# window_id = 14336
# shape = (50, 6)
# window_id = 14337
# shape = (50, 6)
# window_id = 14338
# shape = (50, 6)
# window_id = 14339
# shape = (50, 6)
# window_id = 14340
# shape = (50, 6)
# window_id = 14341
# shape = (50, 6)
# window_id = 14342
# shape = (50, 6)
# window_id = 14343
# shape = (50, 6)
# window_id = 14344
# shape = (50, 6)
# window_id = 14345
# shape = (50, 6)
# window_id = 14346
# shape = (50, 6)
# window_id = 14347
# shape = (50, 6)
# window_id = 14348
# shape = (50, 6)
# window_id = 14349
# shape = (50, 6)
# window_id = 14350
# shape = (50, 6)
# window_id = 14351
# shape = (50, 6)
# window_id = 14352
# shape = (50, 6)
# window_id = 14353
# shape = (50, 6)
# window_id = 14354
# shape = (50, 6)
# window_id = 14355
# shape = (50, 6)
# window_id = 14356
# shape = (50, 6)
# window_id = 14357
# shape = (50, 6)
# window_id = 14358
# shape = (50, 6)
# window_id = 14359
# shape = (50, 6)
# window_id = 14360
# shape = (50, 6)
# window_id = 14361
# shape = (50, 6)
# window_id = 14362
# shape = (50, 6)
# window_id = 14363
# shape = (50, 6)
# window_id = 14364
# shape = (50, 6)
# window_id = 14365
# shape = (50, 6)
# window_id = 14366
# shape = (50, 6)
# window_id = 14367
# shape = (50, 6)
# window_id = 14368
# shape = (50, 6)
# window_id = 14369
# shape = (50, 6)
# window_id = 14370
# shape = (50, 6)
# window_id = 14371
# shape = (50, 6)
# window_id = 14372
# shape = (50, 6)
# window_id = 14373
# shape = (50, 6)
# window_id = 14374
# shape = (50, 6)
# window_id = 14375
# shape = (50, 6)
# window_id = 14376
# shape = (50, 6)
# window_id = 14377
# shape = (50, 6)
# window_id = 14378
# shape = (50, 6)
# window_id = 14379
# shape = (50, 6)
# window_id = 14380
# shape = (50, 6)
# window_id = 14381
# shape = (50, 6)
# window_id = 14382
# shape = (50, 6)
# window_id = 14383
# shape = (50, 6)
# window_id = 14384
# shape = (50, 6)
# window_id = 14385
# shape = (50, 6)
# window_id = 14386
# shape = (50, 6)
# window_id = 14387
# shape = (50, 6)
# window_id = 14388
# shape = (50, 6)
# window_id = 14389
# shape = (50, 6)
# window_id = 14390
# shape = (50, 6)
# window_id = 14391
# shape = (50, 6)
# window_id = 14392
# shape = (50, 6)
# window_id = 14393
# shape = (50, 6)
# window_id = 14394
# shape = (50, 6)
# window_id = 14395
# shape = (50, 6)
# window_id = 14396
# shape = (50, 6)
# window_id = 14397
# shape = (50, 6)
# window_id = 14398
# shape = (50, 6)
# window_id = 14399
# shape = (50, 6)
# window_id = 14400
# shape = (50, 6)
# window_id = 14401
# shape = (50, 6)
# window_id = 14402
# shape = (50, 6)
# window_id = 14403
# shape = (50, 6)
# window_id = 14404
# shape = (50, 6)
# window_id = 14405
# shape = (50, 6)
# window_id = 14406
# shape = (50, 6)
# window_id = 14407
# shape = (50, 6)
# window_id = 14408
# shape = (50, 6)
# window_id = 14409
# shape = (50, 6)
# window_id = 14410
# shape = (50, 6)
# window_id = 14411
# shape = (50, 6)
# window_id = 14412
# shape = (50, 6)
# window_id = 14413
# shape = (50, 6)
# window_id = 14414
# shape = (50, 6)
# window_id = 14415
# shape = (50, 6)
# window_id = 14416
# shape = (50, 6)
# window_id = 14417
# shape = (50, 6)
# window_id = 14418
# shape = (50, 6)
# window_id = 14419
# shape = (50, 6)
# window_id = 14420
# shape = (50, 6)
# window_id = 14421
# shape = (50, 6)
# window_id = 14422
# shape = (50, 6)
# window_id = 14423
# shape = (50, 6)
# window_id = 14424
# shape = (50, 6)
# window_id = 14425
# shape = (50, 6)
# window_id = 14426
# shape = (50, 6)
# window_id = 14427
# shape = (50, 6)
# window_id = 14428
# shape = (50, 6)
# window_id = 14429
# shape = (50, 6)
# window_id = 14430
# shape = (50, 6)
# window_id = 14431
# shape = (50, 6)
# window_id = 14432
# shape = (50, 6)
# window_id = 14433
# shape = (50, 6)
# window_id = 14434
# shape = (50, 6)
# window_id = 14435
# shape = (50, 6)
# window_id = 14436
# shape = (50, 6)
# window_id = 14437
# shape = (50, 6)
# window_id = 14438
# shape = (50, 6)
# window_id = 14439
# shape = (50, 6)
# window_id = 14440
# shape = (50, 6)
# window_id = 14441
# shape = (50, 6)
# window_id = 14442
# shape = (50, 6)
# window_id = 14443
# shape = (50, 6)
# window_id = 14444
# shape = (50, 6)
# window_id = 14445
# shape = (50, 6)
# window_id = 14446
# shape = (50, 6)
# window_id = 14447
# shape = (50, 6)
# window_id = 14448
# shape = (50, 6)
# window_id = 14449
# shape = (50, 6)
# window_id = 14450
# shape = (50, 6)
# window_id = 14451
# shape = (50, 6)
# window_id = 14452
# shape = (50, 6)
# window_id = 14453
# shape = (50, 6)
# window_id = 14454
# shape = (50, 6)
# window_id = 14455
# shape = (50, 6)
# window_id = 14456
# shape = (50, 6)
# window_id = 14457
# shape = (50, 6)
# window_id = 14458
# shape = (50, 6)
# window_id = 14459
# shape = (50, 6)
# window_id = 14460
# shape = (50, 6)
# window_id = 14461
# shape = (50, 6)
# window_id = 14462
# shape = (50, 6)
# window_id = 14463
# shape = (50, 6)
# window_id = 14464
# shape = (50, 6)
# window_id = 14465
# shape = (50, 6)
# window_id = 14466
# shape = (50, 6)
# window_id = 14467
# shape = (50, 6)
# window_id = 14468
# shape = (50, 6)
# window_id = 14469
# shape = (50, 6)
# window_id = 14470
# shape = (50, 6)
# window_id = 14471
# shape = (50, 6)
# window_id = 14472
# shape = (50, 6)
# window_id = 14473
# shape = (50, 6)
# window_id = 14474
# shape = (50, 6)
# window_id = 14475
# shape = (50, 6)
# window_id = 14476
# shape = (50, 6)
# window_id = 14477
# shape = (50, 6)
# window_id = 14478
# shape = (50, 6)
# window_id = 14479
# shape = (50, 6)
# window_id = 14480
# shape = (50, 6)
# window_id = 14481
# shape = (50, 6)
# window_id = 14482
# shape = (50, 6)
# window_id = 14483
# shape = (50, 6)
# window_id = 14484
# shape = (50, 6)
# window_id = 14485
# shape = (50, 6)
# window_id = 14486
# shape = (50, 6)
# window_id = 14487
# shape = (50, 6)
# window_id = 14488
# shape = (50, 6)
# window_id = 14489
# shape = (50, 6)
# window_id = 14490
# shape = (50, 6)
# window_id = 14491
# shape = (50, 6)
# window_id = 14492
# shape = (50, 6)
# window_id = 14493
# shape = (50, 6)
# window_id = 14494
# shape = (50, 6)
# window_id = 14495
# shape = (50, 6)
# window_id = 14496
# shape = (50, 6)
# window_id = 14497
# shape = (50, 6)
# window_id = 14498
# shape = (50, 6)
# window_id = 14499
# shape = (50, 6)
# window_id = 14500
# shape = (50, 6)
# window_id = 14501
# shape = (50, 6)
# window_id = 14502
# shape = (50, 6)
# window_id = 14503
# shape = (50, 6)
# window_id = 14504
# shape = (50, 6)
# window_id = 14505
# shape = (50, 6)
# window_id = 14506
# shape = (50, 6)
# window_id = 14507
# shape = (50, 6)
# window_id = 14508
# shape = (50, 6)
# window_id = 14509
# shape = (50, 6)
# window_id = 14510
# shape = (50, 6)
# window_id = 14511
# shape = (50, 6)
# window_id = 14512
# shape = (50, 6)
# window_id = 14513
# shape = (50, 6)
# window_id = 14514
# shape = (50, 6)
# window_id = 14515
# shape = (50, 6)
# window_id = 14516
# shape = (50, 6)
# window_id = 14517
# shape = (50, 6)
# window_id = 14518
# shape = (50, 6)
# window_id = 14519
# shape = (50, 6)
# window_id = 14520
# shape = (50, 6)
# window_id = 14521
# shape = (50, 6)
# window_id = 14522
# shape = (50, 6)
# window_id = 14523
# shape = (50, 6)
# window_id = 14524
# shape = (50, 6)
# window_id = 14525
# shape = (50, 6)
# window_id = 14526
# shape = (50, 6)
# window_id = 14527
# shape = (50, 6)
# window_id = 14528
# shape = (50, 6)
# window_id = 14529
# shape = (50, 6)
# window_id = 14530
# shape = (50, 6)
# window_id = 14531
# shape = (50, 6)
# window_id = 14532
# shape = (50, 6)
# window_id = 14533
# shape = (50, 6)
# window_id = 14534
# shape = (50, 6)
# window_id = 14535
# shape = (50, 6)
# window_id = 14536
# shape = (50, 6)
# window_id = 14537
# shape = (50, 6)
# window_id = 14538
# shape = (50, 6)
# window_id = 14539
# shape = (50, 6)
# window_id = 14540
# shape = (50, 6)
# window_id = 14541
# shape = (50, 6)
# window_id = 14542
# shape = (50, 6)
# window_id = 14543
# shape = (50, 6)
# window_id = 14544
# shape = (50, 6)
# window_id = 14545
# shape = (50, 6)
# window_id = 14546
# shape = (50, 6)
# window_id = 14547
# shape = (50, 6)
# window_id = 14548
# shape = (50, 6)
# window_id = 14549
# shape = (50, 6)
# window_id = 14550
# shape = (50, 6)
# window_id = 14551
# shape = (50, 6)
# window_id = 14552
# shape = (50, 6)
# window_id = 14553
# shape = (50, 6)
# window_id = 14554
# shape = (50, 6)
# window_id = 14555
# shape = (50, 6)
# window_id = 14556
# shape = (50, 6)
# window_id = 14557
# shape = (50, 6)
# window_id = 14558
# shape = (50, 6)
# window_id = 14559
# shape = (50, 6)
# window_id = 14560
# shape = (50, 6)
# window_id = 14561
# shape = (50, 6)
# window_id = 14562
# shape = (50, 6)
# window_id = 14563
# shape = (50, 6)
# window_id = 14564
# shape = (50, 6)
# window_id = 14565
# shape = (50, 6)
# window_id = 14566
# shape = (50, 6)
# window_id = 14567
# shape = (50, 6)
# window_id = 14568
# shape = (50, 6)
# window_id = 14569
# shape = (50, 6)
# window_id = 14570
# shape = (50, 6)
# window_id = 14571
# shape = (50, 6)
# window_id = 14572
# shape = (50, 6)
# window_id = 14573
# shape = (50, 6)
# window_id = 14574
# shape = (50, 6)
# window_id = 14575
# shape = (50, 6)
# window_id = 14576
# shape = (50, 6)
# window_id = 14577
# shape = (50, 6)
# window_id = 14578
# shape = (50, 6)
# window_id = 14579
# shape = (50, 6)
# window_id = 14580
# shape = (50, 6)
# window_id = 14581
# shape = (50, 6)
# window_id = 14582
# shape = (50, 6)
# window_id = 14583
# shape = (50, 6)
# window_id = 14584
# shape = (50, 6)
# window_id = 14585
# shape = (50, 6)
# window_id = 14586
# shape = (50, 6)
# window_id = 14587
# shape = (50, 6)
# window_id = 14588
# shape = (50, 6)
# window_id = 14589
# shape = (50, 6)
# window_id = 14590
# shape = (50, 6)
# window_id = 14591
# shape = (50, 6)
# window_id = 14592
# shape = (50, 6)
# window_id = 14593
# shape = (50, 6)
# window_id = 14594
# shape = (50, 6)
# window_id = 14595
# shape = (50, 6)
# window_id = 14596
# shape = (50, 6)
# window_id = 14597
# shape = (50, 6)
# window_id = 14598
# shape = (50, 6)
# window_id = 14599
# shape = (50, 6)
# window_id = 14600
# shape = (50, 6)
# window_id = 14601
# shape = (50, 6)
# window_id = 14602
# shape = (50, 6)
# window_id = 14603
# shape = (50, 6)
# window_id = 14604
# shape = (50, 6)
# window_id = 14605
# shape = (50, 6)
# window_id = 14606
# shape = (50, 6)
# window_id = 14607
# shape = (50, 6)
# window_id = 14608
# shape = (50, 6)
# window_id = 14609
# shape = (50, 6)
# window_id = 14610
# shape = (50, 6)
# window_id = 14611
# shape = (50, 6)
# window_id = 14612
# shape = (50, 6)
# window_id = 14613
# shape = (50, 6)

# %%
X = np.asarray(X)
y = np.asarray(y)

print(f"X shape = {X.shape}")
print(f"y shape = {y.shape}")
# Out:
# X shape = (14614, 50, 6)
# y shape = (14614,)

# %% [markdown]
# We can do a similar test/train split for demonstration purposes. Remember that you will have to split your data by subjects, not radomly.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2, train_size=0.8)

y_train = np.asarray(pd.get_dummies(y_train), dtype=np.float32)
y_test = np.asarray(pd.get_dummies(y_test), dtype=np.float32)

# %%
print(f"X_train shape = {X_train.shape}")
print(f"y_train shape = {y_train.shape}")

print(f"X_test shape = {X_test.shape}")
print(f"y_test shape = {y_test.shape}")
# Out:
# X_train shape = (11691, 50, 6)
# y_train shape = (11691, 14)
# X_test shape = (2923, 50, 6)
# y_test shape = (2923, 14)

# %% [markdown]
# Now we are ready to start the training process

# %%
model.compile(
    optimizer=optimizers.SGD(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics = ['accuracy'])

# %%
model.fit(X_train, y_train,
        batch_size=2, epochs=10)
# Out:
# Epoch 1/10
# 5846/5846 [==============================] - 62s 10ms/step - loss: 2.5898 - accuracy: 0.1268
# Epoch 2/10
# 5846/5846 [==============================] - 67s 11ms/step - loss: 2.3711 - accuracy: 0.1809
# Epoch 3/10
# 5846/5846 [==============================] - 48s 8ms/step - loss: 2.2802 - accuracy: 0.2114
# Epoch 4/10
# 5846/5846 [==============================] - 53s 9ms/step - loss: 2.2057 - accuracy: 0.2339
# Epoch 5/10
# 5846/5846 [==============================] - 54s 9ms/step - loss: 2.1636 - accuracy: 0.2533
# Epoch 6/10
# 5846/5846 [==============================] - 49s 8ms/step - loss: 2.1094 - accuracy: 0.2735
# Epoch 7/10
# 5846/5846 [==============================] - 50s 9ms/step - loss: 2.0867 - accuracy: 0.2749
# Epoch 8/10
# 5846/5846 [==============================] - 59s 10ms/step - loss: 2.0400 - accuracy: 0.2952
# Epoch 9/10
# 5846/5846 [==============================] - 55s 9ms/step - loss: 2.0001 - accuracy: 0.3216
# Epoch 10/10
# 5846/5846 [==============================] - 63s 11ms/step - loss: 1.9817 - accuracy: 0.3240

# %% [markdown]
# We can now view the accuracy of our model on the test dataset.

# %%
# stats
y_pred_ohe = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)
y_true_labels = np.argmax(y_test, axis=1)
# Out:
# 92/92 [==============================] - 3s 29ms/step

# %%
print("*" * 80)
print("Classification report")
print("*" * 80)
print(classification_report(y_true_labels, y_pred_labels))
# Out:
# ********************************************************************************
# Classification report
# ********************************************************************************
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       224
#            1       0.50      0.24      0.33       213
#            2       0.46      0.30      0.36       196
#            3       0.14      0.05      0.07       212
#            4       0.55      0.85      0.67       209
#            5       0.00      0.00      0.00       214
#            6       0.21      0.94      0.34       212
#            7       0.64      0.95      0.77       199
#            8       0.38      0.17      0.24       191
#            9       0.78      0.39      0.52       223
#           10       0.00      0.00      0.00       219
#           11       0.03      0.04      0.03       215
#           12       0.18      0.36      0.24       200
#           13       0.29      0.04      0.06       196
#
#     accuracy                           0.31      2923
#    macro avg       0.30      0.31      0.26      2923
# weighted avg       0.29      0.31      0.26      2923

# %% [markdown]
# ## Conclusion

# %% [markdown]
# You are now ready to start developing your own models for HAR. There are numerous tutorials online which you can follow to build models like LSTMs, CNNs, RFCs and many others.
#
# You have a wide choice of ways to solve this classification model. Here are a few things to think about:
#
# * What type of preprocessing do you want to apply to your data? Examples include:
#     * smoothing the sensor axes
#     * performing axis fusion
#     * extracting scalograms from the signal
#     * manually extracting features from the signal
#     * choosing to leave out certain axes
#
# * What type of model do you want to train?
#     * simple ML model
#     * deep learning model
#
# * Do you want a hierarchical model or a flat model?
#     * hierarchical models means you don't have to train the same type of model for each activity
#     * a flat model might be faster to train and apply in real time
