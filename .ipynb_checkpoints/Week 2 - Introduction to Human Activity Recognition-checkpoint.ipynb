# %% [markdown]
# # Introduction to Human Activity Recognition

# %% [markdown]
# Here we will explore some common ways of preprocessing human activity recognition data.
#
# Using the example data we will learn:
# * how to merge multiple files into one large DataFrame
# * how to split data into sliding windows
# * how to quickly extract features from a window
# * how to set the number of classes considered for classification
# * how to build a simple Random Forest Classifier and train it on HAR data
# * how to build a simple CNN and train it on HAR data
#
# Bear in mind that the sample data offered is not cleaned or high quality. You should not use it in your own experiments but it is useful for this tutorial.
#
# You will need the following packages:
# * tsfresh
# * scikit-learn
# * tensorflow

# %% [markdown]
# #### Basic imports

# %%
import pandas as pd
import numpy as np
import tsfresh
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import tensorflow as tf

import os

import matplotlib.pyplot as plt

# keras goodies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv1D, Dropout, MaxPooling1D, BatchNormalization
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from tensorflow.keras import metrics as kmetrics
import tensorflow.keras.backend as K
# Out:
# /afs/inf.ed.ac.uk/user/s19/s1973235/.local/lib/python3.8/site-packages/pandas/core/arrays/masked.py:59: UserWarning: Pandas requires version '1.3.2' or newer of 'bottleneck' (version '1.2.1' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## Loading multiple files into one large DataFrame

# %% [markdown]
# At this stage you should only be working with clean data, saved in the format required for Coursework 1. An example of such data can be found in the Data/Clean/ folder.

# %%
base_df = pd.DataFrame()

clean_data_folder = "train_data"

for filename in os.listdir(clean_data_folder):
    full_path = f"{clean_data_folder}/{filename}"
    
    if "Falling" not in full_path:
    # load data into a DataFrame
        print(full_path)
        new_df = pd.read_csv(full_path)
    
        # merge into the base DataFrame
        base_df = pd.concat([base_df, new_df])
# Out:
# train_data/Respeck_s1732873_Climbing stairs_04-10-2022_14-29-16.csv
# train_data/Respeck_s1732873_Descending stairs_04-10-2022_14-29-57.csv
# train_data/Respeck_s1732873_Desk work_05-10-2022_09-10-44.csv
# train_data/Respeck_s1732873_Lying down left_04-10-2022_14-12-42.csv
# train_data/Respeck_s1732873_Lying down on back_04-10-2022_14-11-56.csv
# train_data/Respeck_s1732873_Lying down on stomach_04-10-2022_14-14-08.csv
# train_data/Respeck_s1732873_Lying down right_04-10-2022_14-13-24.csv
# train_data/Respeck_s1732873_Movement_05-10-2022_10-08-43.csv
# train_data/Respeck_s1732873_Running_04-10-2022_14-32-19.csv
# train_data/Respeck_s1732873_Sitting_04-10-2022_14-07-59.csv
# train_data/Respeck_s1732873_Sitting bent backward_04-10-2022_14-09-25.csv
# train_data/Respeck_s1732873_Sitting bent forward_04-10-2022_14-08-40.csv
# train_data/Respeck_s1732873_Standing_04-10-2022_14-10-08.csv
# train_data/Respeck_s1732873_Walking at normal speed_04-10-2022_14-31-37.csv
# train_data/Respeck_s1800600_Climbing stairs_05-10-2022_14-07-25.csv
# train_data/Respeck_s1800600_Descending stairs_05-10-2022_14-09-55.csv
# train_data/Respeck_s1800600_Desk work_28-09-2022_13-35-51.csv
# train_data/Respeck_s1800600_Lying down left_28-09-2022_13-02-18.csv
# train_data/Respeck_s1800600_Lying down on back_28-09-2022_13-06-41.csv
# train_data/Respeck_s1800600_Lying down on stomach_28-09-2022_13-05-16.csv
# train_data/Respeck_s1800600_Lying down right_28-09-2022_13-03-48.csv
# train_data/Respeck_s1800600_Movement_28-09-2022_13-37-54.csv
# train_data/Respeck_s1800600_Running_28-09-2022_13-27-08.csv
# train_data/Respeck_s1800600_Sitting_28-09-2022_12-49-23.csv
# train_data/Respeck_s1800600_Sitting bent backward_28-09-2022_12-57-52.csv
# train_data/Respeck_s1800600_Sitting bent forward_28-09-2022_12-55-52.csv
# train_data/Respeck_s1800600_Standing_28-09-2022_12-59-33.csv
# train_data/Respeck_s1800600_Walking at normal speed_28-09-2022_13-20-53.csv
# train_data/Respeck_s1809887_Climbing stairs_29-09-2022_12-41-55.csv
# train_data/Respeck_s1809887_Descending stairs_29-09-2022_12-26-57.csv
# train_data/Respeck_s1809887_Desk work_27-09-2022_15-09-34.csv
# train_data/Respeck_s1809887_Lying down left_27-09-2022_15-00-55.csv
# train_data/Respeck_s1809887_Lying down on back_27-09-2022_14-59-54.csv
# train_data/Respeck_s1809887_Lying down on stomach_27-09-2022_15-04-05.csv
# train_data/Respeck_s1809887_Lying down right_27-09-2022_15-03-09.csv
# train_data/Respeck_s1809887_Movement_27-09-2022_15-11-36.csv
# train_data/Respeck_s1809887_Running_29-09-2022_12-37-49.csv
# train_data/Respeck_s1809887_Sitting_27-09-2022_14-48-42.csv
# train_data/Respeck_s1809887_Sitting bent backward_27-09-2022_14-56-45.csv
# train_data/Respeck_s1809887_Sitting bent forward_27-09-2022_14-55-20.csv
# train_data/Respeck_s1809887_Standing_27-09-2022_14-51-10.csv
# train_data/Respeck_s1809887_Walking at normal speed_27-09-2022_15-39-52.csv
# train_data/Respeck_s1810150_Climbing stairs_22-09-2022_19-35-27.csv
# train_data/Respeck_s1810150_Descending stairs_22-09-2022_19-49-57.csv
# train_data/Respeck_s1810150_Desk work_06-10-2022_20-41-46.csv
# train_data/Respeck_s1810150_Lying down left_22-09-2022_11-45-09.csv
# train_data/Respeck_s1810150_Lying down on back_22-09-2022_11-44-14.csv
# train_data/Respeck_s1810150_Lying down on stomach_22-09-2022_11-46-54.csv
# train_data/Respeck_s1810150_Lying down right_22-09-2022_11-46-01.csv
# train_data/Respeck_s1810150_Movement_06-10-2022_20-27-45.csv
# train_data/Respeck_s1810150_Running_22-09-2022_14-06-03.csv
# train_data/Respeck_s1810150_Sitting_22-09-2022_11-49-45.csv
# train_data/Respeck_s1810150_Sitting bent backward_22-09-2022_11-40-46.csv
# train_data/Respeck_s1810150_Sitting bent forward_06-10-2022_20-28-47.csv
# train_data/Respeck_s1810150_Standing_06-10-2022_20-49-00.csv
# train_data/Respeck_s1810150_Walking at normal speed_22-09-2022_12-28-56.csv
# train_data/Respeck_s1817967_Climbing stairs_30-09-2022_16-32-18.csv
# train_data/Respeck_s1817967_Descending stairs_30-09-2022_16-32-59.csv
# train_data/Respeck_s1817967_Desk work_30-09-2022_16-34-46.csv
# train_data/Respeck_s1817967_Lying down left_30-09-2022_16-25-54.csv
# train_data/Respeck_s1817967_Lying down on back_30-09-2022_16-24-43.csv
# train_data/Respeck_s1817967_Lying down on stomach_30-09-2022_16-27-33.csv
# train_data/Respeck_s1817967_Lying down right_30-09-2022_16-26-44.csv
# train_data/Respeck_s1817967_Movement_30-09-2022_16-35-29.csv
# train_data/Respeck_s1817967_Running_30-09-2022_16-30-26.csv
# train_data/Respeck_s1817967_Sitting_30-09-2022_16-19-45.csv
# train_data/Respeck_s1817967_Sitting bent backward_30-09-2022_16-21-38.csv
# train_data/Respeck_s1817967_Sitting bent forward_30-09-2022_16-23-28.csv
# train_data/Respeck_s1817967_Standing_30-09-2022_16-22-44.csv
# train_data/Respeck_s1817967_Walking at normal speed_30-09-2022_16-29-44.csv
# train_data/Respeck_s1826377_Climbing stairs_07-10-2022_09-28-54-2.csv
# train_data/Respeck_s1826377_Descending stairs_07-10-2022_09-29-45-2.csv
# train_data/Respeck_s1826377_Desk work_30-09-2022_02-05-57.csv
# train_data/Respeck_s1826377_Lying down left_28-09-2022_22-20-25.csv
# train_data/Respeck_s1826377_Lying down on back_28-09-2022_22-18-43.csv
# train_data/Respeck_s1826377_Lying down on stomach_28-09-2022_22-28-16.csv
# train_data/Respeck_s1826377_Lying down right_28-09-2022_22-22-54.csv
# train_data/Respeck_s1826377_Movement_28-09-2022_22-37-31.csv
# train_data/Respeck_s1826377_Running_28-09-2022_23-03-32.csv
# train_data/Respeck_s1826377_Sitting_28-09-2022_22-06-13.csv
# train_data/Respeck_s1826377_Sitting bent backward_28-09-2022_22-13-25.csv
# train_data/Respeck_s1826377_Sitting bent forward_28-09-2022_22-08-54.csv
# train_data/Respeck_s1826377_Standing_28-09-2022_22-15-15.csv
# train_data/Respeck_s1826377_Walking at normal speed_28-09-2022_22-58-25.csv
# train_data/Respeck_s1828233_Climbing stairs_22-09-2022_14-07-52.csv
# train_data/Respeck_s1828233_Descending stairs_22-09-2022_14-09-08.csv
# train_data/Respeck_s1828233_Desk work_22-09-2022_14-04-14.csv
# train_data/Respeck_s1828233_Lying down left_22-09-2022_13-58-53.csv
# train_data/Respeck_s1828233_Lying down on back_22-09-2022_13-56-54.csv
# train_data/Respeck_s1828233_Lying down on stomach_22-09-2022_14-01-43.csv
# train_data/Respeck_s1828233_Lying down right_22-09-2022_14-00-18.csv
# train_data/Respeck_s1828233_Movement_22-09-2022_14-05-45.csv
# train_data/Respeck_s1828233_Running_22-09-2022_15-01-25.csv
# train_data/Respeck_s1828233_Sitting_22-09-2022_13-50-44.csv
# train_data/Respeck_s1828233_Sitting bent backward_22-09-2022_13-53-43.csv
# train_data/Respeck_s1828233_Sitting bent forward_22-09-2022_13-52-18.csv
# train_data/Respeck_s1828233_Standing_22-09-2022_13-55-08.csv
# train_data/Respeck_s1828233_Walking at normal speed_22-09-2022_15-00-03.csv
# train_data/Respeck_s1832512_Climbing stairs_05-10-2022_13-42-13.csv
# train_data/Respeck_s1832512_Descending stairs_05-10-2022_13-42-59.csv
# train_data/Respeck_s1832512_Desk work_02-10-2022_15-29-57.csv
# train_data/Respeck_s1832512_Lying down left_05-10-2022_11-39-41.csv
# train_data/Respeck_s1832512_Lying down on back_02-10-2022_15-41-05.csv
# train_data/Respeck_s1832512_Lying down on stomach_02-10-2022_15-44-18.csv
# train_data/Respeck_s1832512_Lying down right_02-10-2022_15-40-15.csv
# train_data/Respeck_s1832512_Movement_05-10-2022_11-26-41.csv
# train_data/Respeck_s1832512_Running_05-10-2022_11-37-48.csv
# train_data/Respeck_s1832512_Sitting_02-10-2022_15-24-49.csv
# train_data/Respeck_s1832512_Sitting bent backward_02-10-2022_15-28-22.csv
# train_data/Respeck_s1832512_Sitting bent forward_07-10-2022_10-27-44.csv
# train_data/Respeck_s1832512_Standing_05-10-2022_11-25-23.csv
# train_data/Respeck_s1832512_Walking at normal speed_07-10-2022_10-33-05.csv
# train_data/Respeck_s1834237_Climbing stairs_30-09-2022_17-56-16.csv
# train_data/Respeck_s1834237_Descending stairs_30-09-2022_17-57-05.csv
# train_data/Respeck_s1834237_Desk work_30-09-2022_17-49-52.csv
# train_data/Respeck_s1834237_Lying down left_30-09-2022_17-14-37.csv
# train_data/Respeck_s1834237_Lying down on back_30-09-2022_17-09-25.csv
# train_data/Respeck_s1834237_Lying down on stomach_30-09-2022_17-17-45.csv
# train_data/Respeck_s1834237_Lying down right_30-09-2022_17-12-08.csv
# train_data/Respeck_s1834237_Movement_30-09-2022_17-59-29.csv
# train_data/Respeck_s1834237_Running_30-09-2022_17-44-40.csv
# train_data/Respeck_s1834237_Sitting_30-09-2022_16-55-17.csv
# train_data/Respeck_s1834237_Sitting bent backward_30-09-2022_16-59-23.csv
# train_data/Respeck_s1834237_Sitting bent forward_30-09-2022_16-58-23.csv
# train_data/Respeck_s1834237_Standing_30-09-2022_17-02-21.csv
# train_data/Respeck_s1834237_Walking at normal speed_30-09-2022_17-39-29.csv
# train_data/Respeck_s1836526_Climbing stairs_23-09-2022_13-15-49.csv
# train_data/Respeck_s1836526_Descending stairs_23-09-2022_13-17-22.csv
# train_data/Respeck_s1836526_Desk work_23-09-2022_13-29-40.csv
# train_data/Respeck_s1836526_Lying down left_23-09-2022_13-21-48.csv
# train_data/Respeck_s1836526_Lying down on back_23-09-2022_13-25-40.csv
# train_data/Respeck_s1836526_Lying down on stomach_23-09-2022_13-24-23.csv
# train_data/Respeck_s1836526_Lying down right_23-09-2022_13-23-05.csv
# train_data/Respeck_s1836526_Movement_23-09-2022_13-08-51.csv
# train_data/Respeck_s1836526_Running_23-09-2022_13-07-03.csv
# train_data/Respeck_s1836526_Sitting_23-09-2022_13-31-03.csv
# train_data/Respeck_s1836526_Sitting bent backward_23-09-2022_13-33-29.csv
# train_data/Respeck_s1836526_Sitting bent forward_23-09-2022_13-32-16.csv
# train_data/Respeck_s1836526_Standing_23-09-2022_13-34-57.csv
# train_data/Respeck_s1836526_Walking at normal speed_23-09-2022_13-05-26.csv
# train_data/Respeck_s1837624_Climbing stairs_04-10-2022_17-16-01.csv
# train_data/Respeck_s1837624_Descending stairs_04-10-2022_17-02-31.csv
# train_data/Respeck_s1837624_Desk work_28-09-2022_15-17-43.csv
# train_data/Respeck_s1837624_Lying down left_04-10-2022_20-15-31.csv
# train_data/Respeck_s1837624_Lying down on back_28-09-2022_15-14-07.csv
# train_data/Respeck_s1837624_Lying down on stomach_04-10-2022_20-14-11.csv
# train_data/Respeck_s1837624_Lying down right_04-10-2022_20-12-36.csv
# train_data/Respeck_s1837624_Movement_28-09-2022_15-18-58.csv
# train_data/Respeck_s1837624_Running_04-10-2022_17-19-09.csv
# train_data/Respeck_s1837624_Sitting_04-10-2022_20-06-04.csv
# train_data/Respeck_s1837624_Sitting bent backward_28-09-2022_15-06-46.csv
# train_data/Respeck_s1837624_Sitting bent forward_04-10-2022_20-07-59.csv
# train_data/Respeck_s1837624_Standing_04-10-2022_20-10-08.csv
# train_data/Respeck_s1837624_Walking at normal speed_04-10-2022_20-18-34.csv
# train_data/Respeck_s1839825_Climbing stairs_22-09-2022_13-42-20.csv
# train_data/Respeck_s1839825_Descending stairs_22-09-2022_13-43-38.csv
# train_data/Respeck_s1839825_Desk work_22-09-2022_13-37-19.csv
# train_data/Respeck_s1839825_Lying down left_22-09-2022_13-30-46.csv
# train_data/Respeck_s1839825_Lying down on back_22-09-2022_13-29-01.csv
# train_data/Respeck_s1839825_Lying down on stomach_22-09-2022_13-34-28.csv
# train_data/Respeck_s1839825_Lying down right_22-09-2022_13-33-01.csv
# train_data/Respeck_s1839825_Movement_22-09-2022_13-38-55.csv
# train_data/Respeck_s1839825_Running_22-09-2022_14-55-01.csv
# train_data/Respeck_s1839825_Sitting_22-09-2022_13-20-18.csv
# train_data/Respeck_s1839825_Sitting bent backward_22-09-2022_13-22-23.csv
# train_data/Respeck_s1839825_Sitting bent forward_22-09-2022_13-21-20.csv
# train_data/Respeck_s1839825_Standing_22-09-2022_13-23-11.csv
# train_data/Respeck_s1839825_Walking at normal speed_22-09-2022_14-53-41.csv
# train_data/Respeck_s1842855_Climbing stairs_04-10-2022_17-03-32.csv
# train_data/Respeck_s1842855_Descending stairs_04-10-2022_17-04-23.csv
# train_data/Respeck_s1842855_Desk work_04-10-2022_00-02-30.csv
# train_data/Respeck_s1842855_Lying down left_03-10-2022_23-56-47.csv
# train_data/Respeck_s1842855_Lying down on back_03-10-2022_23-55-46.csv
# train_data/Respeck_s1842855_Lying down on stomach_03-10-2022_23-59-57.csv
# train_data/Respeck_s1842855_Lying down right_03-10-2022_23-58-54.csv
# train_data/Respeck_s1842855_Movement_04-10-2022_00-05-19.csv
# train_data/Respeck_s1842855_Running_04-10-2022_00-13-13.csv
# train_data/Respeck_s1842855_Sitting_03-10-2022_23-45-36.csv
# train_data/Respeck_s1842855_Sitting bent backward_03-10-2022_23-48-37.csv
# train_data/Respeck_s1842855_Sitting bent forward_03-10-2022_23-47-07.csv
# train_data/Respeck_s1842855_Standing_03-10-2022_23-50-06.csv
# train_data/Respeck_s1842855_Walking at normal speed_04-10-2022_00-16-28.csv
# train_data/Respeck_s1852056_Climbing stairs_05-10-2022_14-35-44.csv
# train_data/Respeck_s1852056_Descending stairs_05-10-2022_14-39-23.csv
# train_data/Respeck_s1852056_Desk work_05-10-2022_15-06-36.csv
# train_data/Respeck_s1852056_Lying down left_05-10-2022_15-16-11.csv
# train_data/Respeck_s1852056_Lying down on back_05-10-2022_15-11-38.csv
# train_data/Respeck_s1852056_Lying down on stomach_05-10-2022_15-13-53.csv
# train_data/Respeck_s1852056_Lying down right_05-10-2022_15-17-15.csv
# train_data/Respeck_s1852056_Movement_05-10-2022_15-10-01.csv
# train_data/Respeck_s1852056_Running_05-10-2022_15-55-29.csv
# train_data/Respeck_s1852056_Sitting_05-10-2022_14-43-03.csv
# train_data/Respeck_s1852056_Sitting bent backward_05-10-2022_15-03-21.csv
# train_data/Respeck_s1852056_Sitting bent forward_05-10-2022_14-44-04.csv
# train_data/Respeck_s1852056_Standing_05-10-2022_15-07-34.csv
# train_data/Respeck_s1852056_Walking at normal speed_05-10-2022_15-52-26.csv
# train_data/Respeck_s1853226_Climbing stairs_28-09-2022_16-38-36.csv
# train_data/Respeck_s1853226_Descending stairs_28-09-2022_16-41-08.csv
# train_data/Respeck_s1853226_Desk work_28-09-2022_16-36-56.csv
# train_data/Respeck_s1853226_Lying down left_28-09-2022_16-22-09.csv
# train_data/Respeck_s1853226_Lying down on back_28-09-2022_16-19-43.csv
# train_data/Respeck_s1853226_Lying down on stomach_28-09-2022_16-31-43.csv
# train_data/Respeck_s1853226_Lying down right_28-09-2022_16-24-19.csv
# train_data/Respeck_s1853226_Movement_28-09-2022_16-33-59.csv
# train_data/Respeck_s1853226_Running_28-09-2022_16-55-34.csv
# train_data/Respeck_s1853226_Sitting_28-09-2022_16-11-24.csv
# train_data/Respeck_s1853226_Sitting bent backward_28-09-2022_16-15-24.csv
# train_data/Respeck_s1853226_Sitting bent forward_28-09-2022_16-12-21.csv
# train_data/Respeck_s1853226_Standing_28-09-2022_16-17-29.csv
# train_data/Respeck_s1853226_Walking at normal speed_28-09-2022_16-53-27.csv
# train_data/Respeck_s1858629_Climbing stairs_22-09-2022_20-05-01.csv
# train_data/Respeck_s1858629_Descending stairs_22-09-2022_20-06-01.csv
# train_data/Respeck_s1858629_Desk work_26-09-2022_12-45-36.csv
# train_data/Respeck_s1858629_Lying down left_26-09-2022_13-24-23.csv
# train_data/Respeck_s1858629_Lying down on back_26-09-2022_13-15-13.csv
# train_data/Respeck_s1858629_Lying down on stomach_26-09-2022_13-01-18.csv
# train_data/Respeck_s1858629_Lying down right_26-09-2022_13-28-36.csv
# train_data/Respeck_s1858629_Movement_26-09-2022_14-00-19.csv
# train_data/Respeck_s1858629_Running_07-10-2022_08-52-32.csv
# train_data/Respeck_s1858629_Sitting_26-09-2022_12-06-10.csv
# train_data/Respeck_s1858629_Sitting bent backward_26-09-2022_12-40-05.csv
# train_data/Respeck_s1858629_Sitting bent forward_26-09-2022_12-17-47.csv
# train_data/Respeck_s1858629_Standing_26-09-2022_12-56-13.csv
# train_data/Respeck_s1858629_Walking at normal speed_07-10-2022_08-46-49.csv
# train_data/Respeck_s1862323_Climbing stairs_02-10-2022_00-05-31.csv
# train_data/Respeck_s1862323_Descending stairs_02-10-2022_00-13-57.csv
# train_data/Respeck_s1862323_Desk work_01-10-2022_23-14-04.csv
# train_data/Respeck_s1862323_Lying down left_01-10-2022_22-45-29.csv
# train_data/Respeck_s1862323_Lying down on back_01-10-2022_22-39-10.csv
# train_data/Respeck_s1862323_Lying down on stomach_01-10-2022_23-05-46.csv
# train_data/Respeck_s1862323_Lying down right_01-10-2022_22-54-56.csv
# train_data/Respeck_s1862323_Movement_01-10-2022_23-17-54.csv
# train_data/Respeck_s1862323_Running_01-10-2022_23-59-27.csv
# train_data/Respeck_s1862323_Sitting_01-10-2022_21-57-58.csv
# train_data/Respeck_s1862323_Sitting bent backward_01-10-2022_22-25-45.csv
# train_data/Respeck_s1862323_Sitting bent forward_01-10-2022_22-03-29.csv
# train_data/Respeck_s1862323_Standing_01-10-2022_22-30-55.csv
# train_data/Respeck_s1862323_Walking at normal speed_01-10-2022_23-55-56.csv
# train_data/Respeck_s1862671_Climbing stairs_22-09-2022_21-02-33.csv
# train_data/Respeck_s1862671_Descending stairs_22-09-2022_21-01-44.csv
# train_data/Respeck_s1862671_Desk work_22-09-2022_21-58-38.csv
# train_data/Respeck_s1862671_Lying down left_05-10-2022_22-56-11.csv
# train_data/Respeck_s1862671_Lying down on back_22-09-2022_21-32-19.csv
# train_data/Respeck_s1862671_Lying down on stomach_22-09-2022_21-40-51.csv
# train_data/Respeck_s1862671_Lying down right_05-10-2022_22-54-41.csv
# train_data/Respeck_s1862671_Movement_22-09-2022_22-58-03.csv
# train_data/Respeck_s1862671_Running_22-09-2022_22-51-08.csv
# train_data/Respeck_s1862671_Sitting_04-10-2022_12-45-29.csv
# train_data/Respeck_s1862671_Sitting bent backward_05-10-2022_22-25-52.csv
# train_data/Respeck_s1862671_Sitting bent forward_22-09-2022_21-50-21.csv
# train_data/Respeck_s1862671_Standing_04-10-2022_12-43-00.csv
# train_data/Respeck_s1862671_Walking at normal speed_22-09-2022_21-09-24.csv
# train_data/Respeck_s1863792_Climbing stairs_05-10-2022_16-17-08.csv
# train_data/Respeck_s1863792_Descending stairs_05-10-2022_16-18-15.csv
# train_data/Respeck_s1863792_Desk work_23-09-2022_15-49-23.csv
# train_data/Respeck_s1863792_Lying down left_23-09-2022_15-34-31.csv
# train_data/Respeck_s1863792_Lying down on back_23-09-2022_15-39-05.csv
# train_data/Respeck_s1863792_Lying down on stomach_23-09-2022_15-37-42.csv
# train_data/Respeck_s1863792_Lying down right_23-09-2022_15-36-02.csv
# train_data/Respeck_s1863792_Movement_23-09-2022_15-53-04.csv
# train_data/Respeck_s1863792_Running_23-09-2022_17-09-20.csv
# train_data/Respeck_s1863792_Sitting_30-09-2022_16-06-38.csv
# train_data/Respeck_s1863792_Sitting bent backward_23-09-2022_15-28-43.csv
# train_data/Respeck_s1863792_Sitting bent forward_23-09-2022_15-27-38.csv
# train_data/Respeck_s1863792_Standing_30-09-2022_16-07-41.csv
# train_data/Respeck_s1863792_Walking at normal speed_23-09-2022_15-42-20.csv
# train_data/Respeck_s1892493_Climbing stairs_28-09-2022_14-51-30.csv
# train_data/Respeck_s1892493_Descending stairs_28-09-2022_14-53-01.csv
# train_data/Respeck_s1892493_Desk work_28-09-2022_14-36-16.csv
# train_data/Respeck_s1892493_Lying down left_28-09-2022_14-48-34.csv
# train_data/Respeck_s1892493_Lying down on back_28-09-2022_14-38-02.csv
# train_data/Respeck_s1892493_Lying down on stomach_28-09-2022_14-44-29.csv
# train_data/Respeck_s1892493_Lying down right_28-09-2022_14-49-57.csv
# train_data/Respeck_s1892493_Movement_28-09-2022_15-13-44.csv
# train_data/Respeck_s1892493_Running_28-09-2022_15-06-19.csv
# train_data/Respeck_s1892493_Sitting_28-09-2022_14-30-05.csv
# train_data/Respeck_s1892493_Sitting bent backward_28-09-2022_14-33-02.csv
# train_data/Respeck_s1892493_Sitting bent forward_28-09-2022_14-30-54.csv
# train_data/Respeck_s1892493_Standing_28-09-2022_14-33-59.csv
# train_data/Respeck_s1892493_Walking at normal speed_28-09-2022_15-02-22.csv
# train_data/Respeck_s1900673_Climbing stairs_02-10-2022_16-01-56.csv
# train_data/Respeck_s1900673_Descending stairs_02-10-2022_16-05-08.csv
# train_data/Respeck_s1900673_Desk work_01-10-2022_20-30-16.csv
# train_data/Respeck_s1900673_Lying down left_03-10-2022_23-59-04.csv
# train_data/Respeck_s1900673_Lying down on back_29-09-2022_22-40-23.csv
# train_data/Respeck_s1900673_Lying down on stomach_04-10-2022_13-13-32.csv
# train_data/Respeck_s1900673_Lying down right_04-10-2022_13-23-43.csv
# train_data/Respeck_s1900673_Movement_01-10-2022_20-21-03.csv
# train_data/Respeck_s1900673_Running_01-10-2022_20-37-17.csv
# train_data/Respeck_s1900673_Sitting_02-10-2022_16-29-19.csv
# train_data/Respeck_s1900673_Sitting bent backward_02-10-2022_15-53-47.csv
# train_data/Respeck_s1900673_Sitting bent forward_02-10-2022_15-52-09.csv
# train_data/Respeck_s1900673_Standing_29-09-2022_22-38-59.csv
# train_data/Respeck_s1900673_Walking at normal speed_29-09-2022_22-45-07.csv
# train_data/Respeck_s1901843_Climbing stairs_06-10-2022_18-17-51.csv
# train_data/Respeck_s1901843_Descending stairs_06-10-2022_18-18-51.csv
# train_data/Respeck_s1901843_Desk work_24-09-2022_16-43-27.csv
# train_data/Respeck_s1901843_Lying down left_24-09-2022_16-46-19.csv
# train_data/Respeck_s1901843_Lying down on back_24-09-2022_16-45-35.csv
# train_data/Respeck_s1901843_Lying down on stomach_24-09-2022_16-47-53.csv
# train_data/Respeck_s1901843_Lying down right_24-09-2022_16-47-10.csv
# train_data/Respeck_s1901843_Movement_24-09-2022_16-42-44.csv
# train_data/Respeck_s1901843_Running_24-09-2022_16-40-20.csv
# train_data/Respeck_s1901843_Sitting_24-09-2022_16-35-40.csv
# train_data/Respeck_s1901843_Sitting bent backward_24-09-2022_16-37-06.csv
# train_data/Respeck_s1901843_Sitting bent forward_24-09-2022_16-36-24.csv
# train_data/Respeck_s1901843_Standing_24-09-2022_16-37-55.csv
# train_data/Respeck_s1901843_Walking at normal speed_24-09-2022_16-39-24.csv
# train_data/Respeck_s1904845_Climbing stairs_05-10-2022_19-15-41.csv
# train_data/Respeck_s1904845_Descending stairs_05-10-2022_19-14-28.csv
# train_data/Respeck_s1904845_Desk work_05-10-2022_19-23-56.csv
# train_data/Respeck_s1904845_Lying down left_05-10-2022_18-56-06.csv
# train_data/Respeck_s1904845_Lying down on back_05-10-2022_18-53-54.csv
# train_data/Respeck_s1904845_Lying down on stomach_03-10-2022_16-55-53.csv
# train_data/Respeck_s1904845_Lying down right_05-10-2022_18-58-12.csv
# train_data/Respeck_s1904845_Movement_03-10-2022_17-10-01.csv
# train_data/Respeck_s1904845_Running_05-10-2022_19-11-23.csv
# train_data/Respeck_s1904845_Sitting_03-10-2022_16-49-45.csv
# train_data/Respeck_s1904845_Sitting bent backward_05-10-2022_18-49-52.csv
# train_data/Respeck_s1904845_Sitting bent forward_05-10-2022_18-48-50.csv
# train_data/Respeck_s1904845_Standing_03-10-2022_16-52-27.csv
# train_data/Respeck_s1904845_Walking at normal speed_05-10-2022_19-07-00.csv
# train_data/Respeck_s1908422_Climbing stairs_05-10-2022_16-23-16.csv
# train_data/Respeck_s1908422_Descending stairs_05-10-2022_16-24-12.csv
# train_data/Respeck_s1908422_Desk work_23-09-2022_16-21-33.csv
# train_data/Respeck_s1908422_Lying down left_30-09-2022_16-14-37.csv
# train_data/Respeck_s1908422_Lying down on back_23-09-2022_16-17-41.csv
# train_data/Respeck_s1908422_Lying down on stomach_30-09-2022_16-15-34.csv
# train_data/Respeck_s1908422_Lying down right_30-09-2022_16-16-38.csv
# train_data/Respeck_s1908422_Movement_23-09-2022_16-23-08.csv
# train_data/Respeck_s1908422_Running_23-09-2022_17-06-43.csv
# train_data/Respeck_s1908422_Sitting_30-09-2022_16-21-46.csv
# train_data/Respeck_s1908422_Sitting bent backward_30-09-2022_16-19-42.csv
# train_data/Respeck_s1908422_Sitting bent forward_30-09-2022_16-20-33.csv
# train_data/Respeck_s1908422_Standing_30-09-2022_16-24-06.csv
# train_data/Respeck_s1908422_Walking at normal speed_23-09-2022_16-19-23.csv
# train_data/Respeck_s1909083_Climbing stairs_30-09-2022_02-35-55.csv
# train_data/Respeck_s1909083_Descending stairs_30-09-2022_02-36-44.csv
# train_data/Respeck_s1909083_Desk work_30-09-2022_03-19-32.csv
# train_data/Respeck_s1909083_Lying down left_30-09-2022_02-04-31.csv
# train_data/Respeck_s1909083_Lying down on back_30-09-2022_02-00-26.csv
# train_data/Respeck_s1909083_Lying down on stomach_30-09-2022_02-07-45.csv
# train_data/Respeck_s1909083_Lying down right_30-09-2022_02-06-48.csv
# train_data/Respeck_s1909083_Movement_30-09-2022_03-24-27.csv
# train_data/Respeck_s1909083_Running_30-09-2022_02-18-24.csv
# train_data/Respeck_s1909083_Sitting_30-09-2022_01-51-02.csv
# train_data/Respeck_s1909083_Sitting bent backward_30-09-2022_01-52-16.csv
# train_data/Respeck_s1909083_Sitting bent forward_30-09-2022_01-39-13.csv
# train_data/Respeck_s1909083_Standing_30-09-2022_01-57-02.csv
# train_data/Respeck_s1909083_Walking at normal speed_30-09-2022_02-13-45.csv
# train_data/Respeck_s1910268_Climbing stairs_03-10-2022_18-12-57.csv
# train_data/Respeck_s1910268_Descending stairs_03-10-2022_18-11-42.csv
# train_data/Respeck_s1910268_Desk work_24-09-2022_16-57-34.csv
# train_data/Respeck_s1910268_Lying down left_24-09-2022_16-30-49.csv
# train_data/Respeck_s1910268_Lying down on back_24-09-2022_16-29-08.csv
# train_data/Respeck_s1910268_Lying down on stomach_24-09-2022_16-33-56.csv
# train_data/Respeck_s1910268_Lying down right_24-09-2022_16-32-24.csv
# train_data/Respeck_s1910268_Movement_24-09-2022_16-59-51.csv
# train_data/Respeck_s1910268_Running_24-09-2022_16-43-26.csv
# train_data/Respeck_s1910268_Sitting_24-09-2022_16-21-35.csv
# train_data/Respeck_s1910268_Sitting bent backward_24-09-2022_17-04-34.csv
# train_data/Respeck_s1910268_Sitting bent forward_24-09-2022_16-22-25.csv
# train_data/Respeck_s1910268_Standing_24-09-2022_16-25-25.csv
# train_data/Respeck_s1910268_Walking at normal speed_24-09-2022_16-40-45.csv
# train_data/Respeck_s1911027_Climbing stairs_04-10-2022_15-11-39.csv
# train_data/Respeck_s1911027_Descending stairs_04-10-2022_15-14-05.csv
# train_data/Respeck_s1911027_Desk work_04-10-2022_15-51-21.csv
# train_data/Respeck_s1911027_Lying down left_04-10-2022_15-53-33.csv
# train_data/Respeck_s1911027_Lying down on back_27-09-2022_11-29-45.csv
# train_data/Respeck_s1911027_Lying down on stomach_27-09-2022_11-33-55.csv
# train_data/Respeck_s1911027_Lying down right_27-09-2022_11-32-21.csv
# train_data/Respeck_s1911027_Movement_27-09-2022_11-38-42.csv
# train_data/Respeck_s1911027_Running_04-10-2022_15-26-46.csv
# train_data/Respeck_s1911027_Sitting_04-10-2022_16-03-16.csv
# train_data/Respeck_s1911027_Sitting bent backward_27-09-2022_11-24-30.csv
# train_data/Respeck_s1911027_Sitting bent forward_04-10-2022_15-52-16.csv
# train_data/Respeck_s1911027_Standing_04-10-2022_15-50-05.csv
# train_data/Respeck_s1911027_Walking at normal speed_27-09-2022_11-35-30.csv
# train_data/Respeck_s1911455_Climbing stairs_04-10-2022_15-18-24.csv
# train_data/Respeck_s1911455_Descending stairs_04-10-2022_15-17-25.csv
# train_data/Respeck_s1911455_Desk work_23-09-2022_17-17-39.csv
# train_data/Respeck_s1911455_Lying down left_23-09-2022_17-22-47.csv
# train_data/Respeck_s1911455_Lying down on back_23-09-2022_17-22-09.csv
# train_data/Respeck_s1911455_Lying down on stomach_04-10-2022_15-13-28.csv
# train_data/Respeck_s1911455_Lying down right_23-09-2022_17-21-29.csv
# train_data/Respeck_s1911455_Movement_23-09-2022_17-24-15.csv
# train_data/Respeck_s1911455_Running_23-09-2022_17-34-41.csv
# train_data/Respeck_s1911455_Sitting_23-09-2022_17-16-52.csv
# train_data/Respeck_s1911455_Sitting bent backward_23-09-2022_17-18-20.csv
# train_data/Respeck_s1911455_Sitting bent forward_23-09-2022_17-18-58.csv
# train_data/Respeck_s1911455_Standing_23-09-2022_17-19-41.csv
# train_data/Respeck_s1911455_Walking at normal speed_04-10-2022_15-14-50.csv
# train_data/Respeck_s1912575_Climbing stairs_01-10-2022_02-20-46.csv
# train_data/Respeck_s1912575_Descending stairs_01-10-2022_02-21-34.csv
# train_data/Respeck_s1912575_Desk work_28-09-2022_22-07-05.csv
# train_data/Respeck_s1912575_Lying down left_28-09-2022_22-04-22.csv
# train_data/Respeck_s1912575_Lying down on back_28-09-2022_21-44-25.csv
# train_data/Respeck_s1912575_Lying down on stomach_28-09-2022_22-05-58.csv
# train_data/Respeck_s1912575_Lying down right_28-09-2022_22-05-10.csv
# train_data/Respeck_s1912575_Movement_04-10-2022_23-20-53.csv
# train_data/Respeck_s1912575_Running_01-10-2022_03-54-07.csv
# train_data/Respeck_s1912575_Sitting_04-10-2022_23-02-40.csv
# train_data/Respeck_s1912575_Sitting bent backward_05-10-2022_09-44-38.csv
# train_data/Respeck_s1912575_Sitting bent forward_05-10-2022_09-43-43.csv
# train_data/Respeck_s1912575_Standing_04-10-2022_23-12-47.csv
# train_data/Respeck_s1912575_Walking at normal speed_01-10-2022_03-52-37.csv
# train_data/Respeck_s1912614_Climbing stairs_02-10-2022_18-32-13.csv
# train_data/Respeck_s1912614_Descending stairs_02-10-2022_18-47-13.csv
# train_data/Respeck_s1912614_Desk work_01-10-2022_14-27-46.csv
# train_data/Respeck_s1912614_Lying down left_01-10-2022_15-11-07.csv
# train_data/Respeck_s1912614_Lying down on back_01-10-2022_14-41-13.csv
# train_data/Respeck_s1912614_Lying down on stomach_01-10-2022_15-16-18.csv
# train_data/Respeck_s1912614_Lying down right_03-10-2022_20-49-17.csv
# train_data/Respeck_s1912614_Movement_03-10-2022_20-46-28.csv
# train_data/Respeck_s1912614_Running_03-10-2022_21-16-46.csv
# train_data/Respeck_s1912614_Sitting_01-10-2022_15-19-35.csv
# train_data/Respeck_s1912614_Sitting bent backward_01-10-2022_13-58-23.csv
# train_data/Respeck_s1912614_Sitting bent forward_01-10-2022_14-28-38.csv
# train_data/Respeck_s1912614_Standing_03-10-2022_20-52-19.csv
# train_data/Respeck_s1912614_Walking at normal speed_02-10-2022_19-19-18.csv
# train_data/Respeck_s1915425_Climbing stairs_28-09-2022_14-02-24.csv
# train_data/Respeck_s1915425_Descending stairs_28-09-2022_14-01-32.csv
# train_data/Respeck_s1915425_Desk work_28-09-2022_18-52-16.csv
# train_data/Respeck_s1915425_Lying down left_28-09-2022_12-21-54.csv
# train_data/Respeck_s1915425_Lying down on back_28-09-2022_12-20-03.csv
# train_data/Respeck_s1915425_Lying down on stomach_28-09-2022_12-24-28.csv
# train_data/Respeck_s1915425_Lying down right_28-09-2022_18-53-31.csv
# train_data/Respeck_s1915425_Movement_28-09-2022_12-32-18.csv
# train_data/Respeck_s1915425_Running_28-09-2022_14-29-29.csv
# train_data/Respeck_s1915425_Sitting_28-09-2022_18-48-53.csv
# train_data/Respeck_s1915425_Sitting bent backward_28-09-2022_12-29-11.csv
# train_data/Respeck_s1915425_Sitting bent forward_28-09-2022_18-51-27.csv
# train_data/Respeck_s1915425_Standing_28-09-2022_18-49-53.csv
# train_data/Respeck_s1915425_Walking at normal speed_28-09-2022_14-30-49.csv
# train_data/Respeck_s1918258_Climbing stairs_29-09-2022_17-42-07.csv
# train_data/Respeck_s1918258_Descending stairs_29-09-2022_17-42-55.csv
# train_data/Respeck_s1918258_Desk work_05-10-2022_10-58-05.csv
# train_data/Respeck_s1918258_Lying down left_28-09-2022_15-43-20.csv
# train_data/Respeck_s1918258_Lying down on back_28-09-2022_15-42-21.csv
# train_data/Respeck_s1918258_Lying down on stomach_28-09-2022_15-45-27.csv
# train_data/Respeck_s1918258_Lying down right_05-10-2022_11-10-46.csv
# train_data/Respeck_s1918258_Movement_28-09-2022_15-49-31.csv
# train_data/Respeck_s1918258_Running_28-09-2022_16-04-54.csv
# train_data/Respeck_s1918258_Sitting_29-09-2022_15-50-55.csv
# train_data/Respeck_s1918258_Sitting bent backward_29-09-2022_15-52-32.csv
# train_data/Respeck_s1918258_Sitting bent forward_29-09-2022_15-51-43.csv
# train_data/Respeck_s1918258_Standing_28-09-2022_15-40-51.csv
# train_data/Respeck_s1918258_Walking at normal speed_28-09-2022_16-03-29.csv
# train_data/Respeck_s1918275_Climbing stairs_05-10-2022_17-00-41.csv
# train_data/Respeck_s1918275_Descending stairs_05-10-2022_16-59-52.csv
# train_data/Respeck_s1918275_Desk work_06-10-2022_09-01-20.csv
# train_data/Respeck_s1918275_Lying down left_01-10-2022_13-47-27.csv
# train_data/Respeck_s1918275_Lying down on back_01-10-2022_13-43-54.csv
# train_data/Respeck_s1918275_Lying down on stomach_01-10-2022_13-50-24.csv
# train_data/Respeck_s1918275_Lying down right_01-10-2022_13-48-16.csv
# train_data/Respeck_s1918275_Movement_01-10-2022_14-11-39.csv
# train_data/Respeck_s1918275_Running_01-10-2022_13-56-24.csv
# train_data/Respeck_s1918275_Sitting_04-10-2022_14-16-41.csv
# train_data/Respeck_s1918275_Sitting bent backward_01-10-2022_13-35-58.csv
# train_data/Respeck_s1918275_Sitting bent forward_01-10-2022_13-34-35.csv
# train_data/Respeck_s1918275_Standing_01-10-2022_13-40-11.csv
# train_data/Respeck_s1918275_Walking at normal speed_01-10-2022_13-54-09.csv
# train_data/Respeck_s1920337_Climbing stairs_23-09-2022_12-36-38.csv
# train_data/Respeck_s1920337_Descending stairs_23-09-2022_12-37-17.csv
# train_data/Respeck_s1920337_Desk work_23-09-2022_12-22-16.csv
# train_data/Respeck_s1920337_Lying down left_23-09-2022_12-24-44.csv
# train_data/Respeck_s1920337_Lying down on back_23-09-2022_12-29-29.csv
# train_data/Respeck_s1920337_Lying down on stomach_23-09-2022_12-28-13.csv
# train_data/Respeck_s1920337_Lying down right_23-09-2022_12-26-01.csv
# train_data/Respeck_s1920337_Movement_23-09-2022_13-00-58.csv
# train_data/Respeck_s1920337_Running_23-09-2022_12-45-08.csv
# train_data/Respeck_s1920337_Sitting_23-09-2022_12-17-12.csv
# train_data/Respeck_s1920337_Sitting bent backward_23-09-2022_12-19-09.csv
# train_data/Respeck_s1920337_Sitting bent forward_23-09-2022_12-18-28.csv
# train_data/Respeck_s1920337_Standing_23-09-2022_12-20-37.csv
# train_data/Respeck_s1920337_Walking at normal speed_23-09-2022_12-43-33.csv
# train_data/Respeck_s1921856_Climbing stairs_29-09-2022_16-53-01.csv
# train_data/Respeck_s1921856_Descending stairs_29-09-2022_16-52-01.csv
# train_data/Respeck_s1921856_Desk work_29-09-2022_15-39-01.csv
# train_data/Respeck_s1921856_Lying down left_03-10-2022_19-08-16.csv
# train_data/Respeck_s1921856_Lying down on back_29-09-2022_15-33-23.csv
# train_data/Respeck_s1921856_Lying down on stomach_29-09-2022_15-35-38.csv
# train_data/Respeck_s1921856_Lying down right_03-10-2022_19-09-11.csv
# train_data/Respeck_s1921856_Movement_29-09-2022_15-37-13.csv
# train_data/Respeck_s1921856_Running_29-09-2022_16-09-39.csv
# train_data/Respeck_s1921856_Sitting_03-10-2022_18-57-36.csv
# train_data/Respeck_s1921856_Sitting bent backward_29-09-2022_15-31-44.csv
# train_data/Respeck_s1921856_Sitting bent forward_29-09-2022_15-30-59.csv
# train_data/Respeck_s1921856_Standing_29-09-2022_15-32-32.csv
# train_data/Respeck_s1921856_Walking at normal speed_29-09-2022_15-51-52.csv
# train_data/Respeck_s1923449_Climbing stairs_28-09-2022_15-53-00.csv
# train_data/Respeck_s1923449_Descending stairs_28-09-2022_15-53-52.csv
# train_data/Respeck_s1923449_Desk work_28-09-2022_14-12-35.csv
# train_data/Respeck_s1923449_Lying down left_28-09-2022_14-18-32.csv
# train_data/Respeck_s1923449_Lying down on back_28-09-2022_14-16-36.csv
# train_data/Respeck_s1923449_Lying down on stomach_28-09-2022_14-22-42.csv
# train_data/Respeck_s1923449_Lying down right_28-09-2022_14-20-13.csv
# train_data/Respeck_s1923449_Movement_28-09-2022_15-59-29.csv
# train_data/Respeck_s1923449_Running_28-09-2022_15-41-21.csv
# train_data/Respeck_s1923449_Sitting_28-09-2022_14-03-34.csv
# train_data/Respeck_s1923449_Sitting bent backward_28-09-2022_14-07-57.csv
# train_data/Respeck_s1923449_Sitting bent forward_28-09-2022_14-05-44.csv
# train_data/Respeck_s1923449_Standing_28-09-2022_14-10-59.csv
# train_data/Respeck_s1923449_Walking at normal speed_28-09-2022_15-39-53.csv
# train_data/Respeck_s1923493_Climbing stairs_02-10-2022_15-16-09.csv
# train_data/Respeck_s1923493_Descending stairs_02-10-2022_15-15-07.csv
# train_data/Respeck_s1923493_Desk work_02-10-2022_16-00-59.csv
# train_data/Respeck_s1923493_Lying down left_02-10-2022_16-07-03.csv
# train_data/Respeck_s1923493_Lying down on back_02-10-2022_16-04-08.csv
# train_data/Respeck_s1923493_Lying down on stomach_02-10-2022_16-12-59.csv
# train_data/Respeck_s1923493_Lying down right_02-10-2022_16-09-11.csv
# train_data/Respeck_s1923493_Movement_02-10-2022_13-15-35.csv
# train_data/Respeck_s1923493_Running_02-10-2022_13-37-42.csv
# train_data/Respeck_s1923493_Sitting_02-10-2022_12-39-58.csv
# train_data/Respeck_s1923493_Sitting bent backward_02-10-2022_15-57-00.csv
# train_data/Respeck_s1923493_Sitting bent forward_02-10-2022_12-42-43.csv
# train_data/Respeck_s1923493_Standing_02-10-2022_12-52-25.csv
# train_data/Respeck_s1923493_Walking at normal speed_02-10-2022_13-11-05.csv
# train_data/Respeck_s1925695_Climbing stairs_28-09-2022_15-41-22.csv
# train_data/Respeck_s1925695_Descending stairs_28-09-2022_15-42-28.csv
# train_data/Respeck_s1925695_Desk work_28-09-2022_16-00-36.csv
# train_data/Respeck_s1925695_Lying down left_28-09-2022_15-37-26.csv
# train_data/Respeck_s1925695_Lying down on back_28-09-2022_15-33-35.csv
# train_data/Respeck_s1925695_Lying down on stomach_28-09-2022_15-36-36.csv
# train_data/Respeck_s1925695_Lying down right_28-09-2022_15-34-20.csv
# train_data/Respeck_s1925695_Movement_28-09-2022_15-58-02.csv
# train_data/Respeck_s1925695_Running_28-09-2022_15-52-31.csv
# train_data/Respeck_s1925695_Sitting_28-09-2022_15-26-51.csv
# train_data/Respeck_s1925695_Sitting bent backward_28-09-2022_15-29-53.csv
# train_data/Respeck_s1925695_Sitting bent forward_28-09-2022_15-27-41.csv
# train_data/Respeck_s1925695_Standing_28-09-2022_15-30-57.csv
# train_data/Respeck_s1925695_Walking at normal speed_28-09-2022_15-49-42.csv
# train_data/Respeck_s1925709_Climbing stairs_02-10-2022_18-26-14.csv
# train_data/Respeck_s1925709_Descending stairs_02-10-2022_18-26-57.csv
# train_data/Respeck_s1925709_Desk work_02-10-2022_22-41-34.csv
# train_data/Respeck_s1925709_Lying down left_01-10-2022_21-27-14.csv
# train_data/Respeck_s1925709_Lying down on back_01-10-2022_21-26-02.csv
# train_data/Respeck_s1925709_Lying down on stomach_02-10-2022_22-30-43.csv
# train_data/Respeck_s1925709_Lying down right_01-10-2022_21-28-39.csv
# train_data/Respeck_s1925709_Movement_01-10-2022_21-21-50.csv
# train_data/Respeck_s1925709_Running_03-10-2022_22-01-57.csv
# train_data/Respeck_s1925709_Sitting_02-10-2022_22-40-16.csv
# train_data/Respeck_s1925709_Sitting bent backward_01-10-2022_21-19-58.csv
# train_data/Respeck_s1925709_Sitting bent forward_01-10-2022_21-18-15.csv
# train_data/Respeck_s1925709_Standing_03-10-2022_21-46-19.csv
# train_data/Respeck_s1925709_Walking at normal speed_03-10-2022_21-58-52.csv
# train_data/Respeck_s1925715_Climbing stairs_28-09-2022_13-57-42.csv
# train_data/Respeck_s1925715_Descending stairs_28-09-2022_13-56-59.csv
# train_data/Respeck_s1925715_Desk work_27-09-2022_11-54-35.csv
# train_data/Respeck_s1925715_Lying down left_28-09-2022_12-13-09.csv
# train_data/Respeck_s1925715_Lying down on back_28-09-2022_12-08-38.csv
# train_data/Respeck_s1925715_Lying down on stomach_28-09-2022_17-00-45.csv
# train_data/Respeck_s1925715_Lying down right_28-09-2022_12-14-33.csv
# train_data/Respeck_s1925715_Movement_27-09-2022_11-55-57.csv
# train_data/Respeck_s1925715_Running_28-09-2022_14-24-20.csv
# train_data/Respeck_s1925715_Sitting_28-09-2022_17-24-21.csv
# train_data/Respeck_s1925715_Sitting bent backward_27-09-2022_11-51-30.csv
# train_data/Respeck_s1925715_Sitting bent forward_28-09-2022_17-22-23.csv
# train_data/Respeck_s1925715_Standing_28-09-2022_16-57-28.csv
# train_data/Respeck_s1925715_Walking at normal speed_28-09-2022_14-26-03.csv
# train_data/Respeck_s1926989_Climbing stairs_03-10-2022_17-15-49.csv
# train_data/Respeck_s1926989_Descending stairs_03-10-2022_17-10-22.csv
# train_data/Respeck_s1926989_Desk work_03-10-2022_17-08-04.csv
# train_data/Respeck_s1926989_Lying down left_03-10-2022_17-04-42.csv
# train_data/Respeck_s1926989_Lying down on back_03-10-2022_17-04-02.csv
# train_data/Respeck_s1926989_Lying down on stomach_03-10-2022_17-06-19.csv
# train_data/Respeck_s1926989_Lying down right_03-10-2022_17-05-36.csv
# train_data/Respeck_s1926989_Movement_03-10-2022_17-07-08.csv
# train_data/Respeck_s1926989_Running_03-10-2022_17-13-11.csv
# train_data/Respeck_s1926989_Sitting_03-10-2022_17-01-17.csv
# train_data/Respeck_s1926989_Sitting bent backward_03-10-2022_17-02-32.csv
# train_data/Respeck_s1926989_Sitting bent forward_03-10-2022_17-01-54.csv
# train_data/Respeck_s1926989_Standing_03-10-2022_17-03-12.csv
# train_data/Respeck_s1926989_Walking at normal speed_03-10-2022_17-11-41.csv
# train_data/Respeck_s1927811_Climbing stairs_01-10-2022_20-41-41.csv
# train_data/Respeck_s1927811_Descending stairs_01-10-2022_20-42-41.csv
# train_data/Respeck_s1927811_Desk work_29-09-2022_12-15-27.csv
# train_data/Respeck_s1927811_Lying down left_29-09-2022_12-09-34.csv
# train_data/Respeck_s1927811_Lying down on back_29-09-2022_12-08-50.csv
# train_data/Respeck_s1927811_Lying down on stomach_29-09-2022_12-10-59.csv
# train_data/Respeck_s1927811_Lying down right_29-09-2022_12-10-17.csv
# train_data/Respeck_s1927811_Movement_02-10-2022_20-46-08.csv
# train_data/Respeck_s1927811_Running_29-09-2022_12-56-28.csv
# train_data/Respeck_s1927811_Sitting_29-09-2022_12-05-07.csv
# train_data/Respeck_s1927811_Sitting bent backward_29-09-2022_12-07-18.csv
# train_data/Respeck_s1927811_Sitting bent forward_29-09-2022_12-06-09.csv
# train_data/Respeck_s1927811_Standing_29-09-2022_12-08-01.csv
# train_data/Respeck_s1927811_Walking at normal speed_29-09-2022_12-53-45.csv
# train_data/Respeck_s1931698_Climbing stairs_26-09-2022_17-34-21.csv
# train_data/Respeck_s1931698_Descending stairs_26-09-2022_17-35-13.csv
# train_data/Respeck_s1931698_Desk work_03-10-2022_22-27-55.csv
# train_data/Respeck_s1931698_Lying down left_02-10-2022_16-43-46.csv
# train_data/Respeck_s1931698_Lying down on back_02-10-2022_16-40-38.csv
# train_data/Respeck_s1931698_Lying down on stomach_02-10-2022_16-49-26.csv
# train_data/Respeck_s1931698_Lying down right_03-10-2022_22-22-49.csv
# train_data/Respeck_s1931698_Movement_03-10-2022_22-29-26.csv
# train_data/Respeck_s1931698_Running_03-10-2022_22-35-55.csv
# train_data/Respeck_s1931698_Sitting_03-10-2022_22-06-06.csv
# train_data/Respeck_s1931698_Sitting bent backward_03-10-2022_22-09-06.csv
# train_data/Respeck_s1931698_Sitting bent forward_03-10-2022_22-07-40.csv
# train_data/Respeck_s1931698_Standing_03-10-2022_22-10-32.csv
# train_data/Respeck_s1931698_Walking at normal speed_03-10-2022_22-33-49.csv
# train_data/Respeck_s1931736_Climbing stairs_29-09-2022_16-58-39.csv
# train_data/Respeck_s1931736_Descending stairs_29-09-2022_16-57-47.csv
# train_data/Respeck_s1931736_Desk work_04-10-2022_22-26-14.csv
# train_data/Respeck_s1931736_Lying down left_04-10-2022_21-17-37.csv
# train_data/Respeck_s1931736_Lying down on back_04-10-2022_21-16-42.csv
# train_data/Respeck_s1931736_Lying down on stomach_04-10-2022_21-19-35.csv
# train_data/Respeck_s1931736_Lying down right_04-10-2022_21-18-29.csv
# train_data/Respeck_s1931736_Movement_04-10-2022_21-20-18.csv
# train_data/Respeck_s1931736_Running_29-09-2022_18-24-05.csv
# train_data/Respeck_s1931736_Sitting_04-10-2022_21-22-46.csv
# train_data/Respeck_s1931736_Sitting bent backward_04-10-2022_21-24-50.csv
# train_data/Respeck_s1931736_Sitting bent forward_04-10-2022_21-23-31.csv
# train_data/Respeck_s1931736_Standing_04-10-2022_21-15-50.csv
# train_data/Respeck_s1931736_Walking at normal speed_29-09-2022_18-16-14.csv
# train_data/Respeck_s1941321_Climbing stairs_26-09-2022_17-36-38.csv
# train_data/Respeck_s1941321_Descending stairs_26-09-2022_17-37-30.csv
# train_data/Respeck_s1941321_Desk work_04-10-2022_10-58-10.csv
# train_data/Respeck_s1941321_Lying down left_02-10-2022_17-34-13.csv
# train_data/Respeck_s1941321_Lying down on back_02-10-2022_17-31-58.csv
# train_data/Respeck_s1941321_Lying down on stomach_02-10-2022_17-38-58.csv
# train_data/Respeck_s1941321_Lying down right_02-10-2022_17-36-14.csv
# train_data/Respeck_s1941321_Movement_04-10-2022_10-59-19.csv
# train_data/Respeck_s1941321_Running_04-10-2022_11-10-47.csv
# train_data/Respeck_s1941321_Sitting_04-10-2022_10-52-21.csv
# train_data/Respeck_s1941321_Sitting bent backward_04-10-2022_10-54-23.csv
# train_data/Respeck_s1941321_Sitting bent forward_04-10-2022_10-53-18.csv
# train_data/Respeck_s1941321_Standing_04-10-2022_10-56-06.csv
# train_data/Respeck_s1941321_Walking at normal speed_04-10-2022_11-09-11.csv
# train_data/Respeck_s1948094_Climbing stairs_23-09-2022_12-51-37.csv
# train_data/Respeck_s1948094_Descending stairs_23-09-2022_12-53-24.csv
# train_data/Respeck_s1948094_Desk work_23-09-2022_12-01-53.csv
# train_data/Respeck_s1948094_Lying down left_23-09-2022_11-54-37.csv
# train_data/Respeck_s1948094_Lying down on back_23-09-2022_11-59-08.csv
# train_data/Respeck_s1948094_Lying down on stomach_23-09-2022_11-57-49.csv
# train_data/Respeck_s1948094_Lying down right_23-09-2022_11-56-22.csv
# train_data/Respeck_s1948094_Movement_23-09-2022_12-58-07.csv
# train_data/Respeck_s1948094_Running_23-09-2022_12-54-29.csv
# train_data/Respeck_s1948094_Sitting_23-09-2022_11-45-44.csv
# train_data/Respeck_s1948094_Sitting bent backward_23-09-2022_11-50-08.csv
# train_data/Respeck_s1948094_Sitting bent forward_23-09-2022_11-48-20.csv
# train_data/Respeck_s1948094_Standing_23-09-2022_11-51-34.csv
# train_data/Respeck_s1948094_Walking at normal speed_23-09-2022_12-49-50.csv
# train_data/Respeck_s1951693_Climbing stairs_05-10-2022_16-29-06.csv
# train_data/Respeck_s1951693_Descending stairs_05-10-2022_16-30-17.csv
# train_data/Respeck_s1951693_Desk work_23-09-2022_16-44-08.csv
# train_data/Respeck_s1951693_Lying down left_23-09-2022_16-36-03.csv
# train_data/Respeck_s1951693_Lying down on back_23-09-2022_16-40-05.csv
# train_data/Respeck_s1951693_Lying down on stomach_23-09-2022_16-38-45.csv
# train_data/Respeck_s1951693_Lying down right_30-09-2022_16-37-22.csv
# train_data/Respeck_s1951693_Movement_23-09-2022_16-45-32.csv
# train_data/Respeck_s1951693_Running_23-09-2022_17-02-52.csv
# train_data/Respeck_s1951693_Sitting_23-09-2022_16-30-37.csv
# train_data/Respeck_s1951693_Sitting bent backward_30-09-2022_16-39-15.csv
# train_data/Respeck_s1951693_Sitting bent forward_30-09-2022_16-41-04.csv
# train_data/Respeck_s1951693_Standing_23-09-2022_16-34-33.csv
# train_data/Respeck_s1951693_Walking at normal speed_06-10-2022_16-05-24.csv
# train_data/Respeck_s1951735_Climbing stairs_03-10-2022_15-25-00.csv
# train_data/Respeck_s1951735_Descending stairs_07-10-2022_02-02-48.csv
# train_data/Respeck_s1951735_Desk work_03-10-2022_02-23-13.csv
# train_data/Respeck_s1951735_Lying down left_03-10-2022_02-15-10.csv
# train_data/Respeck_s1951735_Lying down on back_03-10-2022_02-11-28.csv
# train_data/Respeck_s1951735_Lying down on stomach_03-10-2022_02-19-39.csv
# train_data/Respeck_s1951735_Lying down right_03-10-2022_02-16-50.csv
# train_data/Respeck_s1951735_Movement_03-10-2022_13-27-29.csv
# train_data/Respeck_s1951735_Running_03-10-2022_13-58-49.csv
# train_data/Respeck_s1951735_Sitting_03-10-2022_00-40-18.csv
# train_data/Respeck_s1951735_Sitting bent backward_03-10-2022_00-55-12.csv
# train_data/Respeck_s1951735_Sitting bent forward_03-10-2022_00-44-38.csv
# train_data/Respeck_s1951735_Standing_03-10-2022_00-57-24.csv
# train_data/Respeck_s1951735_Walking at normal speed_03-10-2022_14-46-41.csv
# train_data/Respeck_s1956488_Climbing stairs_02-10-2022_15-38-43.csv
# train_data/Respeck_s1956488_Descending stairs_02-10-2022_15-39-30.csv
# train_data/Respeck_s1956488_Desk work_02-10-2022_15-41-47.csv
# train_data/Respeck_s1956488_Lying down left_02-10-2022_15-36-25.csv
# train_data/Respeck_s1956488_Lying down on back_02-10-2022_15-34-42.csv
# train_data/Respeck_s1956488_Lying down on stomach_06-10-2022_14-44-39.csv
# train_data/Respeck_s1956488_Lying down right_06-10-2022_14-43-25.csv
# train_data/Respeck_s1956488_Movement_02-10-2022_15-45-00.csv
# train_data/Respeck_s1956488_Running_05-10-2022_10-16-38.csv
# train_data/Respeck_s1956488_Sitting_02-10-2022_15-29-10.csv
# train_data/Respeck_s1956488_Sitting bent backward_02-10-2022_15-30-54.csv
# train_data/Respeck_s1956488_Sitting bent forward_02-10-2022_15-31-42.csv
# train_data/Respeck_s1956488_Standing_02-10-2022_15-42-59.csv
# train_data/Respeck_s1956488_Walking at normal speed_05-10-2022_10-15-31.csv
# train_data/Respeck_s1957847_Climbing stairs_05-10-2022_17-05-30.csv
# train_data/Respeck_s1957847_Descending stairs_05-10-2022_17-04-39.csv
# train_data/Respeck_s1957847_Desk work_05-10-2022_13-55-03.csv
# train_data/Respeck_s1957847_Lying down left_05-10-2022_10-56-09.csv
# train_data/Respeck_s1957847_Lying down on back_05-10-2022_10-51-45.csv
# train_data/Respeck_s1957847_Lying down on stomach_05-10-2022_10-57-15.csv
# train_data/Respeck_s1957847_Lying down right_05-10-2022_13-59-03.csv
# train_data/Respeck_s1957847_Movement_05-10-2022_11-12-30.csv
# train_data/Respeck_s1957847_Running_05-10-2022_11-22-43.csv
# train_data/Respeck_s1957847_Sitting_05-10-2022_13-40-26.csv
# train_data/Respeck_s1957847_Sitting bent backward_05-10-2022_13-44-16.csv
# train_data/Respeck_s1957847_Sitting bent forward_05-10-2022_13-48-22.csv
# train_data/Respeck_s1957847_Standing_28-09-2022_10-34-06.csv
# train_data/Respeck_s1957847_Walking at normal speed_05-10-2022_11-20-52.csv
# train_data/Respeck_s1957945_Climbing stairs_05-10-2022_17-18-13.csv
# train_data/Respeck_s1957945_Descending stairs_05-10-2022_17-26-46.csv
# train_data/Respeck_s1957945_Desk work_03-10-2022_16-05-44.csv
# train_data/Respeck_s1957945_Lying down left_03-10-2022_16-19-27.csv
# train_data/Respeck_s1957945_Lying down on back_03-10-2022_16-17-02.csv
# train_data/Respeck_s1957945_Lying down on stomach_03-10-2022_16-11-05.csv
# train_data/Respeck_s1957945_Lying down right_03-10-2022_16-14-16.csv
# train_data/Respeck_s1957945_Movement_03-10-2022_16-25-16.csv
# train_data/Respeck_s1957945_Running_03-10-2022_16-40-34.csv
# ...
# train_data/Thingy_s1870697_Sitting bent forward_03-10-2021_13-50-01.csv
# train_data/Thingy_s1870697_Standing_05-10-2021_02-32-49.csv
# train_data/Thingy_s1870697_Walking at normal speed_03-10-2021_17-36-05.csv
# train_data/Thingy_s1891214_Climbing stairs_07-10-2021_15-45-21.csv
# train_data/Thingy_s1891214_Descending stairs_07-10-2021_15-44-25.csv
# train_data/Thingy_s1891214_Desk work_07-10-2021_15-48-28.csv
# train_data/Thingy_s1891214_Lying down left_07-10-2021_15-39-15.csv
# train_data/Thingy_s1891214_Lying down on back_07-10-2021_15-38-33.csv
# train_data/Thingy_s1891214_Lying down on stomach_07-10-2021_15-40-44.csv
# train_data/Thingy_s1891214_Lying down right_07-10-2021_15-39-56.csv
# train_data/Thingy_s1891214_Movement_07-10-2021_15-46-20.csv
# train_data/Thingy_s1891214_Running_07-10-2021_15-43-21.csv
# train_data/Thingy_s1891214_Sitting_07-10-2021_15-37-05.csv
# train_data/Thingy_s1891214_Sitting bent backward_07-10-2021_15-28-08.csv
# train_data/Thingy_s1891214_Sitting bent forward_07-10-2021_15-26-49.csv
# train_data/Thingy_s1891214_Standing_07-10-2021_15-37-44.csv
# train_data/Thingy_s1893474_Running_06-10-2021_00-06-50.csv
# train_data/Thingy_s1891214_Walking at normal speed_07-10-2021_15-42-34.csv
# train_data/Thingy_s1893474_Climbing stairs_07-10-2021_20-25-35.csv
# train_data/Thingy_s1893474_Descending stairs_07-10-2021_21-03-52.csv
# train_data/Thingy_s1893474_Desk work_08-10-2021_11-23-05.csv
# train_data/Thingy_s1893474_Lying down left_06-10-2021_23-48-02.csv
# train_data/Thingy_s1893474_Lying down on back_06-10-2021_23-44-37.csv
# train_data/Thingy_s1893474_Lying down on stomach_07-10-2021_01-55-31.csv
# train_data/Thingy_s1893474_Lying down right_07-10-2021_01-54-16.csv
# train_data/Thingy_s1893474_Movement_07-10-2021_11-27-18.csv
# train_data/Thingy_s1893474_Sitting_07-10-2021_01-03-33.csv
# train_data/Thingy_s1893474_Sitting bent backward_03-10-2021_19-10-32.csv
# train_data/Thingy_s1893474_Sitting bent forward_06-10-2021_23-40-14.csv
# train_data/Thingy_s1893474_Standing_06-10-2021_23-41-34.csv
# train_data/Thingy_s1893474_Walking at normal speed_04-10-2021_18-10-54.csv
# train_data/Thingy_s1893835_Climbing stairs_06-10-2021_11-21-31.csv
# train_data/Thingy_s1893835_Descending stairs_06-10-2021_11-22-44.csv
# train_data/Thingy_s1893835_Desk work_29-09-2021_11-01-15.csv
# train_data/Thingy_s1893835_Lying down left_29-09-2021_10-58-52.csv
# train_data/Thingy_s1893835_Lying down on back_29-09-2021_10-57-13.csv
# train_data/Thingy_s1893835_Lying down on stomach_29-09-2021_10-59-44.csv
# train_data/Thingy_s1893835_Lying down right_29-09-2021_10-58-05.csv
# train_data/Thingy_s1893835_Movement_29-09-2021_11-13-52.csv
# train_data/Thingy_s1893835_Sitting_29-09-2021_10-53-14.csv
# train_data/Thingy_s1893835_Sitting bent backward_29-09-2021_10-54-48.csv
# train_data/Thingy_s1893835_Sitting bent forward_29-09-2021_10-54-01.csv
# train_data/Thingy_s1893835_Standing_29-09-2021_10-55-38.csv
# train_data/Thingy_s1894401_Climbing stairs_01-10-2021_11-43-53.csv
# train_data/Thingy_s1894401_Descending stairs_01-10-2021_11-46-15.csv
# train_data/Thingy_s1894401_Desk work_06-10-2021_10-32-29.csv
# train_data/Thingy_s1894401_Lying down left_01-10-2021_11-29-38.csv
# train_data/Thingy_s1894401_Lying down on back_06-10-2021_10-29-12.csv
# train_data/Thingy_s1894401_Lying down on stomach_01-10-2021_11-27-46.csv
# train_data/Thingy_s1894401_Lying down right_06-10-2021_10-30-33.csv
# train_data/Thingy_s1894401_Movement_01-10-2021_11-22-15.csv
# train_data/Thingy_s1894401_Running_01-10-2021_12-24-01.csv
# train_data/Thingy_s1894401_Sitting_01-10-2021_11-32-50.csv
# train_data/Thingy_s1894401_Sitting bent backward_01-10-2021_11-31-20.csv
# train_data/Thingy_s1894401_Sitting bent forward_01-10-2021_11-32-05.csv
# train_data/Thingy_s1894401_Standing_01-10-2021_11-30-30.csv
# train_data/Thingy_s1894401_Walking at normal speed_01-10-2021_12-19-13.csv
# train_data/Thingy_s1970333_Climbing stairs_13-10-2021_23-35-47.csv
# train_data/Thingy_s1970333_Descending stairs_13-10-2021_23-36-28.csv
# train_data/Thingy_s1970333_Desk work_15-10-2021_02-30-14.csv
# train_data/Thingy_s1970333_Lying down left_13-10-2021_21-33-10.csv
# train_data/Thingy_s1970333_Lying down on back_13-10-2021_21-36-19.csv
# train_data/Thingy_s1970333_Lying down on stomach_13-10-2021_21-40-53.csv
# train_data/Thingy_s1970333_Lying down right_13-10-2021_21-37-27.csv
# train_data/Thingy_s1970333_Movement_13-10-2021_21-55-05.csv
# train_data/Thingy_s1970333_Running_13-10-2021_22-15-18.csv
# train_data/Thingy_s1970333_Sitting_13-10-2021_21-20-58.csv
# train_data/Thingy_s1970333_Sitting bent backward_13-10-2021_21-26-48.csv
# train_data/Thingy_s1970333_Sitting bent forward_13-10-2021_21-28-19.csv
# train_data/Thingy_s1970333_Standing_13-10-2021_21-29-53.csv
# train_data/Thingy_s1970333_Walking at normal speed_13-10-2021_22-03-21.csv
# train_data/Thingy_s2119637_Climbing stairs_03-10-2021_23-40-48.csv
# train_data/Thingy_s2119637_Descending stairs_03-10-2021_23-37-19.csv
# train_data/Thingy_s2119637_Desk work_03-10-2021_23-22-43.csv
# train_data/Thingy_s2119637_Lying down left_03-10-2021_23-17-46.csv
# train_data/Thingy_s2119637_Lying down on back_03-10-2021_23-21-36.csv
# train_data/Thingy_s2119637_Lying down on stomach_03-10-2021_23-19-46.csv
# train_data/Thingy_s2119637_Lying down right_03-10-2021_23-18-46.csv
# train_data/Thingy_s2119637_Movement_03-10-2021_23-23-45.csv
# train_data/Thingy_s2119637_Running_03-10-2021_23-39-22.csv
# train_data/Thingy_s2119637_Sitting_03-10-2021_23-13-50.csv
# train_data/Thingy_s2119637_Sitting bent backward_03-10-2021_23-15-47.csv
# train_data/Thingy_s2119637_Sitting bent forward_03-10-2021_23-14-57.csv
# train_data/Thingy_s2119637_Standing_03-10-2021_23-16-46.csv
# train_data/Thingy_s2119637_Walking at normal speed_03-10-2021_23-38-32.csv
# train_data/Thingy_s2125423_Climbing stairs_03-10-2021_17-24-27.csv
# train_data/Thingy_s2125423_Running_03-10-2021_17-36-32.csv
# train_data/Thingy_s2125423_Descending stairs_03-10-2021_17-23-15.csv
# train_data/Thingy_s2125423_Desk work_03-10-2021_16-07-18.csv
# train_data/Thingy_s2125423_Lying down left_03-10-2021_15-56-19.csv
# train_data/Thingy_s2125423_Lying down on back_03-10-2021_15-59-43.csv
# train_data/Thingy_s2125423_Lying down on stomach_03-10-2021_16-02-14.csv
# train_data/Thingy_s2125423_Lying down right_03-10-2021_15-58-03.csv
# train_data/Thingy_s2125423_Movement_03-10-2021_16-05-35.csv
# train_data/Thingy_s2125423_Sitting_03-10-2021_15-49-55.csv
# train_data/Thingy_s2125423_Sitting bent backward_03-10-2021_15-52-45.csv
# train_data/Thingy_s2125423_Sitting bent forward_03-10-2021_15-51-20.csv
# train_data/Thingy_s2125423_Standing_03-10-2021_15-54-13.csv
# train_data/Thingy_s2125423_Walking at normal speed_03-10-2021_17-34-37.csv
# train_data/Thingy_s2171825_Climbing stairs_03-10-2021_22-07-33.csv
# train_data/Thingy_s2171825_Descending stairs_03-10-2021_22-04-20.csv
# train_data/Thingy_s2171825_Desk work_03-10-2021_21-35-04.csv
# train_data/Thingy_s2171825_Lying down left_03-10-2021_21-25-25.csv
# train_data/Thingy_s2171825_Lying down on back_03-10-2021_21-33-30.csv
# train_data/Thingy_s2171825_Lying down on stomach_03-10-2021_21-28-46.csv
# train_data/Thingy_s2171825_Lying down right_03-10-2021_21-26-29.csv
# train_data/Thingy_s2171825_Movement_03-10-2021_21-37-14.csv
# train_data/Thingy_s2171825_Running_03-10-2021_22-06-21.csv
# train_data/Thingy_s2171825_Sitting_03-10-2021_21-11-04.csv
# train_data/Thingy_s2171825_Sitting bent backward_03-10-2021_21-19-26.csv
# train_data/Thingy_s2171825_Sitting bent forward_03-10-2021_21-18-09.csv
# train_data/Thingy_s2171825_Standing_03-10-2021_21-23-34.csv
# train_data/Thingy_s2171825_Walking at normal speed_03-10-2021_22-05-34.csv
# train_data/Thingy_s2171931_Climbing stairs_04-10-2021_14-39-09.csv
# train_data/Thingy_s2171931_Descending stairs_04-10-2021_14-33-27.csv
# train_data/Thingy_s2171931_Desk work_04-10-2021_13-28-49.csv
# train_data/Thingy_s2171931_Lying down left_04-10-2021_13-32-06.csv
# train_data/Thingy_s2171931_Running_04-10-2021_14-36-07.csv
# train_data/Thingy_s2171931_Lying down on back_04-10-2021_13-31-16.csv
# train_data/Thingy_s2171931_Lying down on stomach_04-10-2021_13-33-48.csv
# train_data/Thingy_s2171931_Lying down right_04-10-2021_13-32-50.csv
# train_data/Thingy_s2171931_Movement_04-10-2021_13-29-33.csv
# train_data/Thingy_s2171931_Sitting_06-10-2021_16-23-40.csv
# train_data/Thingy_s2171931_Sitting bent backward_04-10-2021_13-27-09.csv
# train_data/Thingy_s2171931_Sitting bent forward_06-10-2021_16-14-08.csv
# train_data/Thingy_s2171931_Standing_06-10-2021_16-33-59.csv
# train_data/Thingy_s2171931_Walking at normal speed_04-10-2021_14-35-01.csv
# train_data/Thingy_s2173036_Climbing stairs_03-10-2021_23-05-41.csv
# train_data/Thingy_s2173036_Descending stairs_03-10-2021_23-01-59.csv
# train_data/Thingy_s2173036_Desk work_03-10-2021_22-47-00.csv
# train_data/Thingy_s2173036_Lying down left_03-10-2021_22-42-14.csv
# train_data/Thingy_s2173036_Lying down on back_03-10-2021_22-45-16.csv
# train_data/Thingy_s2173036_Lying down on stomach_03-10-2021_22-44-23.csv
# train_data/Thingy_s2173036_Lying down right_03-10-2021_22-43-14.csv
# train_data/Thingy_s2173036_Movement_03-10-2021_22-51-03.csv
# train_data/Thingy_s2173036_Running_03-10-2021_23-04-04.csv
# train_data/Thingy_s2173036_Sitting_03-10-2021_22-36-58.csv
# train_data/Thingy_s2173036_Sitting bent backward_03-10-2021_22-38-55.csv
# train_data/Thingy_s2173036_Sitting bent forward_03-10-2021_22-38-00.csv
# train_data/Thingy_s2173036_Standing_03-10-2021_22-39-54.csv
# train_data/Thingy_s2173036_Walking at normal speed_03-10-2021_23-03-07.csv
# train_data/Thingy_s2181154_Climbing stairs_03-10-2021_17-17-08.csv
# train_data/Thingy_s2181154_Descending stairs_03-10-2021_17-16-29.csv
# train_data/Thingy_s2181154_Desk work_03-10-2021_17-10-22.csv
# train_data/Thingy_s2181154_Lying down left_29-09-2021_13-52-28.csv
# train_data/Thingy_s2181154_Lying down on back_29-09-2021_13-51-47.csv
# train_data/Thingy_s2181154_Lying down on stomach_29-09-2021_13-53-57.csv
# train_data/Thingy_s2181154_Lying down right_03-10-2021_17-14-00.csv
# train_data/Thingy_s2181154_Movement_29-09-2021_13-54-44.csv
# train_data/Thingy_s2181154_Running_29-09-2021_13-41-46.csv
# train_data/Thingy_s2181154_Sitting_03-10-2021_16-46-28.csv
# train_data/Thingy_s2181154_Sitting bent backward_03-10-2021_16-48-24.csv
# train_data/Thingy_s2181154_Sitting bent forward_03-10-2021_16-50-36.csv
# train_data/Thingy_s2181154_Standing_03-10-2021_17-09-26.csv
# train_data/Thingy_s2181154_Walking at normal speed_29-09-2021_13-40-54.csv
# train_data/Thingy_s2192970_Climbing stairs_29-09-2021_17-45-16.csv
# train_data/Thingy_s2192970_Descending stairs_29-09-2021_17-45-54.csv
# train_data/Thingy_s2192970_Desk work_29-09-2021_18-03-58.csv
# train_data/Thingy_s2192970_Lying down left_29-09-2021_17-56-33.csv
# train_data/Thingy_s2192970_Lying down on back_29-09-2021_17-55-11.csv
# train_data/Thingy_s2192970_Lying down on stomach_29-09-2021_18-01-37.csv
# train_data/Thingy_s2192970_Lying down right_29-09-2021_17-58-16.csv
# train_data/Thingy_s2192970_Movement_29-09-2021_17-42-21.csv
# train_data/Thingy_s2192970_Running_29-09-2021_17-38-31.csv
# train_data/Thingy_s2192970_Sitting_07-10-2021_21-46-25.csv
# train_data/Thingy_s2192970_Sitting bent backward_07-10-2021_21-47-56.csv
# train_data/Thingy_s2192970_Sitting bent forward_07-10-2021_21-47-10.csv
# train_data/Thingy_s2192970_Standing_06-10-2021_22-42-04.csv
# train_data/Thingy_s2192970_Walking at normal speed_29-09-2021_17-37-53.csv
# train_data/Thingy_s2211162_Climbing stairs_06-10-2021_10-01-57.csv
# train_data/Thingy_s2211162_Running_06-10-2021_10-00-07.csv
# train_data/Thingy_s2211162_Descending stairs_06-10-2021_09-56-27.csv
# train_data/Thingy_s2211162_Desk work_06-10-2021_09-18-24.csv
# train_data/Thingy_s2211162_Lying down left_06-10-2021_09-13-00.csv
# train_data/Thingy_s2211162_Lying down on back_06-10-2021_09-11-52.csv
# train_data/Thingy_s2211162_Lying down on stomach_06-10-2021_09-15-28.csv
# train_data/Thingy_s2211162_Lying down right_06-10-2021_09-14-09.csv
# train_data/Thingy_s2211162_Movement_06-10-2021_09-21-56.csv
# train_data/Thingy_s2211162_Sitting_06-10-2021_09-04-52.csv
# train_data/Thingy_s2211162_Sitting bent backward_06-10-2021_09-09-43.csv
# train_data/Thingy_s2211162_Sitting bent forward_06-10-2021_09-07-19.csv
# train_data/Thingy_s2211162_Standing_06-10-2021_09-10-30.csv
# train_data/Thingy_s2211162_Walking at normal speed_06-10-2021_09-55-01.csv
# train_data/Thingy_s2211228_Climbing stairs_07-10-2021_23-20-08.csv
# train_data/Thingy_s2211228_Descending stairs_07-10-2021_23-20-56.csv
# train_data/Thingy_s2211228_Desk work_06-10-2021_19-40-25.csv
# train_data/Thingy_s2211228_Lying down left_06-10-2021_19-44-51.csv
# train_data/Thingy_s2211228_Lying down on back_29-09-2021_16-42-54.csv
# train_data/Thingy_s2211228_Lying down on stomach_29-09-2021_16-40-44.csv
# train_data/Thingy_s2211228_Lying down right_06-10-2021_23-57-33.csv
# train_data/Thingy_s2211228_Movement_06-10-2021_19-49-31.csv
# train_data/Thingy_s2211228_Running_29-09-2021_17-27-55.csv
# train_data/Thingy_s2211228_Sitting_29-09-2021_16-46-08.csv
# train_data/Thingy_s2211228_Sitting bent backward_29-09-2021_16-44-48.csv
# train_data/Thingy_s2211228_Sitting bent forward_29-09-2021_16-45-26.csv
# train_data/Thingy_s2211228_Standing_06-10-2021_19-41-21.csv
# train_data/Thingy_s2211228_Walking at normal speed_06-10-2021_19-48-08.csv
# train_data/Thingy_s2212045_Climbing stairs_29-09-2021_13-37-28.csv
# train_data/Thingy_s2212045_Descending stairs_29-09-2021_13-36-47.csv
# train_data/Thingy_s2212045_Desk work_29-09-2021_11-59-56.csv
# train_data/Thingy_s2212045_Lying down left_29-09-2021_11-57-39.csv
# train_data/Thingy_s2212045_Running_29-09-2021_13-38-58.csv
# train_data/Thingy_s2212045_Lying down on back_29-09-2021_11-56-56.csv
# train_data/Thingy_s2212045_Lying down on stomach_29-09-2021_11-59-03.csv
# train_data/Thingy_s2212045_Lying down right_29-09-2021_11-58-22.csv
# train_data/Thingy_s2212045_Movement_29-09-2021_12-00-40.csv
# train_data/Thingy_s2212045_Sitting_03-10-2021_17-18-53.csv
# train_data/Thingy_s2212045_Sitting bent backward_03-10-2021_17-23-22.csv
# train_data/Thingy_s2212045_Sitting bent forward_03-10-2021_17-19-36.csv
# train_data/Thingy_s2212045_Standing_29-09-2021_11-55-58.csv
# train_data/Thingy_s2212045_Walking at normal speed_29-09-2021_13-38-22.csv
# train_data/Thingy_s2250677_Climbing stairs_06-10-2021_13-43-53.csv
# train_data/Thingy_s2250677_Descending stairs_06-10-2021_13-45-01.csv
# train_data/Thingy_s2250677_Desk work_06-10-2021_13-48-25.csv
# train_data/Thingy_s2250677_Lying down left_06-10-2021_13-36-02.csv
# train_data/Thingy_s2250677_Lying down on back_06-10-2021_13-35-16.csv
# train_data/Thingy_s2250677_Lying down on stomach_06-10-2021_13-37-50.csv
# train_data/Thingy_s2250677_Lying down right_06-10-2021_13-36-55.csv
# train_data/Thingy_s2250677_Movement_06-10-2021_13-47-06.csv
# train_data/Thingy_s2250677_Running_06-10-2021_13-41-40.csv
# train_data/Thingy_s2250677_Sitting_06-10-2021_13-31-43.csv
# train_data/Thingy_s2250677_Sitting bent backward_06-10-2021_13-33-25.csv
# train_data/Thingy_s2250677_Sitting bent forward_06-10-2021_13-32-31.csv
# train_data/Thingy_s2250677_Standing_06-10-2021_13-34-16.csv
# train_data/Thingy_s2250677_Walking at normal speed_06-10-2021_13-40-35.csv
# train_data/Thingy_s2254050_Climbing stairs_29-09-2021_19-38-48.csv
# train_data/Thingy_s2254050_Descending stairs_29-09-2021_19-39-25.csv
# train_data/Thingy_s2254050_Desk work_02-10-2021_17-22-18.csv
# train_data/Thingy_s2254050_Lying down left_29-09-2021_19-22-26.csv
# train_data/Thingy_s2254050_Lying down on back_29-09-2021_19-21-47.csv
# train_data/Thingy_s2254050_Lying down on stomach_29-09-2021_19-23-57.csv
# train_data/Thingy_s2254050_Lying down right_29-09-2021_19-23-04.csv
# train_data/Thingy_s2254050_Movement_29-09-2021_19-24-36.csv
# train_data/Thingy_s2254050_Running_29-09-2021_19-36-50.csv
# train_data/Thingy_s2254050_Sitting_02-10-2021_17-27-09.csv
# train_data/Thingy_s2254050_Sitting bent backward_02-10-2021_17-33-11.csv
# train_data/Thingy_s2254050_Sitting bent forward_29-09-2021_19-19-18.csv
# train_data/Thingy_s2254050_Standing_29-09-2021_19-20-37.csv
# train_data/Thingy_s2254050_Walking at normal speed_29-09-2021_19-36-14.csv

# %%
len(base_df)
# Out:
# 2608100

# %% [markdown]
# Reset the index of the base DataFrame.

# %%
base_df.reset_index(drop=True, inplace=True)
base_df
# Out:
#             timestamp   accel_x   accel_y   accel_z      gyro_x      gyro_y  \
# 0        1.664890e+12  0.125977 -1.205872  0.143982   16.125000    6.187500
# 1        1.664890e+12  0.104004 -0.896057  0.059509   15.468750    6.812500
# 2        1.664890e+12  0.087402 -1.044495  0.060974    1.953125   -5.453125
# 3        1.664890e+12  0.058594 -0.935364  0.096619   -4.015625   -5.156250
# 4        1.664890e+12 -0.037842 -0.858215  0.167419   -9.843750   -7.828125
# ...               ...       ...       ...       ...         ...         ...
# 2608095  1.632941e+12 -1.128906 -0.014648 -0.200195 -147.968750  126.937500
# 2608096  1.632941e+12 -1.073242 -0.187500 -0.044922 -100.843750  105.812500
# 2608097  1.632941e+12 -0.988281  0.059570 -0.035156   19.406250   43.812500
# 2608098  1.632941e+12 -0.891602  0.082031 -0.016602   25.187500   55.343750
# 2608099  1.632941e+12 -0.998047  0.133789  0.102539   -1.343750   51.312500
#
#             gyro_z sensor_type            activity_type  activity_code  \
# 0         9.515625     Respeck          Climbing stairs             12
# 1        18.062500     Respeck          Climbing stairs             12
# 2        15.625000     Respeck          Climbing stairs             12
# 3        10.718750     Respeck          Climbing stairs             12
# 4         9.671875     Respeck          Climbing stairs             12
# ...            ...         ...                      ...            ...
# 2608095  23.781250      Thingy  Walking at normal speed              1
# 2608096  -2.937500      Thingy  Walking at normal speed              1
# 2608097 -19.781250      Thingy  Walking at normal speed              1
# 2608098 -16.375000      Thingy  Walking at normal speed              1
# 2608099 -15.875000      Thingy  Walking at normal speed              1
#
#         subject_id notes                                       recording_id  \
# 0         s1732873   1.0  Respeck_s1732873_Climbing stairs_04-10-2022_14...
# 1         s1732873   1.0  Respeck_s1732873_Climbing stairs_04-10-2022_14...
# 2         s1732873   1.0  Respeck_s1732873_Climbing stairs_04-10-2022_14...
# 3         s1732873   1.0  Respeck_s1732873_Climbing stairs_04-10-2022_14...
# 4         s1732873   1.0  Respeck_s1732873_Climbing stairs_04-10-2022_14...
# ...            ...   ...                                                ...
# 2608095   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
# 2608096   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
# 2608097   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
# 2608098   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
# 2608099   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
#
#           mag_x    mag_y    mag_z  Unnamed: 0  Unnamed: 0.1
# 0           NaN      NaN      NaN         NaN           NaN
# 1           NaN      NaN      NaN         NaN           NaN
# 2           NaN      NaN      NaN         NaN           NaN
# 3           NaN      NaN      NaN         NaN           NaN
# 4           NaN      NaN      NaN         NaN           NaN
# ...         ...      ...      ...         ...           ...
# 2608095   0.000   0.0000    0.000         NaN           NaN
# 2608096   0.000   0.0000    0.000         NaN           NaN
# 2608097 -44.375 -22.3125 -175.875         NaN           NaN
# 2608098   0.000   0.0000    0.000         NaN           NaN
# 2608099   0.000   0.0000    0.000         NaN           NaN
#
# [2608100 rows x 18 columns]

# %% [markdown]
# Now you can get a list of all recording ids, activities, sensor types and anything else you might need.

# %%
print(f"The data was collected using the sensors: {base_df.sensor_type.unique()}")
print(f"The data was collected for the activities: {base_df.activity_type.unique()}")
print(f"The number of unique recordings is: {len(base_df.recording_id.unique())}")
print(f"The subject IDs in the recordings are: {len(base_df.subject_id.unique())}")
# Out:
# The data was collected using the sensors: ['Respeck' 'Thingy']
# The data was collected for the activities: ['Climbing stairs' 'Descending stairs' 'Desk work' 'Lying down left'
#  'Lying down on back' 'Lying down on stomach' 'Lying down right'
#  'Movement' 'Running' 'Sitting' 'Sitting bent backward'
#  'Sitting bent forward' 'Standing' 'Walking at normal speed'
#  'Falling on knees']
# The number of unique recordings is: 3551
# The subject IDs in the recordings are: 123

# %%
base_df =  base_df[base_df["activity_type"] != "Falling on knees"]

# %%
print(f"The data was collected using the sensors: {base_df.sensor_type.unique()}")
print(f"The data was collected for the activities: {base_df.activity_type.unique()}")
print(f"The number of unique recordings is: {len(base_df.recording_id.unique())}")
print(f"The subject IDs in the recordings are: {len(base_df.subject_id.unique())}")
# Out:
# The data was collected using the sensors: ['Respeck' 'Thingy']
# The data was collected for the activities: ['Climbing stairs' 'Descending stairs' 'Desk work' 'Lying down left'
#  'Lying down on back' 'Lying down on stomach' 'Lying down right'
#  'Movement' 'Running' 'Sitting' 'Sitting bent backward'
#  'Sitting bent forward' 'Standing' 'Walking at normal speed']
# The number of unique recordings is: 3527
# The subject IDs in the recordings are: 123

# %% [markdown]
# You can of course change the clean data folder to where you keep all the PDIoT data and you should be seeing a lot more subject IDs, unique recordings and activity types.

# %% [markdown]
# ## Splitting data into sliding windows

# %% [markdown]
# The sliding window approach is one of the most efficient ways to process Human Activity Recognition data. We saw in the last notebook that sensor data comes in the form of Time Series. One single datapoint is not enough to represent an activity, we need a larger snapshot of the signal for that. The image below shows how a sliding window achieves that.
#
# ![sliding windows](../Images/sliding_windows_complete.png "Sliding Windows")
#
# The windows can have some amount of overlap, as shown in the picture, or they can have no overlap at all in which case they would be side-by-side.
#
# Each window can now be treated as an input datapoint to whichever model you choose to train.

# %% [markdown]
# ### Watch out for separate recordings

# %% [markdown]
# You need to make sure that when you split your data into sliding windows you don't accidentally include two separate recordings in the same window. This would cause the signal from the first recording to suddenly "jump" to an unrelated value from the second recording.
#
# For this, you will have to first split up your dataset by recording (this is where the recording ID comes in), then you have to split each recording into sliding windows. At the end you can aggregate all of your resulting sliding windows in a large dataset.

# %% [markdown]
# ### Sliding windows with Pandas

# %% [markdown]
# Pandas conveniently offers built-in functions that help us create the sliding window data very easily.

# %%
example_recording = base_df[base_df.activity_code == 1]

# confim we only have one recording here
len(example_recording.recording_id.unique())
# Out:
# 273

# %%
window_size = 100 # 50 datapoints for the window size, which, at 25Hz, means 2 seconds
step_size = 25 # this is 50% overlap

window_number = 0 # start a counter at 0 to keep track of the window number

large_enough_windows = [window for window in example_recording.rolling(window=window_size, min_periods=window_size) if len(window) == window_size]

# %%
# we then get the windows with the required overlap

overlapping_windows = large_enough_windows[::step_size]

# %%
# then we will append a window ID to each window
for window in overlapping_windows:
    window.loc[:, 'window_id'] = window_number
    window_number += 1

# %%
# now we concatenate all the resulting windows
final_sliding_windows = pd.concat(overlapping_windows).reset_index(drop=True)

# %%
final_sliding_windows
# Out:
#            timestamp   accel_x   accel_y   accel_z      gyro_x     gyro_y  \
# 0       1.664890e+12 -0.221436 -0.975647  0.371765    5.843750  -0.812500
# 1       1.664890e+12 -0.187256 -1.116028  0.368347   -1.031250   2.312500
# 2       1.664890e+12 -0.300049 -1.127991  0.364685   -3.187500   9.046875
# 3       1.664890e+12  0.067383 -1.263245  0.206726  -10.000000 -11.062500
# 4       1.664890e+12  0.155762 -1.372864 -0.033508   16.234375 -17.765625
# ...              ...       ...       ...       ...         ...        ...
# 775895  1.632941e+12 -0.690430 -0.248047 -0.080078  114.250000 -86.562500
# 775896  1.632941e+12 -0.674805  0.218750 -0.177734   39.406250 -99.500000
# 775897  1.632941e+12 -0.432617  0.247070 -0.196289   66.093750 -72.093750
# 775898  1.632941e+12 -0.323242  0.298828 -0.066406   54.843750  -7.718750
# 775899  1.632941e+12 -0.590820  0.218750  0.122070   84.156250  40.875000
#
#            gyro_z sensor_type            activity_type  activity_code  \
# 0        3.703125     Respeck  Walking at normal speed              1
# 1        4.578125     Respeck  Walking at normal speed              1
# 2        1.109375     Respeck  Walking at normal speed              1
# 3        7.640625     Respeck  Walking at normal speed              1
# 4        5.937500     Respeck  Walking at normal speed              1
# ...           ...         ...                      ...            ...
# 775895 -22.531250      Thingy  Walking at normal speed              1
# 775896  -8.312500      Thingy  Walking at normal speed              1
# 775897   2.375000      Thingy  Walking at normal speed              1
# 775898  13.718750      Thingy  Walking at normal speed              1
# 775899   4.000000      Thingy  Walking at normal speed              1
#
#        subject_id notes                                       recording_id  \
# 0        s1732873   1.0  Respeck_s1732873_Walking at normal speed_04-10...
# 1        s1732873   1.0  Respeck_s1732873_Walking at normal speed_04-10...
# 2        s1732873   1.0  Respeck_s1732873_Walking at normal speed_04-10...
# 3        s1732873   1.0  Respeck_s1732873_Walking at normal speed_04-10...
# 4        s1732873   1.0  Respeck_s1732873_Walking at normal speed_04-10...
# ...           ...   ...                                                ...
# 775895   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
# 775896   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
# 775897   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
# 775898   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
# 775899   s2254050   NaN  Thingy_s2254050_Walking at normal speed_29-09-...
#
#          mag_x   mag_y  mag_z  Unnamed: 0  Unnamed: 0.1  window_id
# 0          NaN     NaN    NaN         NaN           NaN          0
# 1          NaN     NaN    NaN         NaN           NaN          0
# 2          NaN     NaN    NaN         NaN           NaN          0
# 3          NaN     NaN    NaN         NaN           NaN          0
# 4          NaN     NaN    NaN         NaN           NaN          0
# ...        ...     ...    ...         ...           ...        ...
# 775895   0.000   0.000    0.0         NaN           NaN       7758
# 775896   0.000   0.000    0.0         NaN           NaN       7758
# 775897   0.000   0.000    0.0         NaN           NaN       7758
# 775898 -42.125 -18.125 -155.0         NaN           NaN       7758
# 775899   0.000   0.000    0.0         NaN           NaN       7758
#
# [775900 rows x 19 columns]

# %% [markdown]
# You can plot each window to see the signals. Here we will plot the first four windows of the walking activity.

# %%
first_four_windows = [group for _, group in final_sliding_windows[final_sliding_windows.window_id < 4].groupby("window_id")]

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 6))

for i in range(4):
    ax[i].plot(first_four_windows[i]['gyro_x'])
    ax[i].plot(first_four_windows[i]['gyro_y'])
    ax[i].plot(first_four_windows[i]['gyro_z'])
    ax[i].set_title(f"Window number = {first_four_windows[i].window_id.values[0]}")

# %% [markdown]
# It's also interesting to observe the dimensionality of one window. Considering just the accelerometer and gyroscope signals, with all three axes, the resulting dimensionality of one window is:

# %%
columns_of_interest = ['accel_x', 'accel_y', 'accel_z', 'gyro_x', 'gyro_y', 'gyro_z']

# %%
np.array(first_four_windows[0][columns_of_interest]).shape
# Out:
# (100, 6)

# %% [markdown]
# ## From sliding windows to datapoints

# %% [markdown]
# Each sliding window needs to be further processed in order to represent an appropriate input datapoint. The preprocessing methods might differ depending on which type of model you choose to use.
#
# You can also do further processing on the signal types and axes, for example smooth the signal, apply axis fusion, eliminate noise etc.
#
# Here we will discuss simple examples without any preprocessing.

# %% [markdown]
# ### Feature extraction with tsfresh

# %% [markdown]
# One quick and simple method to consider for HAR is a [Random Forest Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html). It can take a multi-dimensional datapoint as input and can output a classification.
#
# We can transform each window of data into one single, multidimensional datapoint by applying simple computations using the [tsfresh](https://tsfresh.readthedocs.io/en/latest/text/feature_extraction_settings.html) package.

# %%
feature_list = []

for col in columns_of_interest:
    new_features = tsfresh.extract_features(timeseries_container=final_sliding_windows, column_id='window_id',
                        column_value=col, default_fc_parameters=tsfresh.feature_extraction.MinimalFCParameters())
    new_features.dropna()
    feature_list.append(new_features)
    
feature_list = pd.concat(feature_list, axis=1)

feature_list
# Out:
# Feature Extraction: 100%|██████████| 10/10 [00:01<00:00,  8.04it/s]
# Feature Extraction: 100%|██████████| 10/10 [00:01<00:00,  8.42it/s]
# Feature Extraction: 100%|██████████| 10/10 [00:01<00:00,  5.46it/s]
# Feature Extraction: 100%|██████████| 10/10 [00:01<00:00,  8.54it/s]
# Feature Extraction: 100%|██████████| 10/10 [00:01<00:00,  8.51it/s]
# Feature Extraction: 100%|██████████| 10/10 [00:01<00:00,  5.29it/s]
#       accel_x__sum_values  accel_x__median  accel_x__mean  accel_x__length  \
# 0               -8.468750        -0.076904      -0.084688            100.0
# 1               -8.415283        -0.077026      -0.084153            100.0
# 2               -7.791504        -0.076904      -0.077915            100.0
# 3               -6.407715        -0.081421      -0.064077            100.0
# 4               -6.462402        -0.090088      -0.064624            100.0
# ...                   ...              ...            ...              ...
# 7754          -100.833985        -0.969727      -1.008340            100.0
# 7755          -100.952149        -0.976562      -1.009521            100.0
# 7756           -98.049805        -0.947754      -0.980498            100.0
# 7757           -99.294922        -0.957520      -0.992949            100.0
# 7758          -101.048828        -1.003906      -1.010488            100.0
#
#       accel_x__standard_deviation  accel_x__variance  \
# 0                        0.186374           0.034735
# 1                        0.184021           0.033864
# 2                        0.173362           0.030054
# 3                        0.176411           0.031121
# 4                        0.176756           0.031243
# ...                           ...                ...
# 7754                     0.354686           0.125802
# 7755                     0.406469           0.165217
# 7756                     0.455908           0.207852
# 7757                     0.445798           0.198736
# 7758                     0.443165           0.196395
#
#       accel_x__root_mean_square  accel_x__maximum  accel_x__absolute_maximum  \
# 0                      0.204713          0.413086                   0.733398
# 1                      0.202349          0.413086                   0.733398
# 2                      0.190066          0.425537                   0.489746
# 3                      0.187687          0.457031                   0.461426
# 4                      0.188199          0.457031                   0.535156
# ...                         ...               ...                        ...
# 7754                   1.068902         -0.245117                   2.000000
# 7755                   1.088279         -0.245117                   2.000000
# 7756                   1.081309         -0.133789                   2.000000
# 7757                   1.088432         -0.133789                   2.000000
# 7758                   1.103395         -0.133789                   2.000000
#
#       accel_x__minimum  ...  gyro_z__sum_values  gyro_z__median  gyro_z__mean  \
# 0            -0.733398  ...           -7.609375        1.289062     -0.076094
# 1            -0.733398  ...           19.218750        1.515625      0.192188
# 2            -0.489746  ...           24.734375        1.289062      0.247344
# 3            -0.461426  ...           55.093750        2.046875      0.550937
# 4            -0.535156  ...           83.078125        1.992188      0.830781
# ...                ...  ...                 ...             ...           ...
# 7754         -2.000000  ...         -219.625000       -1.812500     -2.196250
# 7755         -2.000000  ...         -416.687500       -3.218750     -4.166875
# 7756         -2.000000  ...         -542.125000       -3.859375     -5.421250
# 7757         -2.000000  ...         -631.593750       -9.578125     -6.315938
# 7758         -2.000000  ...         -481.343750       -7.515625     -4.813438
#
#       gyro_z__length  gyro_z__standard_deviation  gyro_z__variance  \
# 0              100.0                    7.550905         57.016160
# 1              100.0                    7.560530         57.161609
# 2              100.0                    7.381817         54.491221
# 3              100.0                    7.393191         54.659275
# 4              100.0                    7.103267         50.456402
# ...              ...                         ...               ...
# 7754           100.0                   27.641315        764.042306
# 7755           100.0                   29.735090        884.175590
# 7756           100.0                   29.660588        879.750498
# 7757           100.0                   30.172577        910.384432
# 7758           100.0                   28.849551        832.296610
#
#       gyro_z__root_mean_square  gyro_z__maximum  gyro_z__absolute_maximum  \
# 0                     7.551288         13.06250                 28.109375
# 1                     7.562972         16.00000                 28.109375
# 2                     7.385960         16.00000                 24.421875
# 3                     7.413691         16.00000                 24.421875
# 4                     7.151685         16.00000                 24.421875
# ...                        ...              ...                       ...
# 7754                 27.728430         72.68750                 77.718750
# 7755                 30.025630         72.68750                 77.718750
# 7756                 30.151956         78.71875                 78.875000
# 7757                 30.826539         78.71875                 78.875000
# 7758                 29.248347         93.68750                 93.687500
#
#       gyro_z__minimum
# 0          -28.109375
# 1          -28.109375
# 2          -24.421875
# 3          -24.421875
# 4          -24.421875
# ...               ...
# 7754       -77.718750
# 7755       -77.718750
# 7756       -78.875000
# 7757       -78.875000
# 7758       -78.875000
#
# [7759 rows x 60 columns]

# %% [markdown]
# Now the index represents the window ID, and each row in the DataFrame represents a multi-dimensional datapoint which we can use as input to the RFC.
#
# You can use the window ID to refer back to the initial dataframe and get the class (activity type) for each window.

# %% [markdown]
# We will now process both recordings so that we have two classes for our classifier. For your own work you should only aim to perform classification on data from one sensor.

# %%
window_size = 50 # 50 datapoints for the window size, which, at 25Hz, means 2 seconds
step_size = 25 # this is 50% overlap

window_number = 0 # start a counter at 0 to keep track of the window number

all_overlapping_windows = []

for rid, group in base_df[base_df["recording_id"].str.contains("Thingy")].groupby("recording_id"):
    print(f"Processing rid = {rid}")
    
    large_enough_windows = [window for window in group.rolling(window=window_size, min_periods=window_size) if len(window) == window_size]
    
    overlapping_windows = large_enough_windows[::step_size] 
    
    # then we will append a window ID to each window
    for window in overlapping_windows:
        window.loc[:, 'window_id'] = window_number
        window_number += 1
    
    
    all_overlapping_windows.append(pd.concat(overlapping_windows).reset_index(drop=True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-b54d0ec1dc9a> in <module>
#       6 all_overlapping_windows = []
#       7
# ----> 8 for rid, group in base_df[base_df["recording_id"].str.contains("Thingy")].groupby("recording_id"):
#       9     print(f"Processing rid = {rid}")
#      10
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3792
#    3793         # Do we have a (boolean) 1d indexer?
# -> 3794         if com.is_bool_indexer(key):
#    3795             return self._getitem_bool_array(key)
#    3796
#
# ~/.local/lib/python3.8/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     133                     # Don't raise on e.g. ["A", "B", np.nan], see
#     134                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135                     raise ValueError(na_msg)
#     136                 return False
#     137             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
final_sliding_windows = pd.concat(all_overlapping_windows).reset_index(drop=True)

# %%
# now extract all features
feature_list = []

for col in columns_of_interest:
    new_features = tsfresh.extract_features(timeseries_container=final_sliding_windows, column_id='window_id',
                        column_value=col, default_fc_parameters=tsfresh.feature_extraction.MinimalFCParameters())
    new_features.dropna()
    feature_list.append(new_features)
feature_list = pd.concat(feature_list, axis=1)

feature_list

# %% [markdown]
# Now we also extract the classes from each window

# %%
final_sliding_windows.groupby("window_id")[['activity_type']].agg(np.min)

# %% [markdown]
# We need to assign a number to each categorical class for the Random Forest Classifer. It is mainly up to you how you categorise your classes. In this example, we will use the labels:
# - 0 for Desk work
# - 1 for Walking at normal speed
#
# Bear in mind that your classification task will be multi-class, not binary.

# %%
class_labels = {
    'Desk work': 0,
    'Walking at normal speed': 1,
    'Climbing stairs': 2,
    'Descending stairs': 3,
    'Lying down left': 4,
    'Lying down right': 5,
    'Lying down on back': 6,
    'Lying down on stomach': 7,
    'Movement': 8,
    'Running': 9,
    'Sitting': 10,
    'Sitting bent backward': 11,
    'Sitting bent forward': 12,
    'Standing': 13  
}

# %%
window_id_class_labels = final_sliding_windows.groupby("window_id")[['activity_type']].agg(np.min).replace(class_labels)
window_id_class_labels

# %%
base_df["recording_id"].unique()

# %% [markdown]
# ### Quickly training a Random Forest Classifier

# %% [markdown]
# We now have all the tools to start training a Random Forest Classifier. We will use the feature_list as inputs and window_id_class_labels as outputs. We will do a basic 80/20 split of the data for demonstration purposes.
#
# In your project you should split the data into training and tests sets by excluding entire subjects from the training set. This is discussed later on in this notebook.

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_list, window_id_class_labels,
                                                    test_size=0.2, train_size=0.8)

# %%
print(f"Training set: X_train = {X_train.shape}, y_train = {y_train.shape}")
print(f"Test set: X_test = {X_test.shape}, y_test = {y_test.shape}")

# %% [markdown]
# Now we can build and train the random forest classifier

# %%
rfc = RandomForestClassifier(n_estimators=10)

rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

# %%
print(classification_report(y_pred=y_pred, y_true=y_test))

# %% [markdown]
# This is a very easy problem so the classifier learns very quickly. Your actual problem of classifying multiple activities will be much harder.

# %% [markdown]
# ## Leave-one-subject-out cross-validation

# %% [markdown]
# One of the other reason our previous classifier functions so well is that each person performs activities in a very consistent manner. If a subject's data is both in the training set and the test set, it provides the model with an unfair advantage. Moreover, the results that your model will output will be falsely high. When you test your model on a completely new, unseen subject, your accuracy will drop considerably.
#
# This is why when training a HAR model you will want to do a special kind of cross-validation: Leave-One-Subject-Out (LOSOXV), where we leave one (or more) subject(s) in the testing set at each iteration.
#
# ![losoxv](../Images/LOOCV.png "losoxv")
#
# This ensures that the results we get from our classifier are consistent to what we would get in real life, if we were to test the model on a new user.

# %% [markdown]
# ## Training a simple CNN

# %% [markdown]
# There are some different preprocessing techniques you can apply when the resulting "datapoint" is an input to a convolutional neural network.
#
# You can use two types of convolutional layers:
# * 1D Conv Layers - which will work on 1D data, for example a single axis from one single sensor (accel, gyro or mag)
# * 2D Conv Layers - suitable if the input data is in the form of an image, for example
#
# We will be demonstrating how to build a simple 1D CNN using 6 channels: the 3 axes of the accelerometer and the 3 axes of the gyroscope.

# %% [markdown]
# ### Setting up the model

# %%
filters = 64
kernel_size = 3
n_features = 6
activation='relu'
n_classes = 14

# %%
from keras.utils.vis_utils import plot_model
model = Sequential()

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear', 
                 input_shape=(window_size, n_features)))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='linear'))
model.add(BatchNormalization())
model.add(Activation(activation))

model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(n_classes, activation='softmax'))

model.summary()
plot_model(model, show_shapes=True, show_layer_names = True)

# %% [markdown]
# ### Re-generating the data in the appropriate format

# %% [markdown]
# We need to do a bit more work with our data to bring it into a format fit for training a CNN.
#
# A CNN will take multi-dimensional arrays as input. We have already specified that the input shape is (window_size, n_features), i.e. (50, 6).

# %% [markdown]
# Remember that we generated sliding windows before. Now we just need to take the raw values from each window and create a training set.

# %%
columns_of_interest

# %%
X = []
y = []

for window_id, group in final_sliding_windows.groupby('window_id'):
    print(f"window_id = {window_id}")
    
    shape = group[columns_of_interest].values.shape
    print(f"shape = {shape}")
    
    X.append(group[columns_of_interest].values)
    y.append(class_labels[group["activity_type"].values[0]])

# %%
X = np.asarray(X)
y = np.asarray(y)

print(f"X shape = {X.shape}")
print(f"y shape = {y.shape}")

# %% [markdown]
# We can do a similar test/train split for demonstration purposes. Remember that you will have to split your data by subjects, not radomly.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2, train_size=0.8)

y_train = np.asarray(pd.get_dummies(y_train), dtype=np.float32)
y_test = np.asarray(pd.get_dummies(y_test), dtype=np.float32)

# %%
print(f"X_train shape = {X_train.shape}")
print(f"y_train shape = {y_train.shape}")

print(f"X_test shape = {X_test.shape}")
print(f"y_test shape = {y_test.shape}")

# %% [markdown]
# Now we are ready to start the training process

# %%
model.compile(
    optimizer=optimizers.SGD(learning_rate=0.00001),
    loss='categorical_crossentropy',
    metrics = ['accuracy'])

# %%
model.fit(X_train, y_train,
        batch_size=4, epochs=1000)

# %% [markdown]
# We can now view the accuracy of our model on the test dataset.

# %%
# stats
y_pred_ohe = model.predict(X_test)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# %%
print("*" * 80)
print("Classification report")
print("*" * 80)
print(classification_report(y_true_labels, y_pred_labels))

# %%
clf_report = classification_report(y_true_labels,
                                   y_pred_labels,
                                   output_dict=True)
print(clf_report)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# You are now ready to start developing your own models for HAR. There are numerous tutorials online which you can follow to build models like LSTMs, CNNs, RFCs and many others.
#
# You have a wide choice of ways to solve this classification model. Here are a few things to think about:
#
# * What type of preprocessing do you want to apply to your data? Examples include:
#     * smoothing the sensor axes
#     * performing axis fusion
#     * extracting scalograms from the signal
#     * manually extracting features from the signal
#     * choosing to leave out certain axes
#
# * What type of model do you want to train?
#     * simple ML model
#     * deep learning model
#
# * Do you want a hierarchical model or a flat model?
#     * hierarchical models means you don't have to train the same type of model for each activity
#     * a flat model might be faster to train and apply in real time

# %%
import pathlib

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

tflite_model_file = pathlib.Path("models/cnn_modelv0_thingy2021_2022.tflite")
tflite_model_file.write_bytes(tflite_model)
interpreter = tf.lite.Interpreter(model_content=tflite_model)
interpreter.allocate_tensors()

# %%
import os
print(os.getcwd())
